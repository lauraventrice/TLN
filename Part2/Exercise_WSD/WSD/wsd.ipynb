# %% [markdown]
# #### 0.0 Load libreries

# %%
import nltk 
import re
import math
import random
import csv
from nltk.corpus import wordnet as wn
from nltk.corpus.reader.wordnet import Synset
from scipy.stats import spearmanr, pearsonr
from nltk.corpus import semcor



print("Libreries imported successfully ✓")
# Out:
# Libreries imported successfully ✓

# %% [markdown]
# #### 0.1 definition of functions for preprocessing

# %%
def remove_punctuation(sentence):
    return re.sub(r'[^\w\s]', '', str(sentence)).strip()

def get_stopwords():
    stopwords_file = open(f"./resources/utils/stop_words__frakes_baeza-yates.txt", "r")
    stopwords_list = []
    for word in stopwords_file:
        stopwords_list.append(word.replace('\n', ''))
    stopwords_file.close()

    stopwords_file = open(f"./resources/utils/stop_words_1.txt", "r")
    stopwords_list = []
    for word in stopwords_file:
        stopwords_list.append(word.replace('\n', ''))
    stopwords_file.close()

    stopwords_file = open(f"./resources/utils/stop_words_FULL.txt", "r")
    stopwords_list = []
    for word in stopwords_file:
        stopwords_list.append(word.replace('\n', ''))
    stopwords_file.close()
    
    stopwords_list = list(set(stopwords_list))

    return stopwords_list
     
def remove_stopwords(sentence: str, stopwords_list: list):
    return [word for word in sentence.split() if word not in stopwords_list]

# %% [markdown]
# ### Esercitazione su Word Sense Disambiguation:
#
# #### INPUT :
# l’input per questa esercitazione è costituito da coppie di termini contenute nel file WordSim353 (disponibile nei
# formati .tsv e .csv)
# - Il file contiene 353 coppie di termini utilizzati come testset in varie competizioni internazionali
# - A ciascuna coppia è attribuito un valore numerico [0,10], che rappresenta la similarità fra gli elementi della coppia.

# %%
sim_file = f"resources/WordSim353/WordSim353.csv"

pairs = []
with open(sim_file, 'r', encoding = "utf-8") as f:
    reader = csv.reader(f)
    reader.__next__()
    for lines in reader:
        pairs.append(lines)

print("WordSim353 loaded correctly ✓")
# Out:
# WordSim353 loaded correctly ✓

# %% [markdown]
# #### Prima parte
#
# Implementare tre misure di similarità basate su WordNet. Per ciascuna delle misure di similarità, calcolare:
# - gli indici di correlazione di Spearman e
# - gli indici di correlazione di Pearson fra i risultati ottenuti e quelli ‘target’ presenti nel file annotato.
#
# Le misure da implementare sono le seguenti:
# - Wu & Palmer:
# $$cs(s_1, s_2) = \frac{2 \cdot depth(LCS)}{depth(s_1) + depth(s_2)}$$
#
# in cui $LCS$ rappresenta il primo antenato comune (Lowest Common Subsumer) e depth è la funzione che misura la distanza fra la radice di WordNet e il sysnet $x$.
#
# ***L’obiettivo è implementare la misura di similarità di Wu & Palmer! Non dobbiamo fare ciò che viene già fatto nell’implementazione di nltk o altre librerie!***

# %%
def get_LCS(synset1: Synset, synset2: Synset) -> Synset:
    """
    Return the lowest common subsumer (LCS) of two synsets.
    
    The LCS is the lowest synset (the one with the maximum depth) that has both synsets as descendants.
    """
    
    lcs = None
    hypernyms1 = []
    hypernyms2 = []

    hypernyms1.append(synset1) 
    hypernyms2.append(synset2) 

    # for each synset extraction of hypernyms to add to the list
    for synset in hypernyms1:
        if synset_hyp := synset.hypernyms():
            hypernyms1.extend(synset_hyp)

    for synset in hypernyms2:
        if synset_hyp := synset.hypernyms():
            hypernyms2.extend(synset_hyp)

    if hypernyms1 and hypernyms2:
        if common_hypernyms := set(hypernyms1).intersection(set(hypernyms2)):
            common_hypernyms = [(syn, syn.max_depth() + 1) for syn in common_hypernyms] 
            common_hypernyms.sort(key=lambda x: x[1], reverse=True)
            lcs = common_hypernyms[0][0] 

    return lcs

def depth(synset: Synset) -> int:
    """
    Return the maximum length of the hypernym paths for a synset.
    """
    depth = 0
    if synset:
        depth = max([len(path) for path in synset.hypernym_paths()])

    return depth

# %%
def wu_palmer_similarity(syn1: Synset, syn2: Synset):
    """
    Return the Wu-Palmer similarity between synset.
    Interval (0, 1]
    """
    
    if isinstance(syn1, Synset) and isinstance(syn2, Synset):

        lcs_depth = 0
        
        if lcs := get_LCS(syn1, syn2):
            lcs_depth = lcs.max_depth() + 1
            
        depth1 = depth(syn1) 
        depth2 = depth(syn2) 
        if depth1 > 0 and depth2 > 0:
            cs = (2 * (lcs_depth)) / (depth1 + depth2)

        return cs
    else:
        raise TypeError("The input parameters must be Synset objects")

# %%
# TEST
print("wu similarity between boat and computer: ", wu_palmer_similarity(wn.synsets("boat")[0], wn.synsets("computer")[0]))
print("wu similarity between ferry and boat: ", wu_palmer_similarity(wn.synsets("ferry")[0], wn.synsets("boat")[0]))
print("wu similarity between boat and ship: ", wu_palmer_similarity(wn.synsets("boat")[0], wn.synsets("ship")[0]))
print("wu similarity between computer and chip: ", wu_palmer_similarity(wn.synsets("computer")[0], wn.synsets("chip")[0]))
print("wu similarity between computer and microchip: ", wu_palmer_similarity(wn.synsets("computer")[0], wn.synsets("microchip")[0]))
# Out:
# wu similarity between boat and computer:  0.6
# wu similarity between ferry and boat:  0.9565217391304348
# wu similarity between boat and ship:  0.9090909090909091
# wu similarity between computer and chip:  0.26666666666666666
# wu similarity between computer and microchip:  0.7368421052631579

# %% [markdown]
# - Shortest Path:
# $$sim_{path}(s_1, s_2) = 2 \cdot depthMax - len(s_1, s_2)$$
#
# in cui $depthMax$ è un valore fissato per una specifica versione di WordNet.

# %%
depth_max = max(max(len(hyp_path) for hyp_path in ss.hypernym_paths()) for ss in wn.all_synsets())

def path_len(synset1: Synset, synset2: Synset):
    """
    Return the length of the shortest path between two synsets.
    
    The path length is defined as the number of edges in the shortest path between the two synsets.
    
    If no path exists between the two synsets, return 0.
    """

    distance = 0
    lcs = get_LCS(synset1, synset2)
    if lcs:
        distance = (depth(synset1) - depth(lcs)) + (depth(synset2) - depth(lcs))

    return distance
    

def shortest_path(synset1: Synset, synset2: Synset):
    """
    Return the shortest path measure between two synsets.
    """
    shortest_path = 0
    if (len := path_len(synset1, synset2)) >= 0:
        shortest_path = 2 * depth_max - len
    
    return shortest_path

# %%
# TEST
shortest_path_value = shortest_path(wn.synsets("dog")[0], wn.synsets("computer")[0])
print(shortest_path_value)
# Out:
# 25

# %% [markdown]
# - Leakcock & Chodorow:
# $$sim_{LC}(s_1, s_2) = - log \frac{len(s_1, s_2)}{2 \cdot depthMax}$$

# %%
def leakcock_chodorow(synset1: Synset, synset2: Synset):
    lc = 0
    if (len := path_len(synset1, synset2)) > 0:
        fract = len / (2 * depth_max) 
        lc = - math.log(fract)
    return lc

# %%
# TEST
print("Similarity: ", leakcock_chodorow(wn.synsets("car")[0], wn.synsets("boat")[0]))
# Out:
# Similarity:  1.742969305058623

# %% [markdown]
# #### Calcolo della similarità
#
# Le funzioni precedentemente implementate richiedono come input sensi e non i termini. Quindi per calcolare la similarità fra 2 termini è necessario prendere la massima similarità fra tutti i sensi del primo termine e tutti i sensi del secondo termine.
#
# L'ipotesi quindi è che i due termini funzionino come contesto di disambiguazione l'uno per l'altro.
#
# L'equazione che formalizza questa idea è la seguente:
#
# $$sim(w_1, w_2) = \max_{c_1 \in s(w_1), c_2 \in s(w_2)} [sim(c_1, c_2)]$$
#
# ***NB!*** Per calcolare gli indici di correlazione non si è interessati a entrare nel merito di come sono calcolati, possiamo prendere delle funzioni prefatte e usarle.

# %%
def get_similarity() -> tuple[list[float], list[float], list[float], list[float]]:
    wordsimilarities = []
    wu_palmer_similarities = []
    shortpath_similarities = []
    leakcock_chodorow_similarities = []

    for row in pairs:
        print("-------------------------------")
        print(row)
        term1 = row[0]
        term2 = row[1]

        synsets1 = wn.synsets(term1)
        synsets2 = wn.synsets(term2)

        print("\nsynsets1: ", synsets1)
        print("synsets2: ", synsets2)
        
        if (synsets1 != [] and synsets2 != []):

            wu_palmer_max = 0
            short_path_max = 0
            leakcock_chodorow_max = 0

            for s1 in synsets1:
                for s2 in synsets2:

                    # Metrica 1
                    wu_palmer = wu_palmer_similarity(s1, s2)
                    if wu_palmer > wu_palmer_max:
                        wu_palmer_max = wu_palmer

                    #Metrica 2
                    shortpath = shortest_path(s1, s2)
                    if shortpath > short_path_max:
                        short_path_max = shortpath

                    # Metrica 3
                    leacchod = leakcock_chodorow(s1, s2)
                    if leacchod > leakcock_chodorow_max:
                        leakcock_chodorow_max = leacchod
            
            print("Wu palmer: ", wu_palmer_max)
            print("Shortest path: ", short_path_max)
            print("Leakcock & Chodorow: ", leakcock_chodorow_max)
            wu_palmer_similarities.append(float(wu_palmer_max))
            shortpath_similarities.append(float(short_path_max))
            leakcock_chodorow_similarities.append(float(leakcock_chodorow_max))
            
            wordsimilarities.append(float(row[2]))

    return wu_palmer_similarities, shortpath_similarities, leakcock_chodorow_similarities, wordsimilarities

# %%
wupalmerres, pathres, lcres, wordsimres = get_similarity()
# Out:
# -------------------------------
# ['love', 'sex', '6.77']
#
# synsets1:  [Synset('love.n.01'), Synset('love.n.02'), Synset('beloved.n.01'), Synset('love.n.04'), Synset('love.n.05'), Synset('sexual_love.n.02'), Synset('love.v.01'), Synset('love.v.02'), Synset('love.v.03'), Synset('sleep_together.v.01')]
# synsets2:  [Synset('sexual_activity.n.01'), Synset('sex.n.02'), Synset('sex.n.03'), Synset('sex.n.04'), Synset('arouse.v.07'), Synset('sex.v.02')]
# Wu palmer:  0.9230769230769231
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['tiger', 'cat', '7.35']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('cat.n.01'), Synset('guy.n.01'), Synset('cat.n.03'), Synset('kat.n.01'), Synset('cat-o'-nine-tails.n.01'), Synset('caterpillar.n.02'), Synset('big_cat.n.01'), Synset('computerized_tomography.n.01'), Synset('cat.v.01'), Synset('vomit.v.01')]
# Wu palmer:  0.9655172413793104
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['tiger', 'tiger', '10.00']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# Wu palmer:  1.0
# Shortest path:  40
# Leakcock & Chodorow:  1.2909841813155656
# -------------------------------
# ['book', 'paper', '7.46']
#
# synsets1:  [Synset('book.n.01'), Synset('book.n.02'), Synset('record.n.05'), Synset('script.n.01'), Synset('ledger.n.01'), Synset('book.n.06'), Synset('book.n.07'), Synset('koran.n.01'), Synset('bible.n.01'), Synset('book.n.10'), Synset('book.n.11'), Synset('book.v.01'), Synset('reserve.v.04'), Synset('book.v.03'), Synset('book.v.04')]
# synsets2:  [Synset('paper.n.01'), Synset('composition.n.08'), Synset('newspaper.n.01'), Synset('paper.n.04'), Synset('paper.n.05'), Synset('newspaper.n.02'), Synset('newspaper.n.03'), Synset('paper.v.01'), Synset('wallpaper.v.01')]
# Wu palmer:  0.875
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['computer', 'keyboard', '7.62']
#
# synsets1:  [Synset('computer.n.01'), Synset('calculator.n.01')]
# synsets2:  [Synset('keyboard.n.01'), Synset('keyboard.n.02')]
# Wu palmer:  0.8235294117647058
# Shortest path:  37
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['computer', 'internet', '7.58']
#
# synsets1:  [Synset('computer.n.01'), Synset('calculator.n.01')]
# synsets2:  [Synset('internet.n.01')]
# Wu palmer:  0.631578947368421
# Shortest path:  33
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['plane', 'car', '5.77']
#
# synsets1:  [Synset('airplane.n.01'), Synset('plane.n.02'), Synset('plane.n.03'), Synset('plane.n.04'), Synset('plane.n.05'), Synset('plane.v.01'), Synset('plane.v.02'), Synset('plane.v.03'), Synset('flat.s.01')]
# synsets2:  [Synset('car.n.01'), Synset('car.n.02'), Synset('car.n.03'), Synset('car.n.04'), Synset('cable_car.n.01')]
# Wu palmer:  0.7272727272727273
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['train', 'car', '6.31']
#
# synsets1:  [Synset('train.n.01'), Synset('string.n.04'), Synset('caravan.n.01'), Synset('train.n.04'), Synset('train.n.05'), Synset('gearing.n.01'), Synset('train.v.01'), Synset('train.v.02'), Synset('discipline.v.01'), Synset('prepare.v.05'), Synset('educate.v.03'), Synset('aim.v.01'), Synset('coach.v.01'), Synset('train.v.08'), Synset('train.v.09'), Synset('train.v.10'), Synset('trail.v.05')]
# synsets2:  [Synset('car.n.01'), Synset('car.n.02'), Synset('car.n.03'), Synset('car.n.04'), Synset('cable_car.n.01')]
# Wu palmer:  0.7368421052631579
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['telephone', 'communication', '7.50']
#
# synsets1:  [Synset('telephone.n.01'), Synset('telephone.n.02'), Synset('call.v.03')]
# synsets2:  [Synset('communication.n.01'), Synset('communication.n.02'), Synset('communication.n.03')]
# Wu palmer:  0.16666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  1.3862943611198906
# -------------------------------
# ['television', 'radio', '6.77']
#
# synsets1:  [Synset('television.n.01'), Synset('television.n.02'), Synset('television_receiver.n.01')]
# synsets2:  [Synset('radio.n.01'), Synset('radio_receiver.n.01'), Synset('radio.n.03'), Synset('radio.v.01'), Synset('radio.a.01')]
# Wu palmer:  0.9090909090909091
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['media', 'radio', '7.42']
#
# synsets1:  [Synset('medium.n.01'), Synset('medium.n.02'), Synset('medium.n.03'), Synset('culture_medium.n.01'), Synset('medium.n.05'), Synset('medium.n.06'), Synset('medium.n.07'), Synset('medium.n.08'), Synset('medium.n.09'), Synset('medium.n.10'), Synset('metier.n.02')]
# synsets2:  [Synset('radio.n.01'), Synset('radio_receiver.n.01'), Synset('radio.n.03'), Synset('radio.v.01'), Synset('radio.a.01')]
# Wu palmer:  0.8235294117647058
# Shortest path:  40
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['drug', 'abuse', '6.85']
#
# synsets1:  [Synset('drug.n.01'), Synset('drug.v.01'), Synset('drug.v.02')]
# synsets2:  [Synset('maltreatment.n.01'), Synset('abuse.n.02'), Synset('misuse.n.01'), Synset('mistreat.v.01'), Synset('pervert.v.03'), Synset('abuse.v.03'), Synset('abuse.v.04')]
# Wu palmer:  0.16666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  1.3862943611198906
# -------------------------------
# ['bread', 'butter', '6.19']
#
# synsets1:  [Synset('bread.n.01'), Synset('boodle.n.01'), Synset('bread.v.01')]
# synsets2:  [Synset('butter.n.01'), Synset('butter.n.02'), Synset('butter.v.01')]
# Wu palmer:  0.75
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['cucumber', 'potato', '5.92']
#
# synsets1:  [Synset('cucumber.n.01'), Synset('cucumber.n.02')]
# synsets2:  [Synset('potato.n.01'), Synset('potato.n.02')]
# Wu palmer:  0.8235294117647058
# Shortest path:  37
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['doctor', 'nurse', '7.00']
#
# synsets1:  [Synset('doctor.n.01'), Synset('doctor_of_the_church.n.01'), Synset('doctor.n.03'), Synset('doctor.n.04'), Synset('sophisticate.v.03'), Synset('doctor.v.02'), Synset('repair.v.01')]
# synsets2:  [Synset('nurse.n.01'), Synset('nanny.n.01'), Synset('nurse.v.01'), Synset('harbor.v.01'), Synset('nurse.v.03'), Synset('nurse.v.04'), Synset('breastfeed.v.01')]
# Wu palmer:  0.8695652173913043
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['professor', 'doctor', '6.62']
#
# synsets1:  [Synset('professor.n.01')]
# synsets2:  [Synset('doctor.n.01'), Synset('doctor_of_the_church.n.01'), Synset('doctor.n.03'), Synset('doctor.n.04'), Synset('sophisticate.v.03'), Synset('doctor.v.02'), Synset('repair.v.01')]
# Wu palmer:  0.75
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['student', 'professor', '6.81']
#
# synsets1:  [Synset('student.n.01'), Synset('scholar.n.01')]
# synsets2:  [Synset('professor.n.01')]
# Wu palmer:  0.6666666666666666
# Shortest path:  33
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['smart', 'student', '4.62']
#
# synsets1:  [Synset('smart.n.01'), Synset('ache.v.03'), Synset('smart.a.01'), Synset('chic.s.01'), Synset('bright.s.03'), Synset('fresh.s.12'), Synset('smart.s.05'), Synset('smart.s.06'), Synset('smart.s.07')]
# synsets2:  [Synset('student.n.01'), Synset('scholar.n.01')]
# Wu palmer:  0.1111111111111111
# Shortest path:  40
# Leakcock & Chodorow:  0.916290731874155
# -------------------------------
# ['smart', 'stupid', '5.81']
#
# synsets1:  [Synset('smart.n.01'), Synset('ache.v.03'), Synset('smart.a.01'), Synset('chic.s.01'), Synset('bright.s.03'), Synset('fresh.s.12'), Synset('smart.s.05'), Synset('smart.s.06'), Synset('smart.s.07')]
# synsets2:  [Synset('stupid.n.01'), Synset('stupid.a.01'), Synset('dazed.s.01'), Synset('unintelligent.a.01')]
# Wu palmer:  0.1111111111111111
# Shortest path:  40
# Leakcock & Chodorow:  0.916290731874155
# -------------------------------
# ['company', 'stock', '7.08']
#
# synsets1:  [Synset('company.n.01'), Synset('company.n.02'), Synset('company.n.03'), Synset('company.n.04'), Synset('caller.n.01'), Synset('company.n.06'), Synset('party.n.03'), Synset('ship's_company.n.01'), Synset('company.n.09'), Synset('company.v.01')]
# synsets2:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# Wu palmer:  0.6153846153846154
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['stock', 'market', '8.08']
#
# synsets1:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# synsets2:  [Synset('market.n.01'), Synset('market.n.02'), Synset('grocery_store.n.01'), Synset('market.n.04'), Synset('marketplace.n.02'), Synset('market.v.01'), Synset('market.v.02'), Synset('market.v.03'), Synset('commercialize.v.02')]
# Wu palmer:  0.5555555555555556
# Shortest path:  40
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['stock', 'phone', '1.62']
#
# synsets1:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# synsets2:  [Synset('telephone.n.01'), Synset('phone.n.02'), Synset('earphone.n.01'), Synset('call.v.03')]
# Wu palmer:  0.7
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['stock', 'CD', '1.31']
#
# synsets1:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# synsets2:  [Synset('cadmium.n.01'), Synset('candle.n.02'), Synset('certificate_of_deposit.n.01'), Synset('compact_disk.n.01'), Synset('four_hundred.s.01')]
# Wu palmer:  0.7368421052631579
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['stock', 'jaguar', '0.92']
#
# synsets1:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# synsets2:  [Synset('jaguar.n.01')]
# Wu palmer:  0.8148148148148148
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['stock', 'egg', '1.81']
#
# synsets1:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# synsets2:  [Synset('egg.n.01'), Synset('egg.n.02'), Synset('testis.n.01'), Synset('egg.v.01'), Synset('egg.v.02')]
# Wu palmer:  0.625
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['fertility', 'egg', '6.69']
#
# synsets1:  [Synset('birthrate.n.01'), Synset('fertility.n.02'), Synset('richness.n.05')]
# synsets2:  [Synset('egg.n.01'), Synset('egg.n.02'), Synset('testis.n.01'), Synset('egg.v.01'), Synset('egg.v.02')]
# Wu palmer:  0.15384615384615385
# Shortest path:  40
# Leakcock & Chodorow:  1.2909841813155656
# -------------------------------
# ['stock', 'live', '3.73']
#
# synsets1:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# synsets2:  [Synset('populate.v.01'), Synset('live.v.02'), Synset('survive.v.01'), Synset('exist.v.02'), Synset('be.v.11'), Synset('know.v.05'), Synset('live.v.07'), Synset('live.a.01'), Synset('live.a.02'), Synset('alive.a.01'), Synset('live.s.04'), Synset('live.s.05'), Synset('bouncy.s.01'), Synset('live.s.07'), Synset('live.s.08'), Synset('live.s.09'), Synset('hot.s.20'), Synset('alive.s.07'), Synset('live.r.01')]
# Wu palmer:  0.2857142857142857
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['stock', 'life', '0.92']
#
# synsets1:  [Synset('stock.n.01'), Synset('stock.n.02'), Synset('stock.n.03'), Synset('stock_certificate.n.01'), Synset('store.n.02'), Synset('lineage.n.01'), Synset('breed.n.01'), Synset('broth.n.01'), Synset('stock.n.09'), Synset('stock.n.10'), Synset('stock.n.11'), Synset('stock.n.12'), Synset('malcolm_stock.n.01'), Synset('stock.n.14'), Synset('stock.n.15'), Synset('neckcloth.n.01'), Synset('livestock.n.01'), Synset('stock.v.01'), Synset('stock.v.02'), Synset('stock.v.03'), Synset('stock.v.04'), Synset('stock.v.05'), Synset('stock.v.06'), Synset('sprout.v.02'), Synset('banal.s.01'), Synset('stock.s.02'), Synset('standard.s.05')]
# synsets2:  [Synset('life.n.01'), Synset('life.n.02'), Synset('life.n.03'), Synset('animation.n.01'), Synset('life.n.05'), Synset('life.n.06'), Synset('life.n.07'), Synset('life.n.08'), Synset('liveliness.n.02'), Synset('life.n.10'), Synset('life.n.11'), Synset('biography.n.01'), Synset('life.n.13'), Synset('life_sentence.n.01')]
# Wu palmer:  0.6153846153846154
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['book', 'library', '7.46']
#
# synsets1:  [Synset('book.n.01'), Synset('book.n.02'), Synset('record.n.05'), Synset('script.n.01'), Synset('ledger.n.01'), Synset('book.n.06'), Synset('book.n.07'), Synset('koran.n.01'), Synset('bible.n.01'), Synset('book.n.10'), Synset('book.n.11'), Synset('book.v.01'), Synset('reserve.v.04'), Synset('book.v.03'), Synset('book.v.04')]
# synsets2:  [Synset('library.n.01'), Synset('library.n.02'), Synset('library.n.03'), Synset('library.n.04'), Synset('library.n.05')]
# Wu palmer:  0.8
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['bank', 'money', '8.12']
#
# synsets1:  [Synset('bank.n.01'), Synset('depository_financial_institution.n.01'), Synset('bank.n.03'), Synset('bank.n.04'), Synset('bank.n.05'), Synset('bank.n.06'), Synset('bank.n.07'), Synset('savings_bank.n.02'), Synset('bank.n.09'), Synset('bank.n.10'), Synset('bank.v.01'), Synset('bank.v.02'), Synset('bank.v.03'), Synset('bank.v.04'), Synset('bank.v.05'), Synset('deposit.v.02'), Synset('bank.v.07'), Synset('trust.v.01')]
# synsets2:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# Wu palmer:  0.5714285714285714
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['wood', 'forest', '7.73']
#
# synsets1:  [Synset('wood.n.01'), Synset('forest.n.01'), Synset('wood.n.03'), Synset('wood.n.04'), Synset('wood.n.05'), Synset('wood.n.06'), Synset('woodwind.n.01'), Synset('wood.n.08')]
# synsets2:  [Synset('forest.n.01'), Synset('forest.n.02'), Synset('afforest.v.01')]
# Wu palmer:  1.0
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['money', 'cash', '9.15']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('cash.n.01'), Synset('cash.n.02'), Synset('cash.n.03'), Synset('cash.v.01')]
# Wu palmer:  0.875
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['professor', 'cucumber', '0.31']
#
# synsets1:  [Synset('professor.n.01')]
# synsets2:  [Synset('cucumber.n.01'), Synset('cucumber.n.02')]
# Wu palmer:  0.5
# Shortest path:  28
# Leakcock & Chodorow:  1.2039728043259361
# -------------------------------
# ['king', 'cabbage', '0.23']
#
# synsets1:  [Synset('king.n.01'), Synset('king.n.02'), Synset('baron.n.03'), Synset('king.n.04'), Synset('king.n.05'), Synset('king.n.06'), Synset('king.n.07'), Synset('king.n.08'), Synset('king.n.09'), Synset('king.n.10')]
# synsets2:  [Synset('cabbage.n.01'), Synset('boodle.n.01'), Synset('cabbage.n.03'), Synset('pilfer.v.01')]
# Wu palmer:  0.5714285714285714
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['king', 'queen', '8.58']
#
# synsets1:  [Synset('king.n.01'), Synset('king.n.02'), Synset('baron.n.03'), Synset('king.n.04'), Synset('king.n.05'), Synset('king.n.06'), Synset('king.n.07'), Synset('king.n.08'), Synset('king.n.09'), Synset('king.n.10')]
# synsets2:  [Synset('queen.n.01'), Synset('queen.n.02'), Synset('queen.n.03'), Synset('queen.n.04'), Synset('king.n.02'), Synset('fagot.n.01'), Synset('queen.n.07'), Synset('queen.n.08'), Synset('queen.n.09'), Synset('tabby.n.02'), Synset('queen.v.01'), Synset('queen.v.02')]
# Wu palmer:  1.0
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['king', 'rook', '5.92']
#
# synsets1:  [Synset('king.n.01'), Synset('king.n.02'), Synset('baron.n.03'), Synset('king.n.04'), Synset('king.n.05'), Synset('king.n.06'), Synset('king.n.07'), Synset('king.n.08'), Synset('king.n.09'), Synset('king.n.10')]
# synsets2:  [Synset('castle.n.03'), Synset('rook.n.02'), Synset('victimize.v.03')]
# Wu palmer:  0.9090909090909091
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['bishop', 'rabbi', '6.69']
#
# synsets1:  [Synset('bishop.n.01'), Synset('bishop.n.02'), Synset('bishop.n.03')]
# synsets2:  [Synset('rabbi.n.01'), Synset('rabbi.n.02')]
# Wu palmer:  0.8181818181818182
# Shortest path:  36
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['Jerusalem', 'Israel', '8.46']
#
# synsets1:  [Synset('jerusalem.n.01')]
# synsets2:  [Synset('israel.n.01'), Synset('israel.n.02')]
# Wu palmer:  0
# Shortest path:  40
# Leakcock & Chodorow:  0
# -------------------------------
# ['Jerusalem', 'Palestinian', '7.65']
#
# synsets1:  [Synset('jerusalem.n.01')]
# synsets2:  [Synset('palestinian.n.01'), Synset('palestinian.a.01')]
# Wu palmer:  0
# Shortest path:  40
# Leakcock & Chodorow:  0
# -------------------------------
# ['holy', 'sex', '1.62']
#
# synsets1:  [Synset('holy_place.n.01'), Synset('holy.a.01')]
# synsets2:  [Synset('sexual_activity.n.01'), Synset('sex.n.02'), Synset('sex.n.03'), Synset('sex.n.04'), Synset('arouse.v.07'), Synset('sex.v.02')]
# Wu palmer:  0.3076923076923077
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['fuck', 'sex', '9.44']
#
# synsets1:  [Synset('fuck.n.01'), Synset('sleep_together.v.01')]
# synsets2:  [Synset('sexual_activity.n.01'), Synset('sex.n.02'), Synset('sex.n.03'), Synset('sex.n.04'), Synset('arouse.v.07'), Synset('sex.v.02')]
# Wu palmer:  0.8571428571428571
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['Maradona', 'football', '8.62']
#
# synsets1:  []
# synsets2:  [Synset('football.n.01'), Synset('football.n.02')]
# -------------------------------
# ['football', 'soccer', '9.03']
#
# synsets1:  [Synset('football.n.01'), Synset('football.n.02')]
# synsets2:  [Synset('soccer.n.01')]
# Wu palmer:  0.96
# Shortest path:  39
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['football', 'basketball', '6.81']
#
# synsets1:  [Synset('football.n.01'), Synset('football.n.02')]
# synsets2:  [Synset('basketball.n.01'), Synset('basketball.n.02')]
# Wu palmer:  0.9
# Shortest path:  38
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['football', 'tennis', '6.63']
#
# synsets1:  [Synset('football.n.01'), Synset('football.n.02')]
# synsets2:  [Synset('tennis.n.01')]
# Wu palmer:  0.782608695652174
# Shortest path:  35
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['tennis', 'racket', '7.56']
#
# synsets1:  [Synset('tennis.n.01')]
# synsets2:  [Synset('racket.n.01'), Synset('racket.n.02'), Synset('noise.n.02'), Synset('racket.n.04'), Synset('revel.v.02'), Synset('racket.v.02'), Synset('racket.v.03')]
# Wu palmer:  0.5714285714285714
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['Arafat', 'peace', '6.73']
#
# synsets1:  [Synset('arafat.n.01')]
# synsets2:  [Synset('peace.n.01'), Synset('peace.n.02'), Synset('peace.n.03'), Synset('peace.n.04'), Synset('peace.n.05')]
# Wu palmer:  0
# Shortest path:  40
# Leakcock & Chodorow:  0
# -------------------------------
# ['Arafat', 'terror', '7.65']
#
# synsets1:  [Synset('arafat.n.01')]
# synsets2:  [Synset('panic.n.01'), Synset('terror.n.02'), Synset('terror.n.03'), Synset('terror.n.04')]
# Wu palmer:  0
# Shortest path:  40
# Leakcock & Chodorow:  0
# -------------------------------
# ['Arafat', 'Jackson', '2.50']
#
# synsets1:  [Synset('arafat.n.01')]
# synsets2:  [Synset('jackson.n.01'), Synset('jackson.n.02'), Synset('jackson.n.03'), Synset('jackson.n.04'), Synset('jackson.n.05'), Synset('jackson.n.06'), Synset('jackson.n.07'), Synset('jackson.n.08'), Synset('jackson.n.09'), Synset('jackson.n.10'), Synset('jackson.n.11')]
# Wu palmer:  0
# Shortest path:  40
# Leakcock & Chodorow:  0
# -------------------------------
# ['law', 'lawyer', '8.38']
#
# synsets1:  [Synset('law.n.01'), Synset('law.n.02'), Synset('law.n.03'), Synset('law.n.04'), Synset('jurisprudence.n.01'), Synset('law.n.06'), Synset('police.n.01')]
# synsets2:  [Synset('lawyer.n.01')]
# Wu palmer:  0.13333333333333333
# Shortest path:  27
# Leakcock & Chodorow:  1.1239300966523995
# -------------------------------
# ['movie', 'star', '7.38']
#
# synsets1:  [Synset('movie.n.01')]
# synsets2:  [Synset('star.n.01'), Synset('ace.n.03'), Synset('star.n.03'), Synset('star.n.04'), Synset('star.n.05'), Synset('headliner.n.01'), Synset('asterisk.n.01'), Synset('star_topology.n.01'), Synset('star.v.01'), Synset('star.v.02'), Synset('star.v.03'), Synset('leading.s.01')]
# Wu palmer:  0.5333333333333333
# Shortest path:  40
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['movie', 'popcorn', '6.19']
#
# synsets1:  [Synset('movie.n.01')]
# synsets2:  [Synset('popcorn.n.01'), Synset('popcorn.n.02')]
# Wu palmer:  0.36363636363636365
# Shortest path:  27
# Leakcock & Chodorow:  1.1239300966523995
# -------------------------------
# ['movie', 'critic', '6.73']
#
# synsets1:  [Synset('movie.n.01')]
# synsets2:  [Synset('critic.n.01'), Synset('critic.n.02'), Synset('critic.n.03')]
# Wu palmer:  0.4444444444444444
# Shortest path:  30
# Leakcock & Chodorow:  1.3862943611198906
# -------------------------------
# ['movie', 'theater', '7.92']
#
# synsets1:  [Synset('movie.n.01')]
# synsets2:  [Synset('theater.n.01'), Synset('dramaturgy.n.01'), Synset('field.n.11')]
# Wu palmer:  0.625
# Shortest path:  34
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['physics', 'proton', '8.12']
#
# synsets1:  [Synset('physics.n.01'), Synset('physics.n.02'), Synset('purgative.n.01')]
# synsets2:  [Synset('proton.n.01')]
# Wu palmer:  0.2
# Shortest path:  24
# Leakcock & Chodorow:  0.916290731874155
# -------------------------------
# ['physics', 'chemistry', '7.35']
#
# synsets1:  [Synset('physics.n.01'), Synset('physics.n.02'), Synset('purgative.n.01')]
# synsets2:  [Synset('chemistry.n.01'), Synset('chemistry.n.02'), Synset('chemistry.n.03')]
# Wu palmer:  0.9
# Shortest path:  38
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['space', 'chemistry', '4.88']
#
# synsets1:  [Synset('space.n.01'), Synset('space.n.02'), Synset('space.n.03'), Synset('outer_space.n.01'), Synset('space.n.05'), Synset('distance.n.05'), Synset('space.n.07'), Synset('space.n.08'), Synset('quad.n.03'), Synset('space.v.01')]
# synsets2:  [Synset('chemistry.n.01'), Synset('chemistry.n.02'), Synset('chemistry.n.03')]
# Wu palmer:  0.4444444444444444
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['alcohol', 'chemistry', '5.54']
#
# synsets1:  [Synset('alcohol.n.01'), Synset('alcohol.n.02')]
# synsets2:  [Synset('chemistry.n.01'), Synset('chemistry.n.02'), Synset('chemistry.n.03')]
# Wu palmer:  0.7142857142857143
# Shortest path:  36
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['vodka', 'gin', '8.46']
#
# synsets1:  [Synset('vodka.n.01')]
# synsets2:  [Synset('gin.n.01'), Synset('snare.n.05'), Synset('cotton_gin.n.01'), Synset('gin.n.04'), Synset('gin.v.01'), Synset('gin.v.02')]
# Wu palmer:  0.9090909090909091
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['vodka', 'brandy', '8.13']
#
# synsets1:  [Synset('vodka.n.01')]
# synsets2:  [Synset('brandy.n.01')]
# Wu palmer:  0.9090909090909091
# Shortest path:  38
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['drink', 'car', '3.04']
#
# synsets1:  [Synset('drink.n.01'), Synset('drink.n.02'), Synset('beverage.n.01'), Synset('drink.n.04'), Synset('swallow.n.02'), Synset('drink.v.01'), Synset('drink.v.02'), Synset('toast.v.02'), Synset('drink_in.v.01'), Synset('drink.v.05')]
# synsets2:  [Synset('car.n.01'), Synset('car.n.02'), Synset('car.n.03'), Synset('car.n.04'), Synset('cable_car.n.01')]
# Wu palmer:  0.26666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  1.2909841813155656
# -------------------------------
# ['drink', 'ear', '1.31']
#
# synsets1:  [Synset('drink.n.01'), Synset('drink.n.02'), Synset('beverage.n.01'), Synset('drink.n.04'), Synset('swallow.n.02'), Synset('drink.v.01'), Synset('drink.v.02'), Synset('toast.v.02'), Synset('drink_in.v.01'), Synset('drink.v.05')]
# synsets2:  [Synset('ear.n.01'), Synset('ear.n.02'), Synset('auricle.n.02'), Synset('ear.n.04'), Synset('ear.n.05')]
# Wu palmer:  0.46153846153846156
# Shortest path:  40
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['drink', 'mouth', '5.96']
#
# synsets1:  [Synset('drink.n.01'), Synset('drink.n.02'), Synset('beverage.n.01'), Synset('drink.n.04'), Synset('swallow.n.02'), Synset('drink.v.01'), Synset('drink.v.02'), Synset('toast.v.02'), Synset('drink_in.v.01'), Synset('drink.v.05')]
# synsets2:  [Synset('mouth.n.01'), Synset('mouth.n.02'), Synset('mouth.n.03'), Synset('mouth.n.04'), Synset('mouth.n.05'), Synset('mouthpiece.n.03'), Synset('sass.n.01'), Synset('mouth.n.08'), Synset('talk.v.02'), Synset('mouth.v.02'), Synset('mouth.v.03')]
# Wu palmer:  0.5
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['drink', 'eat', '6.87']
#
# synsets1:  [Synset('drink.n.01'), Synset('drink.n.02'), Synset('beverage.n.01'), Synset('drink.n.04'), Synset('swallow.n.02'), Synset('drink.v.01'), Synset('drink.v.02'), Synset('toast.v.02'), Synset('drink_in.v.01'), Synset('drink.v.05')]
# synsets2:  [Synset('eat.v.01'), Synset('eat.v.02'), Synset('feed.v.06'), Synset('eat.v.04'), Synset('consume.v.05'), Synset('corrode.v.01')]
# Wu palmer:  0.5
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['baby', 'mother', '7.85']
#
# synsets1:  [Synset('baby.n.01'), Synset('baby.n.02'), Synset('child.n.03'), Synset('baby.n.04'), Synset('baby.n.05'), Synset('baby.n.06'), Synset('baby.n.07'), Synset('pamper.v.01')]
# synsets2:  [Synset('mother.n.01'), Synset('mother.n.02'), Synset('mother.n.03'), Synset('mother.n.04'), Synset('mother.n.05'), Synset('mother.v.01'), Synset('beget.v.01')]
# Wu palmer:  0.8181818181818182
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['drink', 'mother', '2.65']
#
# synsets1:  [Synset('drink.n.01'), Synset('drink.n.02'), Synset('beverage.n.01'), Synset('drink.n.04'), Synset('swallow.n.02'), Synset('drink.v.01'), Synset('drink.v.02'), Synset('toast.v.02'), Synset('drink_in.v.01'), Synset('drink.v.05')]
# synsets2:  [Synset('mother.n.01'), Synset('mother.n.02'), Synset('mother.n.03'), Synset('mother.n.04'), Synset('mother.n.05'), Synset('mother.v.01'), Synset('beget.v.01')]
# Wu palmer:  0.5333333333333333
# Shortest path:  40
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['car', 'automobile', '8.94']
#
# synsets1:  [Synset('car.n.01'), Synset('car.n.02'), Synset('car.n.03'), Synset('car.n.04'), Synset('cable_car.n.01')]
# synsets2:  [Synset('car.n.01'), Synset('automobile.v.01')]
# Wu palmer:  1.0
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['gem', 'jewel', '8.96']
#
# synsets1:  [Synset('gem.n.01'), Synset('gem.n.02'), Synset('jewel.n.02'), Synset('muffin.n.01'), Synset('jewel.n.01')]
# synsets2:  [Synset('jewel.n.01'), Synset('jewel.n.02'), Synset('bejewel.v.01')]
# Wu palmer:  1.0
# Shortest path:  40
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['journey', 'voyage', '9.29']
#
# synsets1:  [Synset('journey.n.01'), Synset('travel.v.02'), Synset('travel.v.04')]
# synsets2:  [Synset('ocean_trip.n.01'), Synset('voyage.n.02'), Synset('voyage.v.01')]
# Wu palmer:  0.9523809523809523
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['boy', 'lad', '8.83']
#
# synsets1:  [Synset('male_child.n.01'), Synset('boy.n.02'), Synset('son.n.01'), Synset('boy.n.04')]
# synsets2:  [Synset('chap.n.01'), Synset('cub.n.02')]
# Wu palmer:  0.9473684210526315
# Shortest path:  39
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['coast', 'shore', '9.10']
#
# synsets1:  [Synset('seashore.n.01'), Synset('coast.n.02'), Synset('coast.n.03'), Synset('slide.n.05'), Synset('coast.v.01')]
# synsets2:  [Synset('shore.n.01'), Synset('shore.n.02'), Synset('shore.v.01'), Synset('land.v.06'), Synset('prop_up.v.01')]
# Wu palmer:  0.9090909090909091
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['asylum', 'madhouse', '8.87']
#
# synsets1:  [Synset('refuge.n.03'), Synset('mental_hospital.n.01')]
# synsets2:  [Synset('bedlam.n.02')]
# Wu palmer:  0.9523809523809523
# Shortest path:  39
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['magician', 'wizard', '9.02']
#
# synsets1:  [Synset('magician.n.01'), Synset('sorcerer.n.01')]
# synsets2:  [Synset('ace.n.03'), Synset('sorcerer.n.01'), Synset('charming.s.02')]
# Wu palmer:  1.0
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['midday', 'noon', '9.29']
#
# synsets1:  [Synset('noon.n.01')]
# synsets2:  [Synset('noon.n.01')]
# Wu palmer:  1.0
# Shortest path:  40
# Leakcock & Chodorow:  0
# -------------------------------
# ['furnace', 'stove', '8.79']
#
# synsets1:  [Synset('furnace.n.01')]
# synsets2:  [Synset('stove.n.01'), Synset('stove.n.02'), Synset('stave.v.01'), Synset('stave.v.02')]
# Wu palmer:  0.5263157894736842
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['food', 'fruit', '7.52']
#
# synsets1:  [Synset('food.n.01'), Synset('food.n.02'), Synset('food.n.03')]
# synsets2:  [Synset('fruit.n.01'), Synset('yield.n.03'), Synset('fruit.n.03'), Synset('fruit.v.01'), Synset('fruit.v.02')]
# Wu palmer:  0.4
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['bird', 'cock', '7.10']
#
# synsets1:  [Synset('bird.n.01'), Synset('bird.n.02'), Synset('dame.n.01'), Synset('boo.n.01'), Synset('shuttlecock.n.01'), Synset('bird.v.01')]
# synsets2:  [Synset('cock.n.01'), Synset('stopcock.n.01'), Synset('hammer.n.01'), Synset('cock.n.04'), Synset('cock.n.05'), Synset('cock.v.01'), Synset('cock.v.02'), Synset('tittup.v.01')]
# Wu palmer:  0.9523809523809523
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['bird', 'crane', '7.38']
#
# synsets1:  [Synset('bird.n.01'), Synset('bird.n.02'), Synset('dame.n.01'), Synset('boo.n.01'), Synset('shuttlecock.n.01'), Synset('bird.v.01')]
# synsets2:  [Synset('crane.n.01'), Synset('crane.n.02'), Synset('grus.n.01'), Synset('crane.n.04'), Synset('crane.n.05'), Synset('crane.v.01')]
# Wu palmer:  0.8695652173913043
# Shortest path:  40
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['tool', 'implement', '6.46']
#
# synsets1:  [Synset('tool.n.01'), Synset('instrument.n.02'), Synset('creature.n.03'), Synset('cock.n.01'), Synset('tool.v.01'), Synset('joyride.v.01'), Synset('tool.v.03'), Synset('tool.v.04')]
# synsets2:  [Synset('implement.n.01'), Synset('implement.v.01'), Synset('enforce.v.01'), Synset('follow_through.v.02')]
# Wu palmer:  0.9333333333333333
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['brother', 'monk', '6.27']
#
# synsets1:  [Synset('brother.n.01'), Synset('brother.n.02'), Synset('buddy.n.01'), Synset('brother.n.04'), Synset('brother.n.05')]
# synsets2:  [Synset('monk.n.01'), Synset('monk.n.02')]
# Wu palmer:  0.9523809523809523
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['crane', 'implement', '2.69']
#
# synsets1:  [Synset('crane.n.01'), Synset('crane.n.02'), Synset('grus.n.01'), Synset('crane.n.04'), Synset('crane.n.05'), Synset('crane.v.01')]
# synsets2:  [Synset('implement.n.01'), Synset('implement.v.01'), Synset('enforce.v.01'), Synset('follow_through.v.02')]
# Wu palmer:  0.75
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['lad', 'brother', '4.46']
#
# synsets1:  [Synset('chap.n.01'), Synset('cub.n.02')]
# synsets2:  [Synset('brother.n.01'), Synset('brother.n.02'), Synset('buddy.n.01'), Synset('brother.n.04'), Synset('brother.n.05')]
# Wu palmer:  0.7777777777777778
# Shortest path:  36
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['journey', 'car', '5.85']
#
# synsets1:  [Synset('journey.n.01'), Synset('travel.v.02'), Synset('travel.v.04')]
# synsets2:  [Synset('car.n.01'), Synset('car.n.02'), Synset('car.n.03'), Synset('car.n.04'), Synset('cable_car.n.01')]
# Wu palmer:  0.1
# Shortest path:  40
# Leakcock & Chodorow:  0.7985076962177716
# -------------------------------
# ['monk', 'oracle', '5.00']
#
# synsets1:  [Synset('monk.n.01'), Synset('monk.n.02')]
# synsets2:  [Synset('prophet.n.01'), Synset('oracle.n.02'), Synset('oracle.n.03')]
# Wu palmer:  0.6666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['cemetery', 'woodland', '2.08']
#
# synsets1:  [Synset('cemetery.n.01')]
# synsets2:  [Synset('forest.n.02')]
# Wu palmer:  0.4
# Shortest path:  31
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['food', 'rooster', '4.42']
#
# synsets1:  [Synset('food.n.01'), Synset('food.n.02'), Synset('food.n.03')]
# synsets2:  [Synset('cock.n.04')]
# Wu palmer:  0.21052631578947367
# Shortest path:  25
# Leakcock & Chodorow:  0.9808292530117262
# -------------------------------
# ['coast', 'hill', '4.38']
#
# synsets1:  [Synset('seashore.n.01'), Synset('coast.n.02'), Synset('coast.n.03'), Synset('slide.n.05'), Synset('coast.v.01')]
# synsets2:  [Synset('hill.n.01'), Synset('mound.n.04'), Synset('hill.n.03'), Synset('hill.n.04'), Synset('mound.n.01'), Synset('hill.v.01')]
# Wu palmer:  0.6666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['forest', 'graveyard', '1.85']
#
# synsets1:  [Synset('forest.n.01'), Synset('forest.n.02'), Synset('afforest.v.01')]
# synsets2:  [Synset('cemetery.n.01')]
# Wu palmer:  0.4
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['shore', 'woodland', '3.08']
#
# synsets1:  [Synset('shore.n.01'), Synset('shore.n.02'), Synset('shore.v.01'), Synset('land.v.06'), Synset('prop_up.v.01')]
# synsets2:  [Synset('forest.n.02')]
# Wu palmer:  0.5454545454545454
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['monk', 'slave', '0.92']
#
# synsets1:  [Synset('monk.n.01'), Synset('monk.n.02')]
# synsets2:  [Synset('slave.n.01'), Synset('slave.n.02'), Synset('slave.n.03'), Synset('slave.v.01')]
# Wu palmer:  0.7777777777777778
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['coast', 'forest', '3.15']
#
# synsets1:  [Synset('seashore.n.01'), Synset('coast.n.02'), Synset('coast.n.03'), Synset('slide.n.05'), Synset('coast.v.01')]
# synsets2:  [Synset('forest.n.01'), Synset('forest.n.02'), Synset('afforest.v.01')]
# Wu palmer:  0.5
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['lad', 'wizard', '0.92']
#
# synsets1:  [Synset('chap.n.01'), Synset('cub.n.02')]
# synsets2:  [Synset('ace.n.03'), Synset('sorcerer.n.01'), Synset('charming.s.02')]
# Wu palmer:  0.7777777777777778
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['chord', 'smile', '0.54']
#
# synsets1:  [Synset('chord.n.01'), Synset('chord.n.02'), Synset('chord.v.01'), Synset('harmonize.v.06')]
# synsets2:  [Synset('smile.n.01'), Synset('smile.v.01'), Synset('smile.v.02')]
# Wu palmer:  0.375
# Shortest path:  40
# Leakcock & Chodorow:  1.3862943611198906
# -------------------------------
# ['glass', 'magician', '2.08']
#
# synsets1:  [Synset('glass.n.01'), Synset('glass.n.02'), Synset('glass.n.03'), Synset('field_glass.n.01'), Synset('methamphetamine.n.01'), Synset('looking_glass.n.01'), Synset('glass.n.07'), Synset('glass.v.01'), Synset('glass.v.02'), Synset('glass.v.03'), Synset('glass.v.04'), Synset('glaze.v.02')]
# synsets2:  [Synset('magician.n.01'), Synset('sorcerer.n.01')]
# Wu palmer:  0.47058823529411764
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['noon', 'string', '0.54']
#
# synsets1:  [Synset('noon.n.01')]
# synsets2:  [Synset('string.n.01'), Synset('bowed_stringed_instrument.n.01'), Synset('string.n.03'), Synset('string.n.04'), Synset('string.n.05'), Synset('drawstring.n.01'), Synset('string.n.07'), Synset('string.n.08'), Synset('string.n.09'), Synset('chain.n.10'), Synset('string.v.01'), Synset('string.v.02'), Synset('string.v.03'), Synset('string.v.04'), Synset('string.v.05'), Synset('string.v.06'), Synset('string.v.07')]
# Wu palmer:  0.26666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  1.2909841813155656
# -------------------------------
# ['rooster', 'voyage', '0.62']
#
# synsets1:  [Synset('cock.n.04')]
# synsets2:  [Synset('ocean_trip.n.01'), Synset('voyage.n.02'), Synset('voyage.v.01')]
# Wu palmer:  0.08
# Shortest path:  40
# Leakcock & Chodorow:  0.5533852381847867
# -------------------------------
# ['money', 'dollar', '8.42']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('dollar.n.01'), Synset('dollar.n.02'), Synset('dollar.n.03'), Synset('dollar.n.04')]
# Wu palmer:  0.7777777777777778
# Shortest path:  36
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['money', 'cash', '9.08']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('cash.n.01'), Synset('cash.n.02'), Synset('cash.n.03'), Synset('cash.v.01')]
# Wu palmer:  0.875
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['money', 'currency', '9.04']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('currency.n.01'), Synset('currency.n.02'), Synset('currentness.n.01')]
# Wu palmer:  0.9333333333333333
# Shortest path:  39
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['money', 'wealth', '8.27']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('wealth.n.01'), Synset('wealth.n.02'), Synset('wealth.n.03'), Synset('wealth.n.04')]
# Wu palmer:  0.9230769230769231
# Shortest path:  39
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['money', 'property', '7.57']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('property.n.01'), Synset('property.n.02'), Synset('place.n.02'), Synset('property.n.04'), Synset('property.n.05')]
# Wu palmer:  0.8333333333333334
# Shortest path:  38
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['money', 'possession', '7.29']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('possession.n.01'), Synset('possession.n.02'), Synset('possession.n.03'), Synset('monomania.n.01'), Synset('possession.n.05'), Synset('self-control.n.02'), Synset('possession.n.07')]
# Wu palmer:  0.7272727272727273
# Shortest path:  37
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['money', 'bank', '8.50']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('bank.n.01'), Synset('depository_financial_institution.n.01'), Synset('bank.n.03'), Synset('bank.n.04'), Synset('bank.n.05'), Synset('bank.n.06'), Synset('bank.n.07'), Synset('savings_bank.n.02'), Synset('bank.n.09'), Synset('bank.n.10'), Synset('bank.v.01'), Synset('bank.v.02'), Synset('bank.v.03'), Synset('bank.v.04'), Synset('bank.v.05'), Synset('deposit.v.02'), Synset('bank.v.07'), Synset('trust.v.01')]
# Wu palmer:  0.5714285714285714
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['money', 'deposit', '7.73']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('deposit.n.01'), Synset('sediment.n.01'), Synset('deposition.n.01'), Synset('deposit.n.04'), Synset('down_payment.n.01'), Synset('deposit.n.06'), Synset('deposit.n.07'), Synset('depository.n.01'), Synset('deposit.n.09'), Synset('lodge.v.02'), Synset('deposit.v.02'), Synset('situate.v.02')]
# Wu palmer:  0.875
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['money', 'withdrawal', '6.88']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('withdrawal.n.01'), Synset('withdrawal.n.02'), Synset('withdrawal.n.03'), Synset('withdrawal.n.04'), Synset('withdrawal.n.05'), Synset('withdrawal.n.06'), Synset('coitus_interruptus.n.01'), Synset('secession.n.03'), Synset('withdrawal.n.09')]
# Wu palmer:  0.2857142857142857
# Shortest path:  30
# Leakcock & Chodorow:  1.3862943611198906
# -------------------------------
# ['money', 'laundering', '5.65']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('laundering.n.01'), Synset('wash.v.03'), Synset('launder.v.02')]
# Wu palmer:  0.25
# Shortest path:  40
# Leakcock & Chodorow:  1.2039728043259361
# -------------------------------
# ['money', 'operation', '3.31']
#
# synsets1:  [Synset('money.n.01'), Synset('money.n.02'), Synset('money.n.03')]
# synsets2:  [Synset('operation.n.01'), Synset('operation.n.02'), Synset('operation.n.03'), Synset('operation.n.04'), Synset('operation.n.05'), Synset('operation.n.06'), Synset('operation.n.07'), Synset('operation.n.08'), Synset('process.n.02'), Synset('mathematical_process.n.01'), Synset('operation.n.11')]
# Wu palmer:  0.3333333333333333
# Shortest path:  32
# Leakcock & Chodorow:  1.6094379124341003
# -------------------------------
# ['tiger', 'jaguar', '8.00']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('jaguar.n.01')]
# Wu palmer:  0.9333333333333333
# Shortest path:  38
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['tiger', 'feline', '8.00']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('feline.n.01'), Synset('feline.a.01')]
# Wu palmer:  0.9285714285714286
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['tiger', 'carnivore', '7.08']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('carnivore.n.01'), Synset('carnivore.n.02')]
# Wu palmer:  0.8888888888888888
# Shortest path:  37
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['tiger', 'mammal', '6.85']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('mammal.n.01')]
# Wu palmer:  0.8
# Shortest path:  35
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['tiger', 'animal', '7.00']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('animal.n.01'), Synset('animal.s.01')]
# Wu palmer:  0.8
# Shortest path:  40
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['tiger', 'organism', '4.77']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('organism.n.01'), Synset('organism.n.02')]
# Wu palmer:  0.8571428571428571
# Shortest path:  38
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['tiger', 'fauna', '5.62']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('fauna.n.01'), Synset('animal.n.01')]
# Wu palmer:  0.8
# Shortest path:  37
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['tiger', 'zoo', '5.87']
#
# synsets1:  [Synset('tiger.n.01'), Synset('tiger.n.02')]
# synsets2:  [Synset('menagerie.n.02')]
# Wu palmer:  0.5333333333333333
# Shortest path:  33
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['psychology', 'psychiatry', '8.08']
#
# synsets1:  [Synset('psychology.n.01')]
# synsets2:  [Synset('psychiatry.n.01')]
# Wu palmer:  0.7272727272727273
# Shortest path:  34
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['psychology', 'anxiety', '7.00']
#
# synsets1:  [Synset('psychology.n.01')]
# synsets2:  [Synset('anxiety.n.01'), Synset('anxiety.n.02')]
# Wu palmer:  0.25
# Shortest path:  28
# Leakcock & Chodorow:  1.2039728043259361
# -------------------------------
# ['psychology', 'fear', '6.85']
#
# synsets1:  [Synset('psychology.n.01')]
# ...
# Wu palmer:  0.13333333333333333
# Shortest path:  27
# Leakcock & Chodorow:  1.1239300966523995
# -------------------------------
# ['population', 'development', '3.75']
#
# synsets1:  [Synset('population.n.01'), Synset('population.n.02'), Synset('population.n.03'), Synset('population.n.04'), Synset('population.n.05')]
# synsets2:  [Synset('development.n.01'), Synset('development.n.02'), Synset('growth.n.01'), Synset('development.n.04'), Synset('exploitation.n.01'), Synset('development.n.06'), Synset('development.n.07'), Synset('development.n.08'), Synset('development.n.09')]
# Wu palmer:  0.7272727272727273
# Shortest path:  34
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['morality', 'importance', '3.31']
#
# synsets1:  [Synset('morality.n.01'), Synset('ethical_motive.n.01')]
# synsets2:  [Synset('importance.n.01'), Synset('importance.n.02')]
# Wu palmer:  0.6666666666666666
# Shortest path:  36
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['morality', 'marriage', '3.69']
#
# synsets1:  [Synset('morality.n.01'), Synset('ethical_motive.n.01')]
# synsets2:  [Synset('marriage.n.01'), Synset('marriage.n.02'), Synset('marriage.n.03'), Synset('marriage.n.04')]
# Wu palmer:  0.5454545454545454
# Shortest path:  35
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['Mexico', 'Brazil', '7.44']
#
# synsets1:  [Synset('mexico.n.01')]
# synsets2:  [Synset('brazil.n.01'), Synset('brazil_nut.n.02')]
# Wu palmer:  0
# Shortest path:  40
# Leakcock & Chodorow:  0
# -------------------------------
# ['gender', 'equality', '6.41']
#
# synsets1:  [Synset('gender.n.01'), Synset('sex.n.04')]
# synsets2:  [Synset('equality.n.01'), Synset('equality.n.02')]
# Wu palmer:  0.46153846153846156
# Shortest path:  33
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['change', 'attitude', '5.44']
#
# synsets1:  [Synset('change.n.01'), Synset('change.n.02'), Synset('change.n.03'), Synset('change.n.04'), Synset('change.n.05'), Synset('change.n.06'), Synset('change.n.07'), Synset('change.n.08'), Synset('change.n.09'), Synset('variety.n.06'), Synset('change.v.01'), Synset('change.v.02'), Synset('change.v.03'), Synset('switch.v.03'), Synset('change.v.05'), Synset('change.v.06'), Synset('exchange.v.01'), Synset('transfer.v.06'), Synset('deepen.v.04'), Synset('change.v.10')]
# synsets2:  [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# Wu palmer:  0.5454545454545454
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['family', 'planning', '6.25']
#
# synsets1:  [Synset('family.n.01'), Synset('family.n.02'), Synset('class.n.01'), Synset('family.n.04'), Synset('kin.n.01'), Synset('family.n.06'), Synset('syndicate.n.01'), Synset('family.n.08')]
# synsets2:  [Synset('planning.n.01'), Synset('planning.n.02'), Synset('planning.n.03'), Synset('plan.v.01'), Synset('plan.v.02'), Synset('plan.v.03'), Synset('design.v.04')]
# Wu palmer:  0.3076923076923077
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['opera', 'industry', '2.63']
#
# synsets1:  [Synset('opera.n.01'), Synset('opera.n.02'), Synset('opera.n.03')]
# synsets2:  [Synset('industry.n.01'), Synset('industry.n.02'), Synset('diligence.n.02')]
# Wu palmer:  0.26666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  1.2909841813155656
# -------------------------------
# ['sugar', 'approach', '0.88']
#
# synsets1:  [Synset('sugar.n.01'), Synset('carbohydrate.n.01'), Synset('boodle.n.01'), Synset('sugar.v.01')]
# synsets2:  [Synset('approach.n.01'), Synset('approach.n.02'), Synset('access.n.03'), Synset('approach_path.n.01'), Synset('approach.n.05'), Synset('overture.n.03'), Synset('approach.n.07'), Synset('approach.n.08'), Synset('approach.n.09'), Synset('approach.v.01'), Synset('border_on.v.01'), Synset('set_about.v.01'), Synset('approach.v.04'), Synset('approach.v.05')]
# Wu palmer:  0.26666666666666666
# Shortest path:  40
# Leakcock & Chodorow:  1.2909841813155656
# -------------------------------
# ['practice', 'institution', '3.19']
#
# synsets1:  [Synset('practice.n.01'), Synset('exercise.n.03'), Synset('practice.n.03'), Synset('practice.n.04'), Synset('practice.n.05'), Synset('practice.v.01'), Synset('drill.v.03'), Synset('rehearse.v.01'), Synset('practice.v.04'), Synset('commit.v.06')]
# synsets2:  [Synset('institution.n.01'), Synset('institution.n.02'), Synset('institution.n.03'), Synset('initiation.n.02'), Synset('mental_hospital.n.01')]
# Wu palmer:  0.8333333333333334
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['ministry', 'culture', '4.69']
#
# synsets1:  [Synset('ministry.n.01'), Synset('ministry.n.02'), Synset('ministry.n.03'), Synset('ministry.n.04')]
# synsets2:  [Synset('culture.n.01'), Synset('culture.n.02'), Synset('acculturation.n.02'), Synset('culture.n.04'), Synset('polish.n.02'), Synset('culture.n.06'), Synset('culture.n.07'), Synset('culture.v.01')]
# Wu palmer:  0.5333333333333333
# Shortest path:  40
# Leakcock & Chodorow:  1.742969305058623
# -------------------------------
# ['problem', 'challenge', '6.75']
#
# synsets1:  [Synset('problem.n.01'), Synset('problem.n.02'), Synset('trouble.n.01')]
# synsets2:  [Synset('challenge.n.01'), Synset('challenge.n.02'), Synset('challenge.n.03'), Synset('challenge.n.04'), Synset('challenge.n.05'), Synset('challenge.v.01'), Synset('challenge.v.02'), Synset('challenge.v.03'), Synset('challenge.v.04')]
# Wu palmer:  0.6153846153846154
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['size', 'prominence', '5.31']
#
# synsets1:  [Synset('size.n.01'), Synset('size.n.02'), Synset('size.n.03'), Synset('size.n.04'), Synset('size.n.05'), Synset('size.v.01'), Synset('size.v.02'), Synset('size.v.03'), Synset('size.s.01')]
# synsets2:  [Synset('prominence.n.01'), Synset('prominence.n.02'), Synset('bulge.n.01')]
# Wu palmer:  0.6153846153846154
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['country', 'citizen', '7.31']
#
# synsets1:  [Synset('state.n.04'), Synset('country.n.02'), Synset('nation.n.02'), Synset('country.n.04'), Synset('area.n.01')]
# synsets2:  [Synset('citizen.n.01')]
# Wu palmer:  0.4
# Shortest path:  31
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['planet', 'people', '5.75']
#
# synsets1:  [Synset('planet.n.01'), Synset('satellite.n.02'), Synset('planet.n.03')]
# synsets2:  [Synset('people.n.01'), Synset('citizenry.n.01'), Synset('people.n.03'), Synset('multitude.n.03'), Synset('people.v.01'), Synset('people.v.02')]
# Wu palmer:  0.18181818181818182
# Shortest path:  40
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['development', 'issue', '3.97']
#
# synsets1:  [Synset('development.n.01'), Synset('development.n.02'), Synset('growth.n.01'), Synset('development.n.04'), Synset('exploitation.n.01'), Synset('development.n.06'), Synset('development.n.07'), Synset('development.n.08'), Synset('development.n.09')]
# synsets2:  [Synset('issue.n.01'), Synset('issue.n.02'), Synset('topic.n.02'), Synset('issue.n.04'), Synset('issue.n.05'), Synset('return.n.06'), Synset('consequence.n.01'), Synset('offspring.n.01'), Synset('emergence.n.02'), Synset('exit.n.01'), Synset('issue.n.11'), Synset('publish.v.02'), Synset('issue.v.02'), Synset('issue.v.03'), Synset('issue.v.04'), Synset('write_out.v.02')]
# Wu palmer:  0.75
# Shortest path:  40
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['experience', 'music', '3.47']
#
# synsets1:  [Synset('experience.n.01'), Synset('experience.n.02'), Synset('experience.n.03'), Synset('experience.v.01'), Synset('know.v.05'), Synset('experience.v.03'), Synset('feel.v.01'), Synset('have.v.11')]
# synsets2:  [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04'), Synset('music.n.05')]
# Wu palmer:  0.6153846153846154
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['music', 'project', '3.63']
#
# synsets1:  [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04'), Synset('music.n.05')]
# synsets2:  [Synset('undertaking.n.01'), Synset('project.n.02'), Synset('project.v.01'), Synset('stick_out.v.01'), Synset('project.v.03'), Synset('project.v.04'), Synset('project.v.05'), Synset('project.v.06'), Synset('plan.v.03'), Synset('project.v.08'), Synset('visualize.v.01'), Synset('project.v.10'), Synset('project.v.11'), Synset('project.v.12')]
# Wu palmer:  0.8
# Shortest path:  40
# Leakcock & Chodorow:  2.5902671654458267
# -------------------------------
# ['glass', 'metal', '5.56']
#
# synsets1:  [Synset('glass.n.01'), Synset('glass.n.02'), Synset('glass.n.03'), Synset('field_glass.n.01'), Synset('methamphetamine.n.01'), Synset('looking_glass.n.01'), Synset('glass.n.07'), Synset('glass.v.01'), Synset('glass.v.02'), Synset('glass.v.03'), Synset('glass.v.04'), Synset('glaze.v.02')]
# synsets2:  [Synset('metallic_element.n.01'), Synset('alloy.n.01'), Synset('metal.v.01'), Synset('metallic.a.01')]
# Wu palmer:  0.5
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['aluminum', 'metal', '7.83']
#
# synsets1:  [Synset('aluminum.n.01')]
# synsets2:  [Synset('metallic_element.n.01'), Synset('alloy.n.01'), Synset('metal.v.01'), Synset('metallic.a.01')]
# Wu palmer:  0.9333333333333333
# Shortest path:  40
# Leakcock & Chodorow:  3.6888794541139363
# -------------------------------
# ['chance', 'credibility', '3.88']
#
# synsets1:  [Synset('opportunity.n.01'), Synset('luck.n.02'), Synset('chance.n.03'), Synset('probability.n.01'), Synset('prospect.n.01'), Synset('chance.v.01'), Synset('gamble.v.01'), Synset('find.v.01'), Synset('casual.s.04')]
# synsets2:  [Synset('credibility.n.01')]
# Wu palmer:  0.5
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['exhibit', 'memorabilia', '5.31']
#
# synsets1:  [Synset('exhibit.n.01'), Synset('display.n.02'), Synset('exhibit.v.01'), Synset('expose.v.03'), Synset('show.v.01'), Synset('parade.v.01')]
# synsets2:  [Synset('memorabilia.n.01')]
# Wu palmer:  0.42857142857142855
# Shortest path:  40
# Leakcock & Chodorow:  1.6094379124341003
# -------------------------------
# ['concert', 'virtuoso', '6.81']
#
# synsets1:  [Synset('concert.n.01'), Synset('concert.v.01'), Synset('concert.v.02')]
# synsets2:  [Synset('ace.n.03'), Synset('virtuoso.n.02'), Synset('consummate.s.01')]
# Wu palmer:  0.11764705882352941
# Shortest path:  40
# Leakcock & Chodorow:  0.9808292530117262
# -------------------------------
# ['rock', 'jazz', '7.59']
#
# synsets1:  [Synset('rock.n.01'), Synset('rock.n.02'), Synset('rock.n.03'), Synset('rock.n.04'), Synset('rock_candy.n.01'), Synset('rock_'n'_roll.n.01'), Synset('rock.n.07'), Synset('rock.v.01'), Synset('rock.v.02')]
# synsets2:  [Synset('wind.n.04'), Synset('jazz.n.02'), Synset('jazz.n.03'), Synset('jazz.v.01'), Synset('sleep_together.v.01')]
# Wu palmer:  0.875
# Shortest path:  40
# Leakcock & Chodorow:  2.995732273553991
# -------------------------------
# ['museum', 'theater', '7.19']
#
# synsets1:  [Synset('museum.n.01')]
# synsets2:  [Synset('theater.n.01'), Synset('dramaturgy.n.01'), Synset('field.n.11')]
# Wu palmer:  0.625
# Shortest path:  34
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['observation', 'architecture', '4.38']
#
# synsets1:  [Synset('observation.n.01'), Synset('observation.n.02'), Synset('observation.n.03'), Synset('observation.n.04'), Synset('notice.n.02')]
# synsets2:  [Synset('architecture.n.01'), Synset('architecture.n.02'), Synset('architecture.n.03'), Synset('computer_architecture.n.02')]
# Wu palmer:  0.7058823529411765
# Shortest path:  35
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['space', 'world', '6.53']
#
# synsets1:  [Synset('space.n.01'), Synset('space.n.02'), Synset('space.n.03'), Synset('outer_space.n.01'), Synset('space.n.05'), Synset('distance.n.05'), Synset('space.n.07'), Synset('space.n.08'), Synset('quad.n.03'), Synset('space.v.01')]
# synsets2:  [Synset('universe.n.01'), Synset('world.n.02'), Synset('world.n.03'), Synset('earth.n.01'), Synset('populace.n.01'), Synset('world.n.06'), Synset('worldly_concern.n.01'), Synset('world.n.08'), Synset('global.s.01')]
# Wu palmer:  0.5714285714285714
# Shortest path:  40
# Leakcock & Chodorow:  2.0794415416798357
# -------------------------------
# ['preservation', 'world', '6.19']
#
# synsets1:  [Synset('preservation.n.01'), Synset('preservation.n.02'), Synset('preservation.n.03'), Synset('conservation.n.01')]
# synsets2:  [Synset('universe.n.01'), Synset('world.n.02'), Synset('world.n.03'), Synset('earth.n.01'), Synset('populace.n.01'), Synset('world.n.06'), Synset('worldly_concern.n.01'), Synset('world.n.08'), Synset('global.s.01')]
# Wu palmer:  0.5882352941176471
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['admission', 'ticket', '7.69']
#
# synsets1:  [Synset('admission.n.01'), Synset('admission.n.02'), Synset('entrance_fee.n.01'), Synset('entree.n.02')]
# synsets2:  [Synset('ticket.n.01'), Synset('tag.n.01'), Synset('ticket.n.03'), Synset('slate.n.04'), Synset('ticket.n.05'), Synset('ticket.v.01'), Synset('ticket.v.02')]
# Wu palmer:  0.5714285714285714
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['shower', 'thunderstorm', '6.31']
#
# synsets1:  [Synset('shower.n.01'), Synset('shower.n.02'), Synset('shower.n.03'), Synset('shower.n.04'), Synset('exhibitor.n.01'), Synset('shower.n.06'), Synset('lavish.v.01'), Synset('shower.v.02'), Synset('shower.v.03'), Synset('shower.v.04'), Synset('shower.v.05')]
# synsets2:  [Synset('thunderstorm.n.01')]
# Wu palmer:  0.7
# Shortest path:  40
# Leakcock & Chodorow:  1.8971199848858813
# -------------------------------
# ['shower', 'flood', '6.03']
#
# synsets1:  [Synset('shower.n.01'), Synset('shower.n.02'), Synset('shower.n.03'), Synset('shower.n.04'), Synset('exhibitor.n.01'), Synset('shower.n.06'), Synset('lavish.v.01'), Synset('shower.v.02'), Synset('shower.v.03'), Synset('shower.v.04'), Synset('shower.v.05')]
# synsets2:  [Synset('flood.n.01'), Synset('flood.n.02'), Synset('flood.n.03'), Synset('flood.n.04'), Synset('flood.n.05'), Synset('flood_tide.n.02'), Synset('deluge.v.01'), Synset('flood.v.02'), Synset('flood.v.03'), Synset('flood.v.04')]
# Wu palmer:  0.6363636363636364
# Shortest path:  40
# Leakcock & Chodorow:  2.3025850929940455
# -------------------------------
# ['weather', 'forecast', '8.34']
#
# synsets1:  [Synset('weather.n.01'), Synset('weather.v.01'), Synset('weather.v.02'), Synset('weather.v.03'), Synset('weather.v.04'), Synset('upwind.s.01')]
# synsets2:  [Synset('prognosis.n.01'), Synset('forecast.v.01'), Synset('calculate.v.02'), Synset('bode.v.01')]
# Wu palmer:  0.13333333333333333
# Shortest path:  40
# Leakcock & Chodorow:  1.1239300966523995
# -------------------------------
# ['disaster', 'area', '6.25']
#
# synsets1:  [Synset('catastrophe.n.02'), Synset('calamity.n.01'), Synset('disaster.n.03')]
# synsets2:  [Synset('area.n.01'), Synset('area.n.02'), Synset('area.n.03'), Synset('sphere.n.01'), Synset('area.n.05'), Synset('area.n.06')]
# Wu palmer:  0.5
# Shortest path:  32
# Leakcock & Chodorow:  1.6094379124341003
# -------------------------------
# ['governor', 'office', '6.34']
#
# synsets1:  [Synset('governor.n.01'), Synset('governor.n.02')]
# synsets2:  [Synset('office.n.01'), Synset('agency.n.01'), Synset('function.n.03'), Synset('office.n.04'), Synset('office.n.05'), Synset('office.n.06'), Synset('position.n.06')]
# Wu palmer:  0.5263157894736842
# Shortest path:  31
# Leakcock & Chodorow:  1.491654876777717
# -------------------------------
# ['architecture', 'century', '3.78']
#
# synsets1:  [Synset('architecture.n.01'), Synset('architecture.n.02'), Synset('architecture.n.03'), Synset('computer_architecture.n.02')]
# synsets2:  [Synset('century.n.01'), Synset('hundred.n.01')]
# Wu palmer:  0.3076923076923077
# Shortest path:  31
# Leakcock & Chodorow:  1.491654876777717

# %%
#Indici di correlazione

print("len(wordsimres): ", len(wordsimres))
print("len(wupalmerres): ", len(wupalmerres))
print("len(pathres): ", len(pathres))
print("len(lcres): ", len(lcres))

#Pearson
print("####################################################################")
print("Pearson ")
print(pearsonr(wordsimres, wupalmerres))
print(pearsonr(wordsimres, pathres))
print(pearsonr(wordsimres, lcres))

#Spearman
print("Spearman ")
print(spearmanr(wordsimres, wupalmerres))
print(spearmanr(wordsimres, pathres))
print(spearmanr(wordsimres, lcres))
# Out:
# len(wordsimres):  352
# len(wupalmerres):  352
# len(pathres):  352
# len(lcres):  352
# ####################################################################
# Pearson
# PearsonRResult(statistic=0.26572842333653923, pvalue=4.214296990969587e-07)
# PearsonRResult(statistic=0.05102892624806722, pvalue=0.339777896217168)
# PearsonRResult(statistic=0.21697565961231546, pvalue=4.0369391220383806e-05)
# Spearman
# SpearmanrResult(correlation=0.324400489230381, pvalue=4.5457429629669424e-10)
# SpearmanrResult(correlation=-0.011465814304130732, pvalue=0.8302666223953653)
# SpearmanrResult(correlation=0.21800782093534113, pvalue=3.7014431035413466e-05)

# %% [markdown]
# ### Seconda parte
#
# Implementare l’algoritmo di Lesk (NON (!=) usare implementazione esistente, e.g., in nltk…).
# 1. Estrarre 50 frasi dal corpus SemCor (corpus annotato con i synset di
# WN) e disambiguare (almeno) un sostantivo per frase.
# Calcolare l’accuratezza del sistema implementato sulla base dei sensi annotati in
# SemCor.
#     - SemCor è disponibile all’URL http://web.eecs.umich.edu/~mihalcea/downloads.html
# 2. Randomizzare la selezione delle 50 frasi e la selezione del termine da disambiguare,
# e restituire l’accuratezza media su (per esempio) 10 esecuzioni del programma.

# %%
stop_words = get_stopwords()

def get_set_of_words(phrase: str) -> list:
    """
    Returns the set of words of a phrase.
    """
    phrase = remove_punctuation(phrase)
    set_of_words = remove_stopwords(phrase, stop_words)

    return set_of_words

def get_context_of_phrase(sentence: str) -> list:
    """
    Returns the context of a phrase.
    """
    sentence = remove_punctuation(sentence)
    set_of_words = remove_stopwords(sentence, stop_words)

    return set_of_words

def compute_overlap(signature: list, context: list) -> int:
    """
    Returns the number of words in common between signature and context
    """

    number_of_words_in_common = len(list(set(signature) & set(context)))

    return number_of_words_in_common

def get_signature(synset: Synset) -> list:
    """
    Returns the signature of synset, i.e. the set of words that are contained in the gloss and examples of synset.
    """

    gloss_of_synset = synset.definition() #gloss of synset
    examples_of_synset = synset.examples() #examples of synset
    initial_signature = [gloss_of_synset] + examples_of_synset

    signature = []
    for phrase in initial_signature:
        set_of_words = get_set_of_words(phrase)
        signature.extend(set_of_words)

    return list(set(signature)) # remove duplicates

# %%
def lesk(word: str, sentence: str) -> Synset:
    """
    Returns the best sense of given word used in sentence.
    """ 

    max_overlap = 0
    context = get_set_of_words(sentence)
    synsets = wn.synsets(word)
    print(wn.synsets(word))
    best_sense = None

    if synsets != []:
        best_sense = synsets[0]

    for synset in synsets:
        signature = get_signature(synset) 
        overlap = compute_overlap(signature, context)

        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = synset

    return best_sense

# %%
# Test
best_sense = lesk("bank", "I went to the bank to deposit money.")

best_sense_nltk = nltk.wsd.lesk("I went to the bank to deposit money.".split(), "bank")

print("best sense:")
print(best_sense) 

print("best sense nltk:", best_sense_nltk)
# Out:
# [Synset('bank.n.01'), Synset('depository_financial_institution.n.01'), Synset('bank.n.03'), Synset('bank.n.04'), Synset('bank.n.05'), Synset('bank.n.06'), Synset('bank.n.07'), Synset('savings_bank.n.02'), Synset('bank.n.09'), Synset('bank.n.10'), Synset('bank.v.01'), Synset('bank.v.02'), Synset('bank.v.03'), Synset('bank.v.04'), Synset('bank.v.05'), Synset('deposit.v.02'), Synset('bank.v.07'), Synset('trust.v.01')]
# best sense:
# Synset('depository_financial_institution.n.01')
# best sense nltk: Synset('bank.v.07')

# %% [markdown]
# #### 1. Extraction first 50 phrases and disambiguation of (at least) one name

# %%
corpus = semcor.sents()

def lemma_list(sent):
    return [l.label() for l in sent if isinstance(l, nltk.tree.Tree)]

def disambiguation(sentences: list[str], sentences_tagged: list) -> None:
    lesk_correct = 0 
    total_names = 0 

    for sentence, sentence_tagged in zip(sentences, sentences_tagged):
        
        lemmas = lemma_list(sentence_tagged)

        lemmas_length = len(lemmas)
        names_disambiguated = 0 # count to stop the search of disambiguation
        
        j = 0
        while (j < lemmas_length and names_disambiguated < 3):
            string = str(lemmas[j])
            string = string.replace("Lemma('","")
            string = string.replace("')", "") # jury.n.01.jury
            synset_string = string.rsplit('.', 1)[0] # jury.n.01
            
            parts = string.split('.')   # jury.n.01.jury --> ['jury', 'n', '01', 'jury']
            
            # Lemma('jury.n.01.jury') --> "synset".paroladeltesto
            # parts[0] = jury
            # parts[1] = n (può essere 'n', 'r', 'v', ...)
            # parts[2] = 01
            # parts[3] = jury # lemma della parola del testo che ha "taggato"

            if len(parts) == 4 and parts[1] == 'n': #and parts[3] in sentences[i]):
                total_names += 1
                names_disambiguated += 1
                lesk_synset = lesk(parts[3],sentence) 
                print("Phrase: ", sentence)
                print("Word: "+parts[3])
                print("Lesk algorithm: " + str(lesk_synset))
                print("True Synset: " + synset_string)

                
                if lesk_synset:
                    lesk_name_syn = str(lesk_synset)
                    lesk_name_syn = lesk_name_syn.replace("Synset('", "")
                    lesk_name_syn = lesk_name_syn.replace("')","")

                    if (synset_string == lesk_name_syn): # confront synset true with lesk one 
                        lesk_correct = lesk_correct + 1

            j += 1
        lemmas.clear()
        
    print("Numero di volte che lesk ha trovato la giusta definizione: " + str(lesk_correct))
    print("Numero di nomi totali da disambiguare: " + str(total_names))
        
    return lesk_correct / total_names

# %%
def first_50_phrases() -> list[list[str], list]:
    sentences = corpus[0:50]
    sentences_tagged = semcor.tagged_sents(tag="sem")[0:50]

    return sentences, sentences_tagged

sentences, sentences_tagged = first_50_phrases()
disambiguation(sentences, sentences_tagged)
# Out:
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', 'Atlanta', "'s", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('friday.n.01')]
# Phrase:  ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', 'Atlanta', "'s", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# Word: Friday
# Lesk algorithm: Synset('friday.n.01')
# True Synset: friday.n.01
# [Synset('probe.n.01'), Synset('investigation.n.02')]
# Phrase:  ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of', 'Atlanta', "'s", 'recent', 'primary', 'election', 'produced', '``', 'no', 'evidence', "''", 'that', 'any', 'irregularities', 'took', 'place', '.']
# Word: investigation
# Lesk algorithm: Synset('probe.n.01')
# True Synset: probe.n.01
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['The', 'jury', 'further', 'said', 'in', 'term', 'end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('term.n.01'), Synset('term.n.02'), Synset('condition.n.07'), Synset('term.n.04'), Synset('term.n.05'), Synset('term.n.06'), Synset('terminus.n.03'), Synset('term.v.01')]
# Phrase:  ['The', 'jury', 'further', 'said', 'in', 'term', 'end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.']
# Word: term
# Lesk algorithm: Synset('term.n.02')
# True Synset: term.n.02
# [Synset('end.n.01'), Synset('end.n.02'), Synset('end.n.03'), Synset('goal.n.01'), Synset('end.n.05'), Synset('end.n.06'), Synset('end.n.07'), Synset('end.n.08'), Synset('end.n.09'), Synset('end.n.10'), Synset('end.n.11'), Synset('conclusion.n.08'), Synset('end.n.13'), Synset('end.n.14'), Synset('end.v.01'), Synset('end.v.02'), Synset('end.v.03'), Synset('end.v.04')]
# Phrase:  ['The', 'jury', 'further', 'said', 'in', 'term', 'end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.']
# Word: end
# Lesk algorithm: Synset('end.v.01')
# True Synset: end.n.02
# [Synset('september.n.01')]
# Phrase:  ['The', 'September', 'October', 'term', 'jury', 'had', 'been', 'charged', 'by', 'Fulton', 'Superior', 'Court', 'Judge', 'Durwood', 'Pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', "''", 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.', '.']
# Word: September
# Lesk algorithm: Synset('september.n.01')
# True Synset: september.n.01
# [Synset('october.n.01')]
# Phrase:  ['The', 'September', 'October', 'term', 'jury', 'had', 'been', 'charged', 'by', 'Fulton', 'Superior', 'Court', 'Judge', 'Durwood', 'Pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', "''", 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.', '.']
# Word: October
# Lesk algorithm: Synset('october.n.01')
# True Synset: october.n.01
# [Synset('term.n.01'), Synset('term.n.02'), Synset('condition.n.07'), Synset('term.n.04'), Synset('term.n.05'), Synset('term.n.06'), Synset('terminus.n.03'), Synset('term.v.01')]
# Phrase:  ['The', 'September', 'October', 'term', 'jury', 'had', 'been', 'charged', 'by', 'Fulton', 'Superior', 'Court', 'Judge', 'Durwood', 'Pye', 'to', 'investigate', 'reports', 'of', 'possible', '``', 'irregularities', "''", 'in', 'the', 'hard-fought', 'primary', 'which', 'was', 'won', 'by', 'Mayor-nominate', 'Ivan', 'Allen', 'Jr.', '.']
# Word: term
# Lesk algorithm: Synset('term.n.02')
# True Synset: term.n.02
# [Synset('handful.n.01'), Synset('handful.n.02')]
# Phrase:  ['``', 'Only', 'a', 'relative', 'handful', 'of', 'such', 'reports', 'was', 'received', "''", ',', 'the', 'jury', 'said', ',', '``', 'considering', 'the', 'widespread', 'interest', 'in', 'the', 'election', ',', 'the', 'number', 'of', 'voters', 'and', 'the', 'size', 'of', 'this', 'city', "''", '.']
# Word: handful
# Lesk algorithm: Synset('handful.n.01')
# True Synset: handful.n.01
# [Synset('report.n.01'), Synset('report.n.02'), Synset('report.n.03'), Synset('report.n.04'), Synset('report_card.n.01'), Synset('composition.n.08'), Synset('reputation.n.03'), Synset('report.v.01'), Synset('report.v.02'), Synset('report.v.03'), Synset('report.v.04'), Synset('report.v.05'), Synset('report.v.06')]
# Phrase:  ['``', 'Only', 'a', 'relative', 'handful', 'of', 'such', 'reports', 'was', 'received', "''", ',', 'the', 'jury', 'said', ',', '``', 'considering', 'the', 'widespread', 'interest', 'in', 'the', 'election', ',', 'the', 'number', 'of', 'voters', 'and', 'the', 'size', 'of', 'this', 'city', "''", '.']
# Word: report
# Lesk algorithm: Synset('report.n.02')
# True Synset: report.n.03
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['``', 'Only', 'a', 'relative', 'handful', 'of', 'such', 'reports', 'was', 'received', "''", ',', 'the', 'jury', 'said', ',', '``', 'considering', 'the', 'widespread', 'interest', 'in', 'the', 'election', ',', 'the', 'number', 'of', 'voters', 'and', 'the', 'size', 'of', 'this', 'city', "''", '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['The', 'jury', 'said', 'it', 'did', 'find', 'that', 'many', 'of', 'Georgia', "'s", 'registration', 'and', 'election', 'laws', '``', 'are', 'outmoded', 'or', 'inadequate', 'and', 'often', 'ambiguous', "''", '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('georgia.n.01'), Synset('georgia.n.02'), Synset('georgia.n.03')]
# Phrase:  ['The', 'jury', 'said', 'it', 'did', 'find', 'that', 'many', 'of', 'Georgia', "'s", 'registration', 'and', 'election', 'laws', '``', 'are', 'outmoded', 'or', 'inadequate', 'and', 'often', 'ambiguous', "''", '.']
# Word: Georgia
# Lesk algorithm: Synset('georgia.n.01')
# True Synset: georgia.n.01
# [Synset('registration.n.01'), Synset('registration.n.02'), Synset('registration.n.03'), Synset('registration.n.04'), Synset('adjustment.n.03')]
# Phrase:  ['The', 'jury', 'said', 'it', 'did', 'find', 'that', 'many', 'of', 'Georgia', "'s", 'registration', 'and', 'election', 'laws', '``', 'are', 'outmoded', 'or', 'inadequate', 'and', 'often', 'ambiguous', "''", '.']
# Word: registration
# Lesk algorithm: Synset('registration.n.01')
# True Synset: registration.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['It', 'recommended', 'that', 'Fulton', 'legislators', 'act', '``', 'to', 'have', 'these', 'laws', 'studied', 'and', 'revised', 'to', 'the', 'end', 'of', 'modernizing', 'and', 'improving', 'them', "''", '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('legislator.n.01')]
# Phrase:  ['It', 'recommended', 'that', 'Fulton', 'legislators', 'act', '``', 'to', 'have', 'these', 'laws', 'studied', 'and', 'revised', 'to', 'the', 'end', 'of', 'modernizing', 'and', 'improving', 'them', "''", '.']
# Word: legislator
# Lesk algorithm: Synset('legislator.n.01')
# True Synset: legislator.n.01
# [Synset('law.n.01'), Synset('law.n.02'), Synset('law.n.03'), Synset('law.n.04'), Synset('jurisprudence.n.01'), Synset('law.n.06'), Synset('police.n.01')]
# Phrase:  ['It', 'recommended', 'that', 'Fulton', 'legislators', 'act', '``', 'to', 'have', 'these', 'laws', 'studied', 'and', 'revised', 'to', 'the', 'end', 'of', 'modernizing', 'and', 'improving', 'them', "''", '.']
# Word: law
# Lesk algorithm: Synset('law.n.04')
# True Synset: law.n.02
# [Synset('grand_jury.n.01')]
# Phrase:  ['The', 'grand', 'jury', 'commented', 'on', 'a', 'number', 'of', 'other', 'topics', ',', 'among', 'them', 'the', 'Atlanta', 'and', 'Fulton', 'County', 'purchasing', 'departments', 'which', 'it', 'said', '``', 'are', 'well', 'operated', 'and', 'follow', 'generally', 'accepted', 'practices', 'which', 'inure', 'to', 'the', 'best', 'interest', 'of', 'both', 'governments', "''", '.']
# Word: grand_jury
# Lesk algorithm: Synset('grand_jury.n.01')
# True Synset: grand_jury.n.01
# [Synset('number.n.01'), Synset('number.n.02'), Synset('act.n.04'), Synset('phone_number.n.01'), Synset('numeral.n.01'), Synset('issue.n.02'), Synset('number.n.07'), Synset('number.n.08'), Synset('number.n.09'), Synset('number.n.10'), Synset('number.n.11'), Synset('total.v.01'), Synset('number.v.02'), Synset('number.v.03'), Synset('count.v.05'), Synset('count.v.01'), Synset('number.v.06')]
# Phrase:  ['The', 'grand', 'jury', 'commented', 'on', 'a', 'number', 'of', 'other', 'topics', ',', 'among', 'them', 'the', 'Atlanta', 'and', 'Fulton', 'County', 'purchasing', 'departments', 'which', 'it', 'said', '``', 'are', 'well', 'operated', 'and', 'follow', 'generally', 'accepted', 'practices', 'which', 'inure', 'to', 'the', 'best', 'interest', 'of', 'both', 'governments', "''", '.']
# Word: number
# Lesk algorithm: Synset('total.v.01')
# True Synset: number.n.01
# [Synset('subject.n.01'), Synset('topic.n.02')]
# Phrase:  ['The', 'grand', 'jury', 'commented', 'on', 'a', 'number', 'of', 'other', 'topics', ',', 'among', 'them', 'the', 'Atlanta', 'and', 'Fulton', 'County', 'purchasing', 'departments', 'which', 'it', 'said', '``', 'are', 'well', 'operated', 'and', 'follow', 'generally', 'accepted', 'practices', 'which', 'inure', 'to', 'the', 'best', 'interest', 'of', 'both', 'governments', "''", '.']
# Word: topic
# Lesk algorithm: Synset('subject.n.01')
# True Synset: topic.n.02
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['However', ',', 'the', 'jury', 'said', 'it', 'believes', '``', 'these', 'two', 'offices', 'should', 'be', 'combined', 'to', 'achieve', 'greater', 'efficiency', 'and', 'reduce', 'the', 'cost', 'of', 'administration', "''", '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('office.n.01'), Synset('agency.n.01'), Synset('function.n.03'), Synset('office.n.04'), Synset('office.n.05'), Synset('office.n.06'), Synset('position.n.06')]
# Phrase:  ['However', ',', 'the', 'jury', 'said', 'it', 'believes', '``', 'these', 'two', 'offices', 'should', 'be', 'combined', 'to', 'achieve', 'greater', 'efficiency', 'and', 'reduce', 'the', 'cost', 'of', 'administration', "''", '.']
# Word: office
# Lesk algorithm: Synset('office.n.06')
# True Synset: agency.n.01
# [Synset('efficiency.n.01'), Synset('efficiency.n.02')]
# Phrase:  ['However', ',', 'the', 'jury', 'said', 'it', 'believes', '``', 'these', 'two', 'offices', 'should', 'be', 'combined', 'to', 'achieve', 'greater', 'efficiency', 'and', 'reduce', 'the', 'cost', 'of', 'administration', "''", '.']
# Word: efficiency
# Lesk algorithm: Synset('efficiency.n.02')
# True Synset: efficiency.n.02
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['The', 'City', 'Purchasing', 'Department', ',', 'the', 'jury', 'said', ',', '``', 'is', 'lacking', 'in', 'experienced', 'clerical', 'personnel', 'as', 'a', 'result', 'of', 'city', 'personnel', 'policies', "''", '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['The', 'City', 'Purchasing', 'Department', ',', 'the', 'jury', 'said', ',', '``', 'is', 'lacking', 'in', 'experienced', 'clerical', 'personnel', 'as', 'a', 'result', 'of', 'city', 'personnel', 'policies', "''", '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('force.n.04'), Synset('personnel_department.n.01')]
# Phrase:  ['The', 'City', 'Purchasing', 'Department', ',', 'the', 'jury', 'said', ',', '``', 'is', 'lacking', 'in', 'experienced', 'clerical', 'personnel', 'as', 'a', 'result', 'of', 'city', 'personnel', 'policies', "''", '.']
# Word: personnel
# Lesk algorithm: Synset('personnel_department.n.01')
# True Synset: force.n.04
# [Synset('city.n.01'), Synset('city.n.02'), Synset('city.n.03')]
# Phrase:  ['It', 'urged', 'that', 'the', 'city', '``', 'take', 'steps', 'to', 'remedy', "''", 'this', 'problem', '.']
# Word: city
# Lesk algorithm: Synset('city.n.01')
# True Synset: city.n.02
# [Synset('measure.n.01'), Synset('footstep.n.03'), Synset('step.n.03'), Synset('step.n.04'), Synset('gradation.n.01'), Synset('step.n.06'), Synset('footfall.n.01'), Synset('tone.n.09'), Synset('footprint.n.01'), Synset('step.n.10'), Synset('dance_step.n.01'), Synset('step.v.01'), Synset('step.v.02'), Synset('step.v.03'), Synset('mistreat.v.01'), Synset('step.v.05'), Synset('step.v.06'), Synset('step.v.07'), Synset('step.v.08'), Synset('pace.v.03'), Synset('step.v.10')]
# Phrase:  ['It', 'urged', 'that', 'the', 'city', '``', 'take', 'steps', 'to', 'remedy', "''", 'this', 'problem', '.']
# Word: step
# Lesk algorithm: Synset('measure.n.01')
# True Synset: measure.n.01
# [Synset('problem.n.01'), Synset('problem.n.02'), Synset('trouble.n.01')]
# Phrase:  ['It', 'urged', 'that', 'the', 'city', '``', 'take', 'steps', 'to', 'remedy', "''", 'this', 'problem', '.']
# Word: problem
# Lesk algorithm: Synset('trouble.n.01')
# True Synset: problem.n.02
# [Synset('execution.n.06'), Synset('implementation.n.02')]
# Phrase:  ['Implementation', 'of', 'Georgia', "'s", 'automobile', 'title', 'law', 'was', 'also', 'recommended', 'by', 'the', 'outgoing', 'jury', '.']
# Word: implementation
# Lesk algorithm: Synset('execution.n.06')
# True Synset: execution.n.06
# [Synset('georgia.n.01'), Synset('georgia.n.02'), Synset('georgia.n.03')]
# Phrase:  ['Implementation', 'of', 'Georgia', "'s", 'automobile', 'title', 'law', 'was', 'also', 'recommended', 'by', 'the', 'outgoing', 'jury', '.']
# Word: Georgia
# Lesk algorithm: Synset('georgia.n.01')
# True Synset: georgia.n.01
# [Synset('car.n.01'), Synset('automobile.v.01')]
# Phrase:  ['Implementation', 'of', 'Georgia', "'s", 'automobile', 'title', 'law', 'was', 'also', 'recommended', 'by', 'the', 'outgoing', 'jury', '.']
# Word: automobile
# Lesk algorithm: Synset('automobile.v.01')
# True Synset: car.n.01
# [Synset('legislature.n.01')]
# Phrase:  ['It', 'urged', 'that', 'the', 'next', 'Legislature', '``', 'provide', 'enabling', 'funds', 'and', 're-set', 'the', 'effective', 'date', 'so', 'that', 'an', 'orderly', 'implementation', 'of', 'the', 'law', 'may', 'be', 'effected', "''", '.']
# Word: legislature
# Lesk algorithm: Synset('legislature.n.01')
# True Synset: legislature.n.01
# [Synset('fund.n.01'), Synset('store.n.02'), Synset('investment_company.n.01'), Synset('fund.v.01'), Synset('fund.v.02'), Synset('fund.v.03'), Synset('fund.v.04'), Synset('fund.v.05'), Synset('fund.v.06')]
# Phrase:  ['It', 'urged', 'that', 'the', 'next', 'Legislature', '``', 'provide', 'enabling', 'funds', 'and', 're-set', 'the', 'effective', 'date', 'so', 'that', 'an', 'orderly', 'implementation', 'of', 'the', 'law', 'may', 'be', 'effected', "''", '.']
# Word: fund
# Lesk algorithm: Synset('fund.v.03')
# True Synset: fund.n.01
# [Synset('date.n.01'), Synset('date.n.02'), Synset('date.n.03'), Synset('date.n.04'), Synset('date.n.05'), Synset('date.n.06'), Synset('date.n.07'), Synset('date.n.08'), Synset('date.v.01'), Synset('date.v.02'), Synset('date.v.03'), Synset('go_steady.v.01'), Synset('date.v.05')]
# Phrase:  ['It', 'urged', 'that', 'the', 'next', 'Legislature', '``', 'provide', 'enabling', 'funds', 'and', 're-set', 'the', 'effective', 'date', 'so', 'that', 'an', 'orderly', 'implementation', 'of', 'the', 'law', 'may', 'be', 'effected', "''", '.']
# Word: date
# Lesk algorithm: Synset('date.n.07')
# True Synset: date.n.01
# [Synset('grand_jury.n.01')]
# Phrase:  ['The', 'grand', 'jury', 'took', 'a', 'swipe', 'at', 'the', 'State', 'Welfare', 'Department', "'s", 'handling', 'of', 'federal', 'funds', 'granted', 'for', 'child', 'welfare', 'services', 'in', 'foster', 'homes', '.']
# Word: grand_jury
# Lesk algorithm: Synset('grand_jury.n.01')
# True Synset: grand_jury.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['The', 'grand', 'jury', 'took', 'a', 'swipe', 'at', 'the', 'State', 'Welfare', 'Department', "'s", 'handling', 'of', 'federal', 'funds', 'granted', 'for', 'child', 'welfare', 'services', 'in', 'foster', 'homes', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('handling.n.01'), Synset('handling.n.02'), Synset('treatment.n.02'), Synset('manage.v.02'), Synset('treat.v.01'), Synset('cover.v.05'), Synset('handle.v.04'), Synset('wield.v.02'), Synset('handle.v.06')]
# Phrase:  ['The', 'grand', 'jury', 'took', 'a', 'swipe', 'at', 'the', 'State', 'Welfare', 'Department', "'s", 'handling', 'of', 'federal', 'funds', 'granted', 'for', 'child', 'welfare', 'services', 'in', 'foster', 'homes', '.']
# Word: handling
# Lesk algorithm: Synset('treatment.n.02')
# True Synset: handling.n.01
# [Synset('item.n.01'), Synset('detail.n.02'), Synset('item.n.03'), Synset('detail.n.01'), Synset('token.n.01'), Synset('item.r.01')]
# Phrase:  ['``', 'This', 'is', 'one', 'of', 'the', 'major', 'items', 'in', 'the', 'Fulton', 'County', 'general', 'assistance', 'program', "''", ',', 'the', 'jury', 'said', ',', 'but', 'the', 'State', 'Welfare', 'Department', '``', 'has', 'seen', 'fit', 'to', 'distribute', 'these', 'funds', 'through', 'the', 'welfare', 'departments', 'of', 'all', 'the', 'counties', 'in', 'the', 'state', 'with', 'the', 'exception', 'of', 'Fulton', 'County', ',', 'which', 'receives', 'none', 'of', 'this', 'money', '.']
# Word: item
# Lesk algorithm: Synset('item.n.01')
# True Synset: detail.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['``', 'This', 'is', 'one', 'of', 'the', 'major', 'items', 'in', 'the', 'Fulton', 'County', 'general', 'assistance', 'program', "''", ',', 'the', 'jury', 'said', ',', 'but', 'the', 'State', 'Welfare', 'Department', '``', 'has', 'seen', 'fit', 'to', 'distribute', 'these', 'funds', 'through', 'the', 'welfare', 'departments', 'of', 'all', 'the', 'counties', 'in', 'the', 'state', 'with', 'the', 'exception', 'of', 'Fulton', 'County', ',', 'which', 'receives', 'none', 'of', 'this', 'money', '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('aid.n.02'), Synset('aid.n.01')]
# Phrase:  ['``', 'This', 'is', 'one', 'of', 'the', 'major', 'items', 'in', 'the', 'Fulton', 'County', 'general', 'assistance', 'program', "''", ',', 'the', 'jury', 'said', ',', 'but', 'the', 'State', 'Welfare', 'Department', '``', 'has', 'seen', 'fit', 'to', 'distribute', 'these', 'funds', 'through', 'the', 'welfare', 'departments', 'of', 'all', 'the', 'counties', 'in', 'the', 'state', 'with', 'the', 'exception', 'of', 'Fulton', 'County', ',', 'which', 'receives', 'none', 'of', 'this', 'money', '.']
# Word: assistance
# Lesk algorithm: Synset('aid.n.02')
# True Synset: aid.n.02
# [Synset('juror.n.01')]
# Phrase:  ['The', 'jurors', 'said', 'they', 'realize', '``', 'a', 'proportionate', 'distribution', 'of', 'these', 'funds', 'might', 'disable', 'this', 'program', 'in', 'our', 'less', 'populous', 'counties', "''", '.']
# Word: juror
# Lesk algorithm: Synset('juror.n.01')
# True Synset: juror.n.01
# [Synset('distribution.n.01'), Synset('distribution.n.02'), Synset('distribution.n.03'), Synset('distribution.n.04')]
# Phrase:  ['The', 'jurors', 'said', 'they', 'realize', '``', 'a', 'proportionate', 'distribution', 'of', 'these', 'funds', 'might', 'disable', 'this', 'program', 'in', 'our', 'less', 'populous', 'counties', "''", '.']
# Word: distribution
# Lesk algorithm: Synset('distribution.n.02')
# True Synset: distribution.n.02
# [Synset('fund.n.01'), Synset('store.n.02'), Synset('investment_company.n.01'), Synset('fund.v.01'), Synset('fund.v.02'), Synset('fund.v.03'), Synset('fund.v.04'), Synset('fund.v.05'), Synset('fund.v.06')]
# Phrase:  ['The', 'jurors', 'said', 'they', 'realize', '``', 'a', 'proportionate', 'distribution', 'of', 'these', 'funds', 'might', 'disable', 'this', 'program', 'in', 'our', 'less', 'populous', 'counties', "''", '.']
# Word: fund
# Lesk algorithm: Synset('fund.v.06')
# True Synset: fund.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['Nevertheless', ',', '``', 'we', 'feel', 'that', 'in', 'the', 'future', 'Fulton', 'County', 'should', 'receive', 'some', 'portion', 'of', 'these', 'available', 'funds', "''", ',', 'the', 'jurors', 'said', '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('part.n.01'), Synset('part.n.02'), Synset('parcel.n.02'), Synset('share.n.01'), Synset('fortune.n.04'), Synset('dowry.n.01'), Synset('helping.n.01'), Synset('assign.v.02')]
# Phrase:  ['Nevertheless', ',', '``', 'we', 'feel', 'that', 'in', 'the', 'future', 'Fulton', 'County', 'should', 'receive', 'some', 'portion', 'of', 'these', 'available', 'funds', "''", ',', 'the', 'jurors', 'said', '.']
# Word: portion
# Lesk algorithm: Synset('part.n.01')
# True Synset: parcel.n.02
# [Synset('fund.n.01'), Synset('store.n.02'), Synset('investment_company.n.01'), Synset('fund.v.01'), Synset('fund.v.02'), Synset('fund.v.03'), Synset('fund.v.04'), Synset('fund.v.05'), Synset('fund.v.06')]
# Phrase:  ['Nevertheless', ',', '``', 'we', 'feel', 'that', 'in', 'the', 'future', 'Fulton', 'County', 'should', 'receive', 'some', 'portion', 'of', 'these', 'available', 'funds', "''", ',', 'the', 'jurors', 'said', '.']
# Word: fund
# Lesk algorithm: Synset('store.n.02')
# True Synset: fund.n.01
# [Synset('failure.n.01'), Synset('failure.n.02'), Synset('failure.n.03'), Synset('failure.n.04'), Synset('failure.n.05'), Synset('bankruptcy.n.02'), Synset('failure.n.07')]
# Phrase:  ['``', 'Failure', 'to', 'do', 'this', 'will', 'continue', 'to', 'place', 'a', 'disproportionate', 'burden', "''", 'on', 'Fulton', 'taxpayers', '.']
# Word: failure
# Lesk algorithm: Synset('failure.n.01')
# True Synset: failure.n.01
# [Synset('burden.n.01'), Synset('load.n.01'), Synset('effect.n.04'), Synset('burden.n.04'), Synset('burden.v.01'), Synset('charge.v.18')]
# Phrase:  ['``', 'Failure', 'to', 'do', 'this', 'will', 'continue', 'to', 'place', 'a', 'disproportionate', 'burden', "''", 'on', 'Fulton', 'taxpayers', '.']
# Word: burden
# Lesk algorithm: Synset('burden.n.01')
# True Synset: burden.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['``', 'Failure', 'to', 'do', 'this', 'will', 'continue', 'to', 'place', 'a', 'disproportionate', 'burden', "''", 'on', 'Fulton', 'taxpayers', '.']
# Word: location
# Lesk algorithm: Synset('placement.n.03')
# True Synset: location.n.01
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['The', 'jury', 'also', 'commented', 'on', 'the', 'Fulton', 'ordinary', "'s", 'court', 'which', 'has', 'been', 'under', 'fire', 'for', 'its', 'practices', 'in', 'the', 'appointment', 'of', 'appraisers', ',', 'guardians', 'and', 'administrators', 'and', 'the', 'awarding', 'of', 'fees', 'and', 'compensation', '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['The', 'jury', 'also', 'commented', 'on', 'the', 'Fulton', 'ordinary', "'s", 'court', 'which', 'has', 'been', 'under', 'fire', 'for', 'its', 'practices', 'in', 'the', 'appointment', 'of', 'appraisers', ',', 'guardians', 'and', 'administrators', 'and', 'the', 'awarding', 'of', 'fees', 'and', 'compensation', '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('ordinary.n.01'), Synset('ordinary.n.02'), Synset('ordinary.n.03'), Synset('ordinary.n.04'), Synset('ordinary.n.05'), Synset('ordinary.a.01'), Synset('average.s.02')]
# Phrase:  ['The', 'jury', 'also', 'commented', 'on', 'the', 'Fulton', 'ordinary', "'s", 'court', 'which', 'has', 'been', 'under', 'fire', 'for', 'its', 'practices', 'in', 'the', 'appointment', 'of', 'appraisers', ',', 'guardians', 'and', 'administrators', 'and', 'the', 'awarding', 'of', 'fees', 'and', 'compensation', '.']
# Word: ordinary
# Lesk algorithm: Synset('ordinary.n.01')
# True Synset: ordinary.n.02
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['The', 'jury', 'said', 'it', 'found', 'the', 'court', '``', 'has', 'incorporated', 'into', 'its', 'operating', 'procedures', 'the', 'recommendations', "''", 'of', 'two', 'previous', 'grand', 'juries', ',', 'the', 'Atlanta', 'Bar', 'Association', 'and', 'an', 'interim', 'citizens', 'committee', '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11'), Synset('woo.v.02'), Synset('woo.v.01'), Synset('court.v.03')]
# Phrase:  ['The', 'jury', 'said', 'it', 'found', 'the', 'court', '``', 'has', 'incorporated', 'into', 'its', 'operating', 'procedures', 'the', 'recommendations', "''", 'of', 'two', 'previous', 'grand', 'juries', ',', 'the', 'Atlanta', 'Bar', 'Association', 'and', 'an', 'interim', 'citizens', 'committee', '.']
# Word: court
# Lesk algorithm: Synset('court.n.04')
# True Synset: court.n.01
# [Synset('operating_procedure.n.01')]
# Phrase:  ['The', 'jury', 'said', 'it', 'found', 'the', 'court', '``', 'has', 'incorporated', 'into', 'its', 'operating', 'procedures', 'the', 'recommendations', "''", 'of', 'two', 'previous', 'grand', 'juries', ',', 'the', 'Atlanta', 'Bar', 'Association', 'and', 'an', 'interim', 'citizens', 'committee', '.']
# Word: operating_procedure
# Lesk algorithm: Synset('operating_procedure.n.01')
# True Synset: operating_procedure.n.01
# [Synset('action.n.01'), Synset('action.n.02'), Synset('military_action.n.01'), Synset('natural_process.n.01'), Synset('action.n.05'), Synset('action.n.06'), Synset('action.n.07'), Synset('legal_action.n.01'), Synset('action.n.09'), Synset('action.n.10'), Synset('action.v.01'), Synset('carry_through.v.01')]
# Phrase:  ['``', 'These', 'actions', 'should', 'serve', 'to', 'protect', 'in', 'fact', 'and', 'in', 'effect', 'the', 'court', "'s", 'wards', 'from', 'undue', 'costs', 'and', 'its', 'appointed', 'and', 'elected', 'servants', 'from', 'unmeritorious', 'criticisms', "''", ',', 'the', 'jury', 'said', '.']
# Word: action
# Lesk algorithm: Synset('action.n.01')
# True Synset: action.n.01
# [Synset('court.n.01'), Synset('court.n.02'), Synset('court.n.03'), Synset('court.n.04'), Synset('court.n.05'), Synset('court.n.06'), Synset('motor_hotel.n.01'), Synset('court.n.08'), Synset('court.n.09'), Synset('court.n.10'), Synset('court.n.11'), Synset('woo.v.02'), Synset('woo.v.01'), Synset('court.v.03')]
# Phrase:  ['``', 'These', 'actions', 'should', 'serve', 'to', 'protect', 'in', 'fact', 'and', 'in', 'effect', 'the', 'court', "'s", 'wards', 'from', 'undue', 'costs', 'and', 'its', 'appointed', 'and', 'elected', 'servants', 'from', 'unmeritorious', 'criticisms', "''", ',', 'the', 'jury', 'said', '.']
# Word: court
# Lesk algorithm: Synset('court.n.04')
# True Synset: court.n.01
# [Synset('ward.n.01'), Synset('ward.n.02'), Synset('ward.n.03'), Synset('ward.n.04'), Synset('ward.n.05'), Synset('ward.n.06'), Synset('cellblock.n.01'), Synset('guard.v.02')]
# Phrase:  ['``', 'These', 'actions', 'should', 'serve', 'to', 'protect', 'in', 'fact', 'and', 'in', 'effect', 'the', 'court', "'s", 'wards', 'from', 'undue', 'costs', 'and', 'its', 'appointed', 'and', 'elected', 'servants', 'from', 'unmeritorious', 'criticisms', "''", ',', 'the', 'jury', 'said', '.']
# Word: ward
# Lesk algorithm: Synset('guard.v.02')
# True Synset: ward.n.01
# [Synset('atlanta.n.01'), Synset('atlanta.n.02')]
# Phrase:  ['Regarding', 'Atlanta', "'s", 'new', 'million', 'dollar', 'airport', ',', 'the', 'jury', 'recommended', '``', 'that', 'when', 'the', 'new', 'management', 'takes', 'charge', 'Jan.', '1', 'the', 'airport', 'be', 'operated', 'in', 'a', 'manner', 'that', 'will', 'eliminate', 'political', 'influences', "''", '.']
# Word: Atlanta
# Lesk algorithm: Synset('atlanta.n.01')
# True Synset: atlanta.n.01
# [Synset('dollar.n.01'), Synset('dollar.n.02'), Synset('dollar.n.03'), Synset('dollar.n.04')]
# Phrase:  ['Regarding', 'Atlanta', "'s", 'new', 'million', 'dollar', 'airport', ',', 'the', 'jury', 'recommended', '``', 'that', 'when', 'the', 'new', 'management', 'takes', 'charge', 'Jan.', '1', 'the', 'airport', 'be', 'operated', 'in', 'a', 'manner', 'that', 'will', 'eliminate', 'political', 'influences', "''", '.']
# Word: dollar
# Lesk algorithm: Synset('dollar.n.02')
# True Synset: dollar.n.01
# [Synset('airport.n.01')]
# Phrase:  ['Regarding', 'Atlanta', "'s", 'new', 'million', 'dollar', 'airport', ',', 'the', 'jury', 'recommended', '``', 'that', 'when', 'the', 'new', 'management', 'takes', 'charge', 'Jan.', '1', 'the', 'airport', 'be', 'operated', 'in', 'a', 'manner', 'that', 'will', 'eliminate', 'political', 'influences', "''", '.']
# Word: airport
# Lesk algorithm: Synset('airport.n.01')
# True Synset: airport.n.01
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['The', 'jury', 'did', 'not', 'elaborate', ',', 'but', 'it', 'added', 'that', '``', 'there', 'should', 'be', 'periodic', 'surveillance', 'of', 'the', 'pricing', 'practices', 'of', 'the', 'concessionaires', 'for', 'the', 'purpose', 'of', 'keeping', 'the', 'prices', 'reasonable', "''", '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('surveillance.n.01')]
# Phrase:  ['The', 'jury', 'did', 'not', 'elaborate', ',', 'but', 'it', 'added', 'that', '``', 'there', 'should', 'be', 'periodic', 'surveillance', 'of', 'the', 'pricing', 'practices', 'of', 'the', 'concessionaires', 'for', 'the', 'purpose', 'of', 'keeping', 'the', 'prices', 'reasonable', "''", '.']
# Word: surveillance
# Lesk algorithm: Synset('surveillance.n.01')
# True Synset: surveillance.n.01
# [Synset('pricing.n.01'), Synset('price.v.01'), Synset('price.v.02')]
# Phrase:  ['The', 'jury', 'did', 'not', 'elaborate', ',', 'but', 'it', 'added', 'that', '``', 'there', 'should', 'be', 'periodic', 'surveillance', 'of', 'the', 'pricing', 'practices', 'of', 'the', 'concessionaires', 'for', 'the', 'purpose', 'of', 'keeping', 'the', 'prices', 'reasonable', "''", '.']
# Word: pricing
# Lesk algorithm: Synset('price.v.01')
# True Synset: pricing.n.01
# [Synset('matter.n.01'), Synset('topic.n.02'), Synset('matter.n.03'), Synset('matter.n.04'), Synset('matter.n.05'), Synset('matter.n.06'), Synset('count.v.02')]
# Phrase:  ['On', 'other', 'matters', ',', 'the', 'jury', 'recommended', 'that', ':']
# Word: matter
# Lesk algorithm: Synset('matter.n.01')
# True Synset: topic.n.02
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['On', 'other', 'matters', ',', 'the', 'jury', 'recommended', 'that', ':']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('deputy.n.01'), Synset('deputy.n.02'), Synset('deputy.n.03'), Synset('deputy.n.04')]
# Phrase:  ['Four', 'additional', 'deputies', 'be', 'employed', 'at', 'the', 'Fulton', 'County', 'Jail', 'and', '``', 'a', 'doctor', ',', 'medical', 'intern', 'or', 'extern', 'be', 'employed', 'for', 'night', 'and', 'weekend', 'duty', 'at', 'the', 'jail', "''", '.']
# Word: deputy
# Lesk algorithm: Synset('deputy.n.01')
# True Synset: deputy.n.02
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['Four', 'additional', 'deputies', 'be', 'employed', 'at', 'the', 'Fulton', 'County', 'Jail', 'and', '``', 'a', 'doctor', ',', 'medical', 'intern', 'or', 'extern', 'be', 'employed', 'for', 'night', 'and', 'weekend', 'duty', 'at', 'the', 'jail', "''", '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('doctor.n.01'), Synset('doctor_of_the_church.n.01'), Synset('doctor.n.03'), Synset('doctor.n.04'), Synset('sophisticate.v.03'), Synset('doctor.v.02'), Synset('repair.v.01')]
# Phrase:  ['Four', 'additional', 'deputies', 'be', 'employed', 'at', 'the', 'Fulton', 'County', 'Jail', 'and', '``', 'a', 'doctor', ',', 'medical', 'intern', 'or', 'extern', 'be', 'employed', 'for', 'night', 'and', 'weekend', 'duty', 'at', 'the', 'jail', "''", '.']
# Word: doctor
# Lesk algorithm: Synset('doctor.n.01')
# True Synset: doctor.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['Fulton', 'legislators', '``', 'work', 'with', 'city', 'officials', 'to', 'pass', 'enabling', 'legislation', 'that', 'will', 'permit', 'the', 'establishment', 'of', 'a', 'fair', 'and', 'equitable', "''", 'pension', 'plan', 'for', 'city', 'employes', '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('legislator.n.01')]
# Phrase:  ['Fulton', 'legislators', '``', 'work', 'with', 'city', 'officials', 'to', 'pass', 'enabling', 'legislation', 'that', 'will', 'permit', 'the', 'establishment', 'of', 'a', 'fair', 'and', 'equitable', "''", 'pension', 'plan', 'for', 'city', 'employes', '.']
# Word: legislator
# Lesk algorithm: Synset('legislator.n.01')
# True Synset: legislator.n.01
# [Synset('city.n.01'), Synset('city.n.02'), Synset('city.n.03')]
# Phrase:  ['Fulton', 'legislators', '``', 'work', 'with', 'city', 'officials', 'to', 'pass', 'enabling', 'legislation', 'that', 'will', 'permit', 'the', 'establishment', 'of', 'a', 'fair', 'and', 'equitable', "''", 'pension', 'plan', 'for', 'city', 'employes', '.']
# Word: city
# Lesk algorithm: Synset('city.n.01')
# True Synset: city.n.02
# [Synset('jury.n.01'), Synset('jury.n.02')]
# Phrase:  ['The', 'jury', 'praised', 'the', 'administration', 'and', 'operation', 'of', 'the', 'Atlanta', 'Police', 'Department', ',', 'the', 'Fulton', 'Tax', 'Commissioner', "'s", 'Office', ',', 'the', 'Bellwood', 'and', 'Alpharetta', 'prison', 'farms', ',', 'Grady', 'Hospital', 'and', 'the', 'Fulton', 'Health', 'Department', '.']
# Word: jury
# Lesk algorithm: Synset('jury.n.01')
# True Synset: jury.n.01
# [Synset('administration.n.01'), Synset('administration.n.02'), Synset('administration.n.03'), Synset('presidency.n.01'), Synset('government.n.02'), Synset('administration.n.06')]
# Phrase:  ['The', 'jury', 'praised', 'the', 'administration', 'and', 'operation', 'of', 'the', 'Atlanta', 'Police', 'Department', ',', 'the', 'Fulton', 'Tax', 'Commissioner', "'s", 'Office', ',', 'the', 'Bellwood', 'and', 'Alpharetta', 'prison', 'farms', ',', 'Grady', 'Hospital', 'and', 'the', 'Fulton', 'Health', 'Department', '.']
# Word: administration
# Lesk algorithm: Synset('administration.n.02')
# True Synset: administration.n.01
# [Synset('operation.n.01'), Synset('operation.n.02'), Synset('operation.n.03'), Synset('operation.n.04'), Synset('operation.n.05'), Synset('operation.n.06'), Synset('operation.n.07'), Synset('operation.n.08'), Synset('process.n.02'), Synset('mathematical_process.n.01'), Synset('operation.n.11')]
# Phrase:  ['The', 'jury', 'praised', 'the', 'administration', 'and', 'operation', 'of', 'the', 'Atlanta', 'Police', 'Department', ',', 'the', 'Fulton', 'Tax', 'Commissioner', "'s", 'Office', ',', 'the', 'Bellwood', 'and', 'Alpharetta', 'prison', 'farms', ',', 'Grady', 'Hospital', 'and', 'the', 'Fulton', 'Health', 'Department', '.']
# Word: operation
# Lesk algorithm: Synset('operation.n.01')
# True Synset: operation.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Mayor', 'William', 'B.', 'Hartsfield', 'filed', 'suit', 'for', 'divorce', 'from', 'his', 'wife', ',', 'Pearl', 'Williams', 'Hartsfield', ',', 'in', 'Fulton', 'Superior', 'Court', 'Friday', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('suit.n.01'), Synset('lawsuit.n.01'), Synset('suit.n.03'), Synset('courtship.n.01'), Synset('suit.n.05'), Synset('suit.n.06'), Synset('suit.v.01'), Synset('suit.v.02'), Synset('befit.v.01'), Synset('become.v.04')]
# Phrase:  ['Mayor', 'William', 'B.', 'Hartsfield', 'filed', 'suit', 'for', 'divorce', 'from', 'his', 'wife', ',', 'Pearl', 'Williams', 'Hartsfield', ',', 'in', 'Fulton', 'Superior', 'Court', 'Friday', '.']
# Word: suit
# Lesk algorithm: Synset('suit.n.01')
# True Synset: lawsuit.n.01
# [Synset('divorce.n.01'), Synset('disassociate.v.01'), Synset('divorce.v.02')]
# Phrase:  ['Mayor', 'William', 'B.', 'Hartsfield', 'filed', 'suit', 'for', 'divorce', 'from', 'his', 'wife', ',', 'Pearl', 'Williams', 'Hartsfield', ',', 'in', 'Fulton', 'Superior', 'Court', 'Friday', '.']
# Word: divorce
# Lesk algorithm: Synset('divorce.v.02')
# True Synset: divorce.n.01
# [Synset('request.n.01'), Synset('prayer.n.02'), Synset('petition.v.01')]
# Phrase:  ['His', 'petition', 'charged', 'mental', 'cruelty', '.']
# Word: petition
# Lesk algorithm: Synset('prayer.n.02')
# True Synset: request.n.01
# [Synset('cruelty.n.01'), Synset('cruelty.n.02'), Synset('cruelty.n.03')]
# Phrase:  ['His', 'petition', 'charged', 'mental', 'cruelty', '.']
# Word: cruelty
# Lesk algorithm: Synset('cruelty.n.01')
# True Synset: cruelty.n.02
# [Synset('couple.n.01'), Synset('couple.n.02'), Synset('couple.n.03'), Synset('couple.n.04'), Synset('couple.n.05'), Synset('match.v.03'), Synset('couple.v.02'), Synset('pair.v.01'), Synset('copulate.v.01')]
# Phrase:  ['The', 'couple', 'was', 'married', 'Aug.', '2', ',', '1913', '.']
# Word: couple
# Lesk algorithm: Synset('couple.n.02')
# True Synset: couple.n.02
# [Synset('august.n.01')]
# Phrase:  ['The', 'couple', 'was', 'married', 'Aug.', '2', ',', '1913', '.']
# Word: Aug
# Lesk algorithm: Synset('august.n.01')
# True Synset: august.n.01
# [Synset('son.n.01'), Synset('son.n.02')]
# Phrase:  ['They', 'have', 'a', 'son', ',', 'William', 'Berry', 'Jr.', ',', 'and', 'a', 'daughter', ',', 'Mrs.', 'J.', 'M.', 'Cheshire', 'of', 'Griffin', '.']
# Word: son
# Lesk algorithm: Synset('son.n.01')
# True Synset: son.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['They', 'have', 'a', 'son', ',', 'William', 'Berry', 'Jr.', ',', 'and', 'a', 'daughter', ',', 'Mrs.', 'J.', 'M.', 'Cheshire', 'of', 'Griffin', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('daughter.n.01')]
# Phrase:  ['They', 'have', 'a', 'son', ',', 'William', 'Berry', 'Jr.', ',', 'and', 'a', 'daughter', ',', 'Mrs.', 'J.', 'M.', 'Cheshire', 'of', 'Griffin', '.']
# Word: daughter
# Lesk algorithm: Synset('daughter.n.01')
# True Synset: daughter.n.01
# [Synset('lawyer.n.01')]
# Phrase:  ['Attorneys', 'for', 'the', 'mayor', 'said', 'that', 'an', 'amicable', 'property', 'settlement', 'has', 'been', 'agreed', 'upon', '.']
# Word: attorney
# Lesk algorithm: Synset('lawyer.n.01')
# True Synset: lawyer.n.01
# [Synset('mayor.n.01')]
# Phrase:  ['Attorneys', 'for', 'the', 'mayor', 'said', 'that', 'an', 'amicable', 'property', 'settlement', 'has', 'been', 'agreed', 'upon', '.']
# Word: mayor
# Lesk algorithm: Synset('mayor.n.01')
# True Synset: mayor.n.01
# [Synset('property_settlement.n.01')]
# Phrase:  ['Attorneys', 'for', 'the', 'mayor', 'said', 'that', 'an', 'amicable', 'property', 'settlement', 'has', 'been', 'agreed', 'upon', '.']
# Word: property_settlement
# Lesk algorithm: Synset('property_settlement.n.01')
# True Synset: property_settlement.n.01
# [Synset('request.n.01'), Synset('prayer.n.02'), Synset('petition.v.01')]
# Phrase:  ['The', 'petition', 'listed', 'the', 'mayor', "'s", 'occupation', 'as', '``', 'attorney', "''", 'and', 'his', 'age', 'as', '71', '.']
# Word: petition
# Lesk algorithm: Synset('prayer.n.02')
# True Synset: request.n.01
# [Synset('mayor.n.01')]
# Phrase:  ['The', 'petition', 'listed', 'the', 'mayor', "'s", 'occupation', 'as', '``', 'attorney', "''", 'and', 'his', 'age', 'as', '71', '.']
# Word: mayor
# Lesk algorithm: Synset('mayor.n.01')
# True Synset: mayor.n.01
# [Synset('occupation.n.01'), Synset('occupation.n.02'), Synset('occupation.n.03'), Synset('occupation.n.04'), Synset('occupation.n.05')]
# Phrase:  ['The', 'petition', 'listed', 'the', 'mayor', "'s", 'occupation', 'as', '``', 'attorney', "''", 'and', 'his', 'age', 'as', '71', '.']
# Word: occupation
# Lesk algorithm: Synset('occupation.n.03')
# True Synset: occupation.n.01
# [Synset('wife.n.01')]
# Phrase:  ['It', 'listed', 'his', 'wife', "'s", 'age', 'as', '74', 'and', 'place', 'of', 'birth', 'as', 'Opelika', ',', 'Ala.', '.']
# Word: wife
# Lesk algorithm: Synset('wife.n.01')
# True Synset: wife.n.01
# [Synset('age.n.01'), Synset('historic_period.n.01'), Synset('age.n.03'), Synset('long_time.n.01'), Synset('old_age.n.01'), Synset('age.v.01'), Synset('senesce.v.01'), Synset('age.v.03')]
# Phrase:  ['It', 'listed', 'his', 'wife', "'s", 'age', 'as', '74', 'and', 'place', 'of', 'birth', 'as', 'Opelika', ',', 'Ala.', '.']
# Word: age
# Lesk algorithm: Synset('age.v.01')
# True Synset: age.n.01
# [Synset('birthplace.n.01')]
# Phrase:  ['It', 'listed', 'his', 'wife', "'s", 'age', 'as', '74', 'and', 'place', 'of', 'birth', 'as', 'Opelika', ',', 'Ala.', '.']
# Word: place_of_birth
# Lesk algorithm: Synset('birthplace.n.01')
# True Synset: birthplace.n.01
# [Synset('request.n.01'), Synset('prayer.n.02'), Synset('petition.v.01')]
# Phrase:  ['The', 'petition', 'said', 'that', 'the', 'couple', 'has', 'not', 'lived', 'together', 'as', 'man', 'and', 'wife', 'for', 'more', 'than', 'a', 'year', '.']
# Word: petition
# Lesk algorithm: Synset('prayer.n.02')
# True Synset: request.n.01
# [Synset('couple.n.01'), Synset('couple.n.02'), Synset('couple.n.03'), Synset('couple.n.04'), Synset('couple.n.05'), Synset('match.v.03'), Synset('couple.v.02'), Synset('pair.v.01'), Synset('copulate.v.01')]
# Phrase:  ['The', 'petition', 'said', 'that', 'the', 'couple', 'has', 'not', 'lived', 'together', 'as', 'man', 'and', 'wife', 'for', 'more', 'than', 'a', 'year', '.']
# Word: couple
# Lesk algorithm: Synset('match.v.03')
# True Synset: couple.n.02
# [Synset('marriage.n.02')]
# Phrase:  ['The', 'petition', 'said', 'that', 'the', 'couple', 'has', 'not', 'lived', 'together', 'as', 'man', 'and', 'wife', 'for', 'more', 'than', 'a', 'year', '.']
# Word: man_and_wife
# Lesk algorithm: Synset('marriage.n.02')
# True Synset: marriage.n.02
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['The', 'Hartsfield', 'home', 'is', 'at', '637', 'E.', 'Pelham', 'Rd.', 'NE', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('home.n.01'), Synset('dwelling.n.01'), Synset('home.n.03'), Synset('home_plate.n.01'), Synset('base.n.14'), Synset('home.n.06'), Synset('home.n.07'), Synset('family.n.01'), Synset('home.n.09'), Synset('home.v.01'), Synset('home.v.02'), Synset('home.a.01'), Synset('home.a.02'), Synset('home.s.03'), Synset('home.r.01'), Synset('home.r.02'), Synset('home.r.03')]
# Phrase:  ['The', 'Hartsfield', 'home', 'is', 'at', '637', 'E.', 'Pelham', 'Rd.', 'NE', '.']
# Word: home
# Lesk algorithm: Synset('home.n.01')
# True Synset: dwelling.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['The', 'Hartsfield', 'home', 'is', 'at', '637', 'E.', 'Pelham', 'Rd.', 'NE', '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Henry', 'L.', 'Bowden', 'was', 'listed', 'on', 'the', 'petition', 'as', 'the', 'mayor', "'s", 'attorney', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('request.n.01'), Synset('prayer.n.02'), Synset('petition.v.01')]
# Phrase:  ['Henry', 'L.', 'Bowden', 'was', 'listed', 'on', 'the', 'petition', 'as', 'the', 'mayor', "'s", 'attorney', '.']
# Word: petition
# Lesk algorithm: Synset('prayer.n.02')
# True Synset: request.n.01
# [Synset('mayor.n.01')]
# Phrase:  ['Henry', 'L.', 'Bowden', 'was', 'listed', 'on', 'the', 'petition', 'as', 'the', 'mayor', "'s", 'attorney', '.']
# Word: mayor
# Lesk algorithm: Synset('mayor.n.01')
# True Synset: mayor.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Hartsfield', 'has', 'been', 'mayor', 'of', 'Atlanta', ',', 'with', 'exception', 'of', 'one', 'brief', 'interlude', ',', 'since', '1937', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('mayor.n.01')]
# Phrase:  ['Hartsfield', 'has', 'been', 'mayor', 'of', 'Atlanta', ',', 'with', 'exception', 'of', 'one', 'brief', 'interlude', ',', 'since', '1937', '.']
# Word: mayor
# Lesk algorithm: Synset('mayor.n.01')
# True Synset: mayor.n.01
# [Synset('atlanta.n.01'), Synset('atlanta.n.02')]
# Phrase:  ['Hartsfield', 'has', 'been', 'mayor', 'of', 'Atlanta', ',', 'with', 'exception', 'of', 'one', 'brief', 'interlude', ',', 'since', '1937', '.']
# Word: Atlanta
# Lesk algorithm: Synset('atlanta.n.01')
# True Synset: atlanta.n.01
# [Synset('career.n.01'), Synset('career.n.02'), Synset('career.v.01')]
# Phrase:  ['His', 'political', 'career', 'goes', 'back', 'to', 'his', 'election', 'to', 'city', 'council', 'in', '1923', '.']
# Word: career
# Lesk algorithm: Synset('career.n.02')
# True Synset: career.n.01
# [Synset('election.n.01'), Synset('election.n.02'), Synset('election.n.03'), Synset('election.n.04')]
# Phrase:  ['His', 'political', 'career', 'goes', 'back', 'to', 'his', 'election', 'to', 'city', 'council', 'in', '1923', '.']
# Word: election
# Lesk algorithm: Synset('election.n.01')
# True Synset: election.n.01
# [Synset('city_council.n.01')]
# Phrase:  ['His', 'political', 'career', 'goes', 'back', 'to', 'his', 'election', 'to', 'city', 'council', 'in', '1923', '.']
# Word: city_council
# Lesk algorithm: Synset('city_council.n.01')
# True Synset: city_council.n.01
# [Synset('mayor.n.01')]
# Phrase:  ['The', 'mayor', "'s", 'present', 'term', 'of', 'office', 'expires', 'Jan.', '1', '.']
# Word: mayor
# Lesk algorithm: Synset('mayor.n.01')
# True Synset: mayor.n.01
# [Synset('tenure.n.01')]
# Phrase:  ['The', 'mayor', "'s", 'present', 'term', 'of', 'office', 'expires', 'Jan.', '1', '.']
# Word: term_of_office
# Lesk algorithm: Synset('tenure.n.01')
# True Synset: tenure.n.01
# [Synset('january.n.01')]
# Phrase:  ['The', 'mayor', "'s", 'present', 'term', 'of', 'office', 'expires', 'Jan.', '1', '.']
# Word: Jan
# Lesk algorithm: Synset('january.n.01')
# True Synset: january.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['He', 'will', 'be', 'succeeded', 'by', 'Ivan', 'Allen', 'Jr.', ',', 'who', 'became', 'a', 'candidate', 'in', 'the', 'Sept.', '13', 'primary', 'after', 'Mayor', 'Hartsfield', 'announced', 'that', 'he', 'would', 'not', 'run', 'for', 'reelection', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('campaigner.n.01'), Synset('candidate.n.02')]
# Phrase:  ['He', 'will', 'be', 'succeeded', 'by', 'Ivan', 'Allen', 'Jr.', ',', 'who', 'became', 'a', 'candidate', 'in', 'the', 'Sept.', '13', 'primary', 'after', 'Mayor', 'Hartsfield', 'announced', 'that', 'he', 'would', 'not', 'run', 'for', 'reelection', '.']
# Word: candidate
# Lesk algorithm: Synset('campaigner.n.01')
# True Synset: campaigner.n.01
# [Synset('september.n.01'), Synset('family.n.04')]
# Phrase:  ['He', 'will', 'be', 'succeeded', 'by', 'Ivan', 'Allen', 'Jr.', ',', 'who', 'became', 'a', 'candidate', 'in', 'the', 'Sept.', '13', 'primary', 'after', 'Mayor', 'Hartsfield', 'announced', 'that', 'he', 'would', 'not', 'run', 'for', 'reelection', '.']
# Word: Sept
# Lesk algorithm: Synset('september.n.01')
# True Synset: september.n.01
# [Synset('georgia.n.01'), Synset('georgia.n.02'), Synset('georgia.n.03')]
# Phrase:  ['Georgia', 'Republicans', 'are', 'getting', 'strong', 'encouragement', 'to', 'enter', 'a', 'candidate', 'in', 'the', '1962', 'governor', "'s", 'race', ',', 'a', 'top', 'official', 'said', 'Wednesday', '.']
# Word: Georgia
# Lesk algorithm: Synset('georgia.n.01')
# True Synset: georgia.n.01
# [Synset('republican.n.01'), Synset('republican.n.02'), Synset('republican.n.03'), Synset('republican.a.01'), Synset('republican.s.02')]
# Phrase:  ['Georgia', 'Republicans', 'are', 'getting', 'strong', 'encouragement', 'to', 'enter', 'a', 'candidate', 'in', 'the', '1962', 'governor', "'s", 'race', ',', 'a', 'top', 'official', 'said', 'Wednesday', '.']
# Word: Republican
# Lesk algorithm: Synset('republican.n.01')
# True Synset: republican.n.01
# [Synset('encouragement.n.01'), Synset('boost.n.01'), Synset('encouragement.n.03')]
# Phrase:  ['Georgia', 'Republicans', 'are', 'getting', 'strong', 'encouragement', 'to', 'enter', 'a', 'candidate', 'in', 'the', '1962', 'governor', "'s", 'race', ',', 'a', 'top', 'official', 'said', 'Wednesday', '.']
# Word: encouragement
# Lesk algorithm: Synset('encouragement.n.01')
# True Synset: boost.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Robert', 'Snodgrass', ',', 'state', 'GOP', 'chairman', ',', 'said', 'a', 'meeting', 'held', 'Tuesday', 'night', 'in', 'Blue', 'Ridge', 'brought', 'enthusiastic', 'responses', 'from', 'the', 'audience', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('state.n.01'), Synset('state.n.02'), Synset('state.n.03'), Synset('state.n.04'), Synset('state_of_matter.n.01'), Synset('state.n.06'), Synset('country.n.02'), Synset('department_of_state.n.01'), Synset('state.v.01'), Synset('submit.v.02'), Synset('express.v.04')]
# Phrase:  ['Robert', 'Snodgrass', ',', 'state', 'GOP', 'chairman', ',', 'said', 'a', 'meeting', 'held', 'Tuesday', 'night', 'in', 'Blue', 'Ridge', 'brought', 'enthusiastic', 'responses', 'from', 'the', 'audience', '.']
# Word: state
# Lesk algorithm: Synset('state.n.01')
# True Synset: state.n.03
# [Synset('republican_party.n.01')]
# Phrase:  ['Robert', 'Snodgrass', ',', 'state', 'GOP', 'chairman', ',', 'said', 'a', 'meeting', 'held', 'Tuesday', 'night', 'in', 'Blue', 'Ridge', 'brought', 'enthusiastic', 'responses', 'from', 'the', 'audience', '.']
# Word: GOP
# Lesk algorithm: Synset('republican_party.n.01')
# True Synset: republican_party.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['State', 'Party', 'Chairman', 'James', 'W.', 'Dorsey', 'added', 'that', 'enthusiasm', 'was', 'picking', 'up', 'for', 'a', 'state', 'rally', 'to', 'be', 'held', 'Sept.', '8', 'in', 'Savannah', 'at', 'which', 'newly', 'elected', 'Texas', 'Sen.', 'John', 'Tower', 'will', 'be', 'the', 'featured', 'speaker', '.']
# Word: person
# Lesk algorithm: Synset('person.n.03')
# True Synset: person.n.01
# [Synset('enthusiasm.n.01'), Synset('exuberance.n.02'), Synset('enthusiasm.n.03')]
# Phrase:  ['State', 'Party', 'Chairman', 'James', 'W.', 'Dorsey', 'added', 'that', 'enthusiasm', 'was', 'picking', 'up', 'for', 'a', 'state', 'rally', 'to', 'be', 'held', 'Sept.', '8', 'in', 'Savannah', 'at', 'which', 'newly', 'elected', 'Texas', 'Sen.', 'John', 'Tower', 'will', 'be', 'the', 'featured', 'speaker', '.']
# Word: enthusiasm
# Lesk algorithm: Synset('enthusiasm.n.03')
# True Synset: enthusiasm.n.03
# [Synset('state.n.01'), Synset('state.n.02'), Synset('state.n.03'), Synset('state.n.04'), Synset('state_of_matter.n.01'), Synset('state.n.06'), Synset('country.n.02'), Synset('department_of_state.n.01'), Synset('state.v.01'), Synset('submit.v.02'), Synset('express.v.04')]
# Phrase:  ['State', 'Party', 'Chairman', 'James', 'W.', 'Dorsey', 'added', 'that', 'enthusiasm', 'was', 'picking', 'up', 'for', 'a', 'state', 'rally', 'to', 'be', 'held', 'Sept.', '8', 'in', 'Savannah', 'at', 'which', 'newly', 'elected', 'Texas', 'Sen.', 'John', 'Tower', 'will', 'be', 'the', 'featured', 'speaker', '.']
# Word: state
# Lesk algorithm: Synset('state.n.04')
# True Synset: state.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['In', 'the', 'Blue', 'Ridge', 'meeting', ',', 'the', 'audience', 'was', 'warned', 'that', 'entering', 'a', 'candidate', 'for', 'governor', 'would', 'force', 'it', 'to', 'take', 'petitions', 'out', 'into', 'voting', 'precincts', 'to', 'obtain', 'the', 'signatures', 'of', 'registered', 'voters', '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('meeting.n.01'), Synset('meeting.n.02'), Synset('meeting.n.03'), Synset('meeting.n.04'), Synset('merging.n.01'), Synset('confluence.n.01'), Synset('meet.v.01'), Synset('meet.v.02'), Synset('converge.v.01'), Synset('meet.v.04'), Synset('meet.v.05'), Synset('meet.v.06'), Synset('meet.v.07'), Synset('meet.v.08'), Synset('meet.v.09'), Synset('meet.v.10'), Synset('meet.v.11'), Synset('suffer.v.10'), Synset('touch.v.05')]
# Phrase:  ['In', 'the', 'Blue', 'Ridge', 'meeting', ',', 'the', 'audience', 'was', 'warned', 'that', 'entering', 'a', 'candidate', 'for', 'governor', 'would', 'force', 'it', 'to', 'take', 'petitions', 'out', 'into', 'voting', 'precincts', 'to', 'obtain', 'the', 'signatures', 'of', 'registered', 'voters', '.']
# Word: meeting
# Lesk algorithm: Synset('meeting.n.01')
# True Synset: meeting.n.01
# [Synset('audience.n.01'), Synset('audience.n.02'), Synset('hearing.n.02'), Synset('consultation.n.01')]
# Phrase:  ['In', 'the', 'Blue', 'Ridge', 'meeting', ',', 'the', 'audience', 'was', 'warned', 'that', 'entering', 'a', 'candidate', 'for', 'governor', 'would', 'force', 'it', 'to', 'take', 'petitions', 'out', 'into', 'voting', 'precincts', 'to', 'obtain', 'the', 'signatures', 'of', 'registered', 'voters', '.']
# Word: audience
# Lesk algorithm: Synset('audience.n.01')
# True Synset: audience.n.01
# [Synset('warning.n.01'), Synset('admonition.n.01'), Synset('warning.n.03'), Synset('warn.v.01'), Synset('warn.v.02'), Synset('warn.v.03'), Synset('warn.v.04'), Synset('admonitory.s.01')]
# Phrase:  ['Despite', 'the', 'warning', ',', 'there', 'was', 'a', 'unanimous', 'vote', 'to', 'enter', 'a', 'candidate', ',', 'according', 'to', 'Republicans', 'who', 'attended', '.']
# Word: warning
# Lesk algorithm: Synset('warning.n.01')
# True Synset: admonition.n.01
# [Synset('vote.n.01'), Synset('vote.n.02'), Synset('right_to_vote.n.01'), Synset('vote.n.04'), Synset('vote.n.05'), Synset('vote.v.01'), Synset('vote.v.02'), Synset('vote.v.03'), Synset('vote.v.04'), Synset('vote.v.05')]
# Phrase:  ['Despite', 'the', 'warning', ',', 'there', 'was', 'a', 'unanimous', 'vote', 'to', 'enter', 'a', 'candidate', ',', 'according', 'to', 'Republicans', 'who', 'attended', '.']
# Word: vote
# Lesk algorithm: Synset('vote.v.01')
# True Synset: vote.n.01
# [Synset('campaigner.n.01'), Synset('candidate.n.02')]
# Phrase:  ['Despite', 'the', 'warning', ',', 'there', 'was', 'a', 'unanimous', 'vote', 'to', 'enter', 'a', 'candidate', ',', 'according', 'to', 'Republicans', 'who', 'attended', '.']
# Word: candidate
# Lesk algorithm: Synset('campaigner.n.01')
# True Synset: campaigner.n.01
# [Synset('crowd.n.01'), Synset('crowd.n.02'), Synset('herd.v.01'), Synset('crowd.v.02'), Synset('crowd.v.03'), Synset('push.v.06')]
# Phrase:  ['When', 'the', 'crowd', 'was', 'asked', 'whether', 'it', 'wanted', 'to', 'wait', 'one', 'more', 'term', 'to', 'make', 'the', 'race', ',', 'it', 'voted', 'no', '-', 'and', 'there', 'were', 'no', 'dissents', '.']
# Word: crowd
# Lesk algorithm: Synset('crowd.n.01')
# True Synset: crowd.n.01
# [Synset('term.n.01'), Synset('term.n.02'), Synset('condition.n.07'), Synset('term.n.04'), Synset('term.n.05'), Synset('term.n.06'), Synset('terminus.n.03'), Synset('term.v.01')]
# Phrase:  ['When', 'the', 'crowd', 'was', 'asked', 'whether', 'it', 'wanted', 'to', 'wait', 'one', 'more', 'term', 'to', 'make', 'the', 'race', ',', 'it', 'voted', 'no', '-', 'and', 'there', 'were', 'no', 'dissents', '.']
# Word: term
# Lesk algorithm: Synset('term.n.02')
# True Synset: term.n.02
# [Synset('race.n.01'), Synset('race.n.02'), Synset('race.n.03'), Synset('subspecies.n.01'), Synset('slipstream.n.01'), Synset('raceway.n.01'), Synset('rush.v.01'), Synset('race.v.02'), Synset('race.v.03'), Synset('race.v.04')]
# Phrase:  ['When', 'the', 'crowd', 'was', 'asked', 'whether', 'it', 'wanted', 'to', 'wait', 'one', 'more', 'term', 'to', 'make', 'the', 'race', ',', 'it', 'voted', 'no', '-', 'and', 'there', 'were', 'no', 'dissents', '.']
# Word: race
# Lesk algorithm: Synset('race.n.01')
# True Synset: race.n.01
# [Synset('hurdle.n.01'), Synset('hurdle.n.02'), Synset('vault.n.04'), Synset('hurdle.v.01')]
# Phrase:  ['The', 'largest', 'hurdle', 'the', 'Republicans', 'would', 'have', 'to', 'face', 'is', 'a', 'state', 'law', 'which', 'says', 'that', 'before', 'making', 'a', 'first', 'race', ',', 'one', 'of', 'two', 'alternative', 'courses', 'must', 'be', 'taken', ':']
# Word: hurdle
# Lesk algorithm: Synset('hurdle.n.02')
# True Synset: hurdle.n.01
# [Synset('republican.n.01'), Synset('republican.n.02'), Synset('republican.n.03'), Synset('republican.a.01'), Synset('republican.s.02')]
# Phrase:  ['The', 'largest', 'hurdle', 'the', 'Republicans', 'would', 'have', 'to', 'face', 'is', 'a', 'state', 'law', 'which', 'says', 'that', 'before', 'making', 'a', 'first', 'race', ',', 'one', 'of', 'two', 'alternative', 'courses', 'must', 'be', 'taken', ':']
# Word: Republican
# Lesk algorithm: Synset('republican.n.01')
# True Synset: republican.n.01
# [Synset('state.n.01'), Synset('state.n.02'), Synset('state.n.03'), Synset('state.n.04'), Synset('state_of_matter.n.01'), Synset('state.n.06'), Synset('country.n.02'), Synset('department_of_state.n.01'), Synset('state.v.01'), Synset('submit.v.02'), Synset('express.v.04')]
# Phrase:  ['The', 'largest', 'hurdle', 'the', 'Republicans', 'would', 'have', 'to', 'face', 'is', 'a', 'state', 'law', 'which', 'says', 'that', 'before', 'making', 'a', 'first', 'race', ',', 'one', 'of', 'two', 'alternative', 'courses', 'must', 'be', 'taken', ':']
# Word: state
# Lesk algorithm: Synset('state.n.04')
# True Synset: state.n.04
# [Synset('percentage.n.01')]
# Phrase:  ['Five', 'per', 'cent', 'of', 'the', 'voters', 'in', 'each', 'county', 'must', 'sign', 'petitions', 'requesting', 'that', 'the', 'Republicans', 'be', 'allowed', 'to', 'place', 'names', 'of', 'candidates', 'on', 'the', 'general', 'election', 'ballot', ',', 'or', 'The', 'Republicans', 'must', 'hold', 'a', 'primary', 'under', 'the', 'county', 'unit', 'system', '-', 'a', 'system', 'which', 'the', 'party', 'opposes', 'in', 'its', 'platform', '.']
# Word: percent
# Lesk algorithm: Synset('percentage.n.01')
# True Synset: percentage.n.01
# [Synset('voter.n.01')]
# Phrase:  ['Five', 'per', 'cent', 'of', 'the', 'voters', 'in', 'each', 'county', 'must', 'sign', 'petitions', 'requesting', 'that', 'the', 'Republicans', 'be', 'allowed', 'to', 'place', 'names', 'of', 'candidates', 'on', 'the', 'general', 'election', 'ballot', ',', 'or', 'The', 'Republicans', 'must', 'hold', 'a', 'primary', 'under', 'the', 'county', 'unit', 'system', '-', 'a', 'system', 'which', 'the', 'party', 'opposes', 'in', 'its', 'platform', '.']
# Word: voter
# Lesk algorithm: Synset('voter.n.01')
# True Synset: voter.n.01
# [Synset('county.n.01'), Synset('county.n.02')]
# Phrase:  ['Five', 'per', 'cent', 'of', 'the', 'voters', 'in', 'each', 'county', 'must', 'sign', 'petitions', 'requesting', 'that', 'the', 'Republicans', 'be', 'allowed', 'to', 'place', 'names', 'of', 'candidates', 'on', 'the', 'general', 'election', 'ballot', ',', 'or', 'The', 'Republicans', 'must', 'hold', 'a', 'primary', 'under', 'the', 'county', 'unit', 'system', '-', 'a', 'system', 'which', 'the', 'party', 'opposes', 'in', 'its', 'platform', '.']
# Word: county
# Lesk algorithm: Synset('county.n.01')
# True Synset: county.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Sam', 'Caldwell', ',', 'State', 'Highway', 'Department', 'public', 'relations', 'director', ',', 'resigned', 'Tuesday', 'to', 'work', 'for', 'Lt.', 'Gov.', 'Garland', 'Byrd', "'s", 'campaign', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['Sam', 'Caldwell', ',', 'State', 'Highway', 'Department', 'public', 'relations', 'director', ',', 'resigned', 'Tuesday', 'to', 'work', 'for', 'Lt.', 'Gov.', 'Garland', 'Byrd', "'s", 'campaign', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('public_relations.n.01')]
# Phrase:  ['Sam', 'Caldwell', ',', 'State', 'Highway', 'Department', 'public', 'relations', 'director', ',', 'resigned', 'Tuesday', 'to', 'work', 'for', 'Lt.', 'Gov.', 'Garland', 'Byrd', "'s", 'campaign', '.']
# Word: public_relations
# Lesk algorithm: Synset('public_relations.n.01')
# True Synset: public_relations.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Caldwell', "'s", 'resignation', 'had', 'been', 'expected', 'for', 'some', 'time', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('resignation.n.01'), Synset('resignation.n.02'), Synset('resignation.n.03')]
# Phrase:  ['Caldwell', "'s", 'resignation', 'had', 'been', 'expected', 'for', 'some', 'time', '.']
# Word: resignation
# Lesk algorithm: Synset('resignation.n.03')
# True Synset: resignation.n.03
# [Synset('time.n.01'), Synset('time.n.02'), Synset('time.n.03'), Synset('time.n.04'), Synset('time.n.05'), Synset('time.n.06'), Synset('clock_time.n.01'), Synset('fourth_dimension.n.01'), Synset('meter.n.04'), Synset('prison_term.n.01'), Synset('clock.v.01'), Synset('time.v.02'), Synset('time.v.03'), Synset('time.v.04'), Synset('time.v.05')]
# Phrase:  ['Caldwell', "'s", 'resignation', 'had', 'been', 'expected', 'for', 'some', 'time', '.']
# Word: time
# Lesk algorithm: Synset('time.n.01')
# True Synset: time.n.03
# Numero di volte che lesk ha trovato la giusta definizione: 99
# Numero di nomi totali da disambiguare: 147
# 0.673469387755102

# %% [markdown]
# #### 2. Random extraction of 50 phrases from corpus

# %%
def generate_random_numbers_in_range(low: int, high: int, n: int) -> list[int]:
    return random.sample(range(low, high), k=n)

def random_50_phrases() -> tuple[list[str], list]:
    random_indexes = generate_random_numbers_in_range(0, 5000, 50)
    sentences = []
    sentences_tagged = []
    corpus_tagged = semcor.tagged_sents(tag="sem")[:5000]
    for i in random_indexes: 
        sentences.append(corpus[i])
        sentences_tagged.append(corpus_tagged[i])

    return sentences, sentences_tagged

# %%
sentences, sentences_tagged = random_50_phrases()

disambiguation(sentences, sentences_tagged)
# Out:
# [Synset('meaning.n.01'), Synset('meaning.n.02'), Synset('mean.v.01'), Synset('entail.v.01'), Synset('mean.v.03'), Synset('intend.v.01'), Synset('mean.v.05'), Synset('think_of.v.04'), Synset('mean.v.07'), Synset('meaning.s.01')]
# Phrase:  ['The', 'meaning', 'of', 'the', 'word', 'is', 'quite', 'physical', ',', 'to', 'begin', 'with', '.']
# Word: meaning
# Lesk algorithm: Synset('meaning.n.01')
# True Synset: meaning.n.02
# [Synset('word.n.01'), Synset('word.n.02'), Synset('news.n.01'), Synset('word.n.04'), Synset('discussion.n.02'), Synset('parole.n.01'), Synset('word.n.07'), Synset('son.n.02'), Synset('password.n.01'), Synset('bible.n.01'), Synset('give_voice.v.01')]
# Phrase:  ['The', 'meaning', 'of', 'the', 'word', 'is', 'quite', 'physical', ',', 'to', 'begin', 'with', '.']
# Word: word
# Lesk algorithm: Synset('word.n.02')
# True Synset: word.n.01
# [Synset('religion.n.01'), Synset('religion.n.02')]
# Phrase:  ['Religion', 'fosters', 'group', 'life', 'in', 'various', 'ways', '.']
# Word: religion
# Lesk algorithm: Synset('religion.n.01')
# True Synset: religion.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['Religion', 'fosters', 'group', 'life', 'in', 'various', 'ways', '.']
# Word: group
# Lesk algorithm: Synset('group.v.01')
# True Synset: group.n.01
# [Synset('life.n.01'), Synset('life.n.02'), Synset('life.n.03'), Synset('animation.n.01'), Synset('life.n.05'), Synset('life.n.06'), Synset('life.n.07'), Synset('life.n.08'), Synset('liveliness.n.02'), Synset('life.n.10'), Synset('life.n.11'), Synset('biography.n.01'), Synset('life.n.13'), Synset('life_sentence.n.01')]
# Phrase:  ['Religion', 'fosters', 'group', 'life', 'in', 'various', 'ways', '.']
# Word: life
# Lesk algorithm: Synset('life.n.01')
# True Synset: life.n.01
# [Synset('purchase.n.01'), Synset('purchase.n.02'), Synset('purchase.n.03'), Synset('leverage.n.01'), Synset('buy.v.01')]
# Phrase:  ['Makes', 'necessary', 'purchases', ',', 'places', 'contracts', ',', 'supervises', 'construction', ',', 'installation', ',', 'finishing', 'and', 'placement', 'of', 'furniture', ',', 'fixtures', 'and', 'other', 'correlated', 'furnishings', ',', 'and', 'follows', 'through', 'to', 'completion', 'of', 'project', '``', '.']
# Word: purchase
# Lesk algorithm: Synset('purchase.n.01')
# True Synset: purchase.n.01
# [Synset('construction.n.01'), Synset('construction.n.02'), Synset('construction.n.03'), Synset('structure.n.01'), Synset('construction.n.05'), Synset('construction.n.06'), Synset('construction.n.07')]
# Phrase:  ['Makes', 'necessary', 'purchases', ',', 'places', 'contracts', ',', 'supervises', 'construction', ',', 'installation', ',', 'finishing', 'and', 'placement', 'of', 'furniture', ',', 'fixtures', 'and', 'other', 'correlated', 'furnishings', ',', 'and', 'follows', 'through', 'to', 'completion', 'of', 'project', '``', '.']
# Word: construction
# Lesk algorithm: Synset('construction.n.01')
# True Synset: construction.n.01
# [Synset('installation.n.01'), Synset('facility.n.01'), Synset('initiation.n.01')]
# Phrase:  ['Makes', 'necessary', 'purchases', ',', 'places', 'contracts', ',', 'supervises', 'construction', ',', 'installation', ',', 'finishing', 'and', 'placement', 'of', 'furniture', ',', 'fixtures', 'and', 'other', 'correlated', 'furnishings', ',', 'and', 'follows', 'through', 'to', 'completion', 'of', 'project', '``', '.']
# Word: installation
# Lesk algorithm: Synset('installation.n.01')
# True Synset: installation.n.01
# [Synset('figure.n.01'), Synset('human_body.n.01'), Synset('digit.n.01'), Synset('figure.n.04'), Synset('name.n.04'), Synset('figure.n.06'), Synset('figure.n.07'), Synset('figure.n.08'), Synset('number.n.01'), Synset('trope.n.01'), Synset('figure.n.11'), Synset('design.n.04'), Synset('figure.n.13'), Synset('calculate.v.02'), Synset('figure.v.02'), Synset('visualize.v.01'), Synset('calculate.v.01'), Synset('figure.v.05')]
# Phrase:  ['Figures', '1', 'to', '3', 'show', 'photographic', 'and', 'schematic', 'views', 'of', 'the', 'test', 'stand', 'and', 'of', 'two', 'different', 'models', 'of', 'the', 'anode', 'holder', '.']
# Word: figure
# Lesk algorithm: Synset('digit.n.01')
# True Synset: figure.n.01
# [Synset('position.n.03'), Synset('view.n.02'), Synset('view.n.03'), Synset('view.n.04'), Synset('opinion.n.01'), Synset('opinion.n.02'), Synset('view.n.07'), Synset('scene.n.08'), Synset('horizon.n.02'), Synset('view.n.10'), Synset('see.v.05'), Synset('view.v.02'), Synset('watch.v.03')]
# Phrase:  ['Figures', '1', 'to', '3', 'show', 'photographic', 'and', 'schematic', 'views', 'of', 'the', 'test', 'stand', 'and', 'of', 'two', 'different', 'models', 'of', 'the', 'anode', 'holder', '.']
# Word: view
# Lesk algorithm: Synset('scene.n.08')
# True Synset: scene.n.08
# [Synset('base.n.08'), Synset('stand.n.02'), Synset('stand.n.03'), Synset('stand.n.04'), Synset('rack.n.05'), Synset('stand.n.06'), Synset('point_of_view.n.01'), Synset('stall.n.03'), Synset('stand.n.09'), Synset('stand.n.10'), Synset('bandstand.n.01'), Synset('stand.n.12'), Synset('stand.v.01'), Synset('stand.v.02'), Synset('stand.v.03'), Synset('stand.v.04'), Synset('digest.v.03'), Synset('stand.v.06'), Synset('stand.v.07'), Synset('stand.v.08'), Synset('stand.v.09'), Synset('stand.v.10'), Synset('resist.v.04'), Synset('stand.v.12')]
# Phrase:  ['Figures', '1', 'to', '3', 'show', 'photographic', 'and', 'schematic', 'views', 'of', 'the', 'test', 'stand', 'and', 'of', 'two', 'different', 'models', 'of', 'the', 'anode', 'holder', '.']
# Word: stand
# Lesk algorithm: Synset('resist.v.04')
# True Synset: rack.n.05
# [Synset('plaything.n.01'), Synset('toy.n.02'), Synset('toy.n.03'), Synset('miniature.n.02'), Synset('toy_dog.n.01'), Synset('dally.v.01'), Synset('toy.v.02'), Synset('play.v.16')]
# Phrase:  ['Toys', 'he', 'has', 'can', 'be', 'made', 'to', 'act', 'as', 'substitutes', 'for', 'family', 'temptations', 'such', 'as', 'refrigerator', 'and', 'gas', 'stove', '.']
# Word: toy
# Lesk algorithm: Synset('toy.n.02')
# True Synset: plaything.n.01
# [Synset('substitute.n.01'), Synset('substitute.n.02'), Synset('stand-in.n.01'), Synset('substitute.v.01'), Synset('substitute.v.02'), Synset('substitute.v.03'), Synset('utility.s.02'), Synset('alternate.s.02'), Synset('ersatz.s.01')]
# Phrase:  ['Toys', 'he', 'has', 'can', 'be', 'made', 'to', 'act', 'as', 'substitutes', 'for', 'family', 'temptations', 'such', 'as', 'refrigerator', 'and', 'gas', 'stove', '.']
# Word: substitute
# Lesk algorithm: Synset('substitute.v.02')
# True Synset: substitute.n.01
# [Synset('family.n.01'), Synset('family.n.02'), Synset('class.n.01'), Synset('family.n.04'), Synset('kin.n.01'), Synset('family.n.06'), Synset('syndicate.n.01'), Synset('family.n.08')]
# Phrase:  ['Toys', 'he', 'has', 'can', 'be', 'made', 'to', 'act', 'as', 'substitutes', 'for', 'family', 'temptations', 'such', 'as', 'refrigerator', 'and', 'gas', 'stove', '.']
# Word: family
# Lesk algorithm: Synset('family.n.01')
# True Synset: family.n.01
# [Synset('percentage.n.01'), Synset('share.n.01')]
# Phrase:  ['It', 'should', 'be', 'admitted', ',', 'too', ',', 'that', 'there', 'is', 'a', 'good', 'percentage', 'of', 'lapsed', 'or', 'nonchurchgoing', 'Catholics', '(', 'one', 'paper', 'writes', '50', 'per', 'cent', ')', '.']
# Word: percentage
# Lesk algorithm: Synset('percentage.n.01')
# True Synset: percentage.n.01
# [Synset('catholic.n.01'), Synset('catholic.a.01'), Synset('catholic.s.02')]
# Phrase:  ['It', 'should', 'be', 'admitted', ',', 'too', ',', 'that', 'there', 'is', 'a', 'good', 'percentage', 'of', 'lapsed', 'or', 'nonchurchgoing', 'Catholics', '(', 'one', 'paper', 'writes', '50', 'per', 'cent', ')', '.']
# Word: Catholic
# Lesk algorithm: Synset('catholic.n.01')
# True Synset: catholic.n.01
# [Synset('paper.n.01'), Synset('composition.n.08'), Synset('newspaper.n.01'), Synset('paper.n.04'), Synset('paper.n.05'), Synset('newspaper.n.02'), Synset('newspaper.n.03'), Synset('paper.v.01'), Synset('wallpaper.v.01')]
# Phrase:  ['It', 'should', 'be', 'admitted', ',', 'too', ',', 'that', 'there', 'is', 'a', 'good', 'percentage', 'of', 'lapsed', 'or', 'nonchurchgoing', 'Catholics', '(', 'one', 'paper', 'writes', '50', 'per', 'cent', ')', '.']
# Word: paper
# Lesk algorithm: Synset('paper.n.04')
# True Synset: newspaper.n.01
# [Synset('united_states.n.01'), Synset('united_states_government.n.01')]
# Phrase:  ['In', 'the', 'United', 'States', ',', 'most', 'of', 'the', 'sensors', 'are', 'calibrated', 'by', 'dropping', 'small', 'spheres', 'on', 'their', 'sensitive', 'surfaces', '.']
# Word: United_States
# Lesk algorithm: Synset('united_states_government.n.01')
# True Synset: united_states.n.01
# [Synset('detector.n.01')]
# Phrase:  ['In', 'the', 'United', 'States', ',', 'most', 'of', 'the', 'sensors', 'are', 'calibrated', 'by', 'dropping', 'small', 'spheres', 'on', 'their', 'sensitive', 'surfaces', '.']
# Word: sensor
# Lesk algorithm: Synset('detector.n.01')
# True Synset: detector.n.01
# [Synset('sphere.n.01'), Synset('sphere.n.02'), Synset('sphere.n.03'), Synset('sector.n.03'), Synset('sphere.n.05'), Synset('sphere.n.06'), Synset('celestial_sphere.n.01')]
# Phrase:  ['In', 'the', 'United', 'States', ',', 'most', 'of', 'the', 'sensors', 'are', 'calibrated', 'by', 'dropping', 'small', 'spheres', 'on', 'their', 'sensitive', 'surfaces', '.']
# Word: sphere
# Lesk algorithm: Synset('sphere.n.01')
# True Synset: sphere.n.02
# [Synset('russian.n.01'), Synset('russian.n.02'), Synset('russian.a.01')]
# Phrase:  ['The', 'Russians', 'are', 'all', 'trained', 'as', 'dancers', 'before', 'they', 'start', 'to', 'study', 'gymnastics', '.']
# Word: Russian
# Lesk algorithm: Synset('russian.n.01')
# True Synset: russian.n.01
# [Synset('dancer.n.01'), Synset('dancer.n.02')]
# Phrase:  ['The', 'Russians', 'are', 'all', 'trained', 'as', 'dancers', 'before', 'they', 'start', 'to', 'study', 'gymnastics', '.']
# Word: dancer
# Lesk algorithm: Synset('dancer.n.01')
# True Synset: dancer.n.01
# [Synset('gymnastics.n.01')]
# Phrase:  ['The', 'Russians', 'are', 'all', 'trained', 'as', 'dancers', 'before', 'they', 'start', 'to', 'study', 'gymnastics', '.']
# Word: gymnastics
# Lesk algorithm: Synset('gymnastics.n.01')
# True Synset: gymnastics.n.01
# [Synset('silver_chloride.n.01')]
# Phrase:  ['To', 'prepare', 'the', 'latter', ',', 'silver', 'chloride', 'was', 'precipitated', 'from', 'a', 'solution', 'containing', '*', '*', 'f', 'obtained', 'from', 'the', 'Oak', 'Ridge', 'National', 'Laboratory', '.']
# Word: silver_chloride
# Lesk algorithm: Synset('silver_chloride.n.01')
# True Synset: silver_chloride.n.01
# [Synset('solution.n.01'), Synset('solution.n.02'), Synset('solution.n.03'), Synset('solution.n.04'), Synset('solution.n.05')]
# Phrase:  ['To', 'prepare', 'the', 'latter', ',', 'silver', 'chloride', 'was', 'precipitated', 'from', 'a', 'solution', 'containing', '*', '*', 'f', 'obtained', 'from', 'the', 'Oak', 'Ridge', 'National', 'Laboratory', '.']
# Word: solution
# Lesk algorithm: Synset('solution.n.01')
# True Synset: solution.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['To', 'prepare', 'the', 'latter', ',', 'silver', 'chloride', 'was', 'precipitated', 'from', 'a', 'solution', 'containing', '*', '*', 'f', 'obtained', 'from', 'the', 'Oak', 'Ridge', 'National', 'Laboratory', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('system.n.01'), Synset('system.n.02'), Synset('system.n.03'), Synset('system.n.04'), Synset('arrangement.n.03'), Synset('system.n.06'), Synset('system.n.07'), Synset('system.n.08'), Synset('organization.n.05')]
# Phrase:  ['This', 'system', 'provides', 'long', '-', 'and', 'short-term', 'credit', 'to', 'farmers', 'and', 'their', 'cooperative', 'marketing', ',', 'purchasing', ',', 'and', 'business', 'service', 'organizations', '.']
# Word: system
# Lesk algorithm: Synset('system.n.01')
# True Synset: system.n.02
# [Synset('recognition.n.03'), Synset('credit.n.02'), Synset('credit.n.03'), Synset('credit.n.04'), Synset('credit.n.05'), Synset('credit.n.06'), Synset('citation.n.03'), Synset('credit.n.08'), Synset('credit_rating.n.01'), Synset('credit.v.01'), Synset('accredit.v.03'), Synset('credit.v.03'), Synset('credit.v.04')]
# Phrase:  ['This', 'system', 'provides', 'long', '-', 'and', 'short-term', 'credit', 'to', 'farmers', 'and', 'their', 'cooperative', 'marketing', ',', 'purchasing', ',', 'and', 'business', 'service', 'organizations', '.']
# Word: credit
# Lesk algorithm: Synset('recognition.n.03')
# True Synset: credit.n.02
# [Synset('farmer.n.01'), Synset('farmer.n.02'), Synset('farmer.n.03')]
# Phrase:  ['This', 'system', 'provides', 'long', '-', 'and', 'short-term', 'credit', 'to', 'farmers', 'and', 'their', 'cooperative', 'marketing', ',', 'purchasing', ',', 'and', 'business', 'service', 'organizations', '.']
# Word: farmer
# Lesk algorithm: Synset('farmer.n.01')
# True Synset: farmer.n.01
# [Synset('case.n.01'), Synset('example.n.01'), Synset('exemplify.v.02')]
# Phrase:  ['In', 'this', 'instance', ',', 'because', 'of', 'incomplete', 'septation', ',', 'the', 'secondary', 'lobule', 'does', 'not', 'constitute', 'in', 'itself', 'what', 'appears', 'to', 'be', 'a', 'small', 'individual', 'lung', 'as', 'in', 'type', '1', ',', '.']
# Word: instance
# Lesk algorithm: Synset('case.n.01')
# True Synset: example.n.01
# [Synset('septation.n.01')]
# Phrase:  ['In', 'this', 'instance', ',', 'because', 'of', 'incomplete', 'septation', ',', 'the', 'secondary', 'lobule', 'does', 'not', 'constitute', 'in', 'itself', 'what', 'appears', 'to', 'be', 'a', 'small', 'individual', 'lung', 'as', 'in', 'type', '1', ',', '.']
# Word: septation
# Lesk algorithm: Synset('septation.n.01')
# True Synset: septation.n.01
# [Synset('lobule.n.01')]
# Phrase:  ['In', 'this', 'instance', ',', 'because', 'of', 'incomplete', 'septation', ',', 'the', 'secondary', 'lobule', 'does', 'not', 'constitute', 'in', 'itself', 'what', 'appears', 'to', 'be', 'a', 'small', 'individual', 'lung', 'as', 'in', 'type', '1', ',', '.']
# Word: lobule
# Lesk algorithm: Synset('lobule.n.01')
# True Synset: lobule.n.01
# [Synset('eating.n.01'), Synset('feeding.n.02'), Synset('feed.v.01'), Synset('feed.v.02'), Synset('feed.v.03'), Synset('feed.v.04'), Synset('feed.v.05'), Synset('feed.v.06'), Synset('feed.v.07'), Synset('run.v.06'), Synset('prey.v.01'), Synset('feed.v.10'), Synset('fertilize.v.01')]
# Phrase:  ['The', 'feeding', 'pain', 'antagonism', 'seems', 'to', 'be', 'based', 'on', 'this', 'reciprocal', 'relation', 'between', 'the', 'tropho', '-', 'and', 'ergotropic', 'systems', '.']
# Word: feeding
# Lesk algorithm: Synset('eating.n.01')
# True Synset: eating.n.01
# [Synset('pain.n.01'), Synset('pain.n.02'), Synset('pain.n.03'), Synset('pain.n.04'), Synset('annoyance.n.04'), Synset('trouble.v.05'), Synset('pain.v.02')]
# Phrase:  ['The', 'feeding', 'pain', 'antagonism', 'seems', 'to', 'be', 'based', 'on', 'this', 'reciprocal', 'relation', 'between', 'the', 'tropho', '-', 'and', 'ergotropic', 'systems', '.']
# Word: pain
# Lesk algorithm: Synset('pain.n.01')
# True Synset: pain.n.03
# [Synset('relation.n.01'), Synset('sexual_intercourse.n.01'), Synset('relative.n.01'), Synset('relation.n.04'), Synset('relation_back.n.01'), Synset('relation.n.06')]
# Phrase:  ['The', 'feeding', 'pain', 'antagonism', 'seems', 'to', 'be', 'based', 'on', 'this', 'reciprocal', 'relation', 'between', 'the', 'tropho', '-', 'and', 'ergotropic', 'systems', '.']
# Word: relation
# Lesk algorithm: Synset('relation.n.04')
# True Synset: relation.n.01
# [Synset('form.n.03'), Synset('practice.n.01'), Synset('design.n.04'), Synset('convention.n.02'), Synset('pattern.n.05'), Synset('blueprint.n.01'), Synset('traffic_pattern.n.01'), Synset('radiation_pattern.n.01'), Synset('model.v.01'), Synset('pattern.v.02')]
# Phrase:  ['Everywhere', 'within', 'the', 'common', 'pattern', ',', 'however', ',', 'one', 'finds', 'local', 'diversity', ';', 'Greek', 'history', 'and', 'culture', 'were', 'enduringly', 'fertilized', ',', 'and', 'plagued', ',', 'by', 'the', 'interplay', 'of', 'these', 'conjoined', 'yet', 'opposed', 'factors', '.']
# Word: pattern
# Lesk algorithm: Synset('form.n.03')
# True Synset: pattern.n.05
# [Synset('diverseness.n.01'), Synset('diversity.n.02')]
# Phrase:  ['Everywhere', 'within', 'the', 'common', 'pattern', ',', 'however', ',', 'one', 'finds', 'local', 'diversity', ';', 'Greek', 'history', 'and', 'culture', 'were', 'enduringly', 'fertilized', ',', 'and', 'plagued', ',', 'by', 'the', 'interplay', 'of', 'these', 'conjoined', 'yet', 'opposed', 'factors', '.']
# Word: diversity
# Lesk algorithm: Synset('diverseness.n.01')
# True Synset: diverseness.n.01
# [Synset('history.n.01'), Synset('history.n.02'), Synset('history.n.03'), Synset('history.n.04'), Synset('history.n.05')]
# Phrase:  ['Everywhere', 'within', 'the', 'common', 'pattern', ',', 'however', ',', 'one', 'finds', 'local', 'diversity', ';', 'Greek', 'history', 'and', 'culture', 'were', 'enduringly', 'fertilized', ',', 'and', 'plagued', ',', 'by', 'the', 'interplay', 'of', 'these', 'conjoined', 'yet', 'opposed', 'factors', '.']
# Word: history
# Lesk algorithm: Synset('history.n.01')
# True Synset: history.n.01
# [Synset('power.n.01'), Synset('power.n.02'), Synset('ability.n.02'), Synset('office.n.04'), Synset('power.n.05'), Synset('exponent.n.03'), Synset('might.n.01'), Synset('world_power.n.01'), Synset('baron.n.03'), Synset('power.v.01')]
# Phrase:  ['It', 'grows', 'terribly', 'and', 'unavoidably', 'in', 'power', 'and', 'leaves', 'in', 'its', 'wake', 'a', 'trail', 'of', 'misery', ',', 'moral', 'disintegration', ',', 'and', 'destruction', '.']
# Word: power
# Lesk algorithm: Synset('power.n.01')
# True Synset: power.n.01
# [Synset('aftermath.n.01'), Synset('wake_island.n.01'), Synset('wake.n.03'), Synset('wake.n.04'), Synset('wake.v.01'), Synset('wake_up.v.02'), Synset('inflame.v.04'), Synset('wake.v.04'), Synset('awaken.v.01')]
# Phrase:  ['It', 'grows', 'terribly', 'and', 'unavoidably', 'in', 'power', 'and', 'leaves', 'in', 'its', 'wake', 'a', 'trail', 'of', 'misery', ',', 'moral', 'disintegration', ',', 'and', 'destruction', '.']
# Word: wake
# Lesk algorithm: Synset('aftermath.n.01')
# True Synset: aftermath.n.01
# [Synset('trail.n.01'), Synset('trail.n.02'), Synset('lead.n.03'), Synset('drag.v.05'), Synset('chase.v.01'), Synset('trail.v.03'), Synset('trail.v.04'), Synset('trail.v.05')]
# Phrase:  ['It', 'grows', 'terribly', 'and', 'unavoidably', 'in', 'power', 'and', 'leaves', 'in', 'its', 'wake', 'a', 'trail', 'of', 'misery', ',', 'moral', 'disintegration', ',', 'and', 'destruction', '.']
# Word: trail
# Lesk algorithm: Synset('trail.n.01')
# True Synset: trail.n.01
# [Synset('consideration.n.01'), Synset('circumstance.n.03'), Synset('consideration.n.03'), Synset('consideration.n.04'), Synset('retainer.n.01'), Synset('consideration.n.06')]
# Phrase:  ['Upon', 'consideration', 'of', 'the', 'variety', 'of', 'soils', 'and', 'fabrics', 'normally', 'encountered', 'in', 'the', 'washing', 'process', ',', 'it', 'is', 'little', 'wonder', 'that', 'the', 'use', 'of', 'a', 'number', 'of', 'detergent', 'constituents', 'having', '``', 'synergistic', "''", 'properties', 'has', 'gained', 'widespread', 'acceptance', '.']
# Word: consideration
# Lesk algorithm: Synset('consideration.n.01')
# True Synset: consideration.n.01
# [Synset('assortment.n.01'), Synset('diverseness.n.01'), Synset('variety.n.03'), Synset('variety_show.n.01'), Synset('kind.n.01'), Synset('variety.n.06')]
# Phrase:  ['Upon', 'consideration', 'of', 'the', 'variety', 'of', 'soils', 'and', 'fabrics', 'normally', 'encountered', 'in', 'the', 'washing', 'process', ',', 'it', 'is', 'little', 'wonder', 'that', 'the', 'use', 'of', 'a', 'number', 'of', 'detergent', 'constituents', 'having', '``', 'synergistic', "''", 'properties', 'has', 'gained', 'widespread', 'acceptance', '.']
# Word: variety
# Lesk algorithm: Synset('assortment.n.01')
# True Synset: assortment.n.01
# [Synset('dirt.n.02'), Synset('soil.n.02'), Synset('land.n.02'), Synset('territory.n.03'), Synset('dirty.v.01')]
# Phrase:  ['Upon', 'consideration', 'of', 'the', 'variety', 'of', 'soils', 'and', 'fabrics', 'normally', 'encountered', 'in', 'the', 'washing', 'process', ',', 'it', 'is', 'little', 'wonder', 'that', 'the', 'use', 'of', 'a', 'number', 'of', 'detergent', 'constituents', 'having', '``', 'synergistic', "''", 'properties', 'has', 'gained', 'widespread', 'acceptance', '.']
# Word: soil
# Lesk algorithm: Synset('dirt.n.02')
# True Synset: dirt.n.02
# [Synset('clasp.n.02'), Synset('handle.n.01'), Synset('bag.n.06'), Synset('grip.n.04'), Synset('grip.n.05'), Synset('grip.n.06'), Synset('bobby_pin.n.01'), Synset('grip.v.01'), Synset('grapple.v.02'), Synset('fascinate.v.02')]
# Phrase:  ['This', 'is', 'true', 'only', 'if', 'a', 'very', 'wide', 'grip', 'is', 'used', 'and', 'only', 'when', 'the', 'greatest', 'possible', 'stretch', 'is', 'achieved', '.']
# Word: grip
# Lesk algorithm: Synset('clasp.n.02')
# True Synset: clasp.n.02
# [Synset('stretch.n.01'), Synset('reach.n.03'), Synset('stretch.n.03'), Synset('stretch.n.04'), Synset('stretch.n.05'), Synset('stretch.n.06'), Synset('stretch.n.07'), Synset('stretch.v.01'), Synset('stretch.v.02'), Synset('unfold.v.03'), Synset('stretch.v.04'), Synset('elongate.v.01'), Synset('stretch.v.06'), Synset('stretch.v.07'), Synset('stretch.v.08'), Synset('load.v.05'), Synset('extend.v.17'), Synset('stretch.v.11'), Synset('stretch.s.01'), Synset('stretch.s.02')]
# Phrase:  ['This', 'is', 'true', 'only', 'if', 'a', 'very', 'wide', 'grip', 'is', 'used', 'and', 'only', 'when', 'the', 'greatest', 'possible', 'stretch', 'is', 'achieved', '.']
# Word: stretch
# Lesk algorithm: Synset('stretch.n.01')
# True Synset: reach.n.03
# [Synset('value.n.01'), Synset('value.n.02'), Synset('value.n.03'), Synset('value.n.04'), Synset('value.n.05'), Synset('value.n.06'), Synset('value.v.01'), Synset('prize.v.01'), Synset('respect.v.01'), Synset('measure.v.04'), Synset('rate.v.03')]
# Phrase:  ['We', 'will', 'denote', 'the', 'values', 'of', 'f', '(', 't', ')', 'on', 'different', 'components', 'by', '**f', '.']
# Word: value
# Lesk algorithm: Synset('value.n.04')
# True Synset: value.n.01
# [Synset('component.n.01'), Synset('part.n.01'), Synset('component.n.03')]
# Phrase:  ['We', 'will', 'denote', 'the', 'values', 'of', 'f', '(', 't', ')', 'on', 'different', 'components', 'by', '**f', '.']
# Word: component
# Lesk algorithm: Synset('component.n.03')
# True Synset: component.n.01
# [Synset('music.n.01'), Synset('music.n.02'), Synset('music.n.03'), Synset('music.n.04'), Synset('music.n.05')]
# Phrase:  ['The', 'music', 'which', 'La^utner', 'has', 'composed', 'for', 'this', 'episode', 'is', 'for', 'the', 'most', 'part', '``', 'rather', 'pretty', 'and', 'perfectly', 'banal', "''", '.']
# Word: music
# Lesk algorithm: Synset('music.n.02')
# True Synset: music.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['The', 'music', 'which', 'La^utner', 'has', 'composed', 'for', 'this', 'episode', 'is', 'for', 'the', 'most', 'part', '``', 'rather', 'pretty', 'and', 'perfectly', 'banal', "''", '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('episode.n.01'), Synset('episode.n.02'), Synset('episode.n.03'), Synset('sequence.n.03')]
# Phrase:  ['The', 'music', 'which', 'La^utner', 'has', 'composed', 'for', 'this', 'episode', 'is', 'for', 'the', 'most', 'part', '``', 'rather', 'pretty', 'and', 'perfectly', 'banal', "''", '.']
# Word: episode
# Lesk algorithm: Synset('episode.n.01')
# True Synset: episode.n.01
# [Synset('extent.n.01'), Synset('extent.n.02')]
# Phrase:  ['Note', 'extent', 'of', 'these', 'interests', 'and', 'how', 'available', 'they', 'will', 'be', 'for', 'the', 'public', 'to', 'enjoy', '.']
# Word: extent
# Lesk algorithm: Synset('extent.n.01')
# True Synset: extent.n.02
# [Synset('interest.n.01'), Synset('sake.n.01'), Synset('interest.n.03'), Synset('interest.n.04'), Synset('interest.n.05'), Synset('interest.n.06'), Synset('pastime.n.01'), Synset('interest.v.01'), Synset('concern.v.02'), Synset('matter_to.v.01')]
# Phrase:  ['Note', 'extent', 'of', 'these', 'interests', 'and', 'how', 'available', 'they', 'will', 'be', 'for', 'the', 'public', 'to', 'enjoy', '.']
# Word: interest
# Lesk algorithm: Synset('interest.n.05')
# True Synset: interest.n.03
# [Synset('populace.n.01'), Synset('public.n.02'), Synset('public.a.01'), Synset('public.s.02')]
# Phrase:  ['Note', 'extent', 'of', 'these', 'interests', 'and', 'how', 'available', 'they', 'will', 'be', 'for', 'the', 'public', 'to', 'enjoy', '.']
# Word: public
# Lesk algorithm: Synset('public.s.02')
# True Synset: populace.n.01
# [Synset('positivist.n.01'), Synset('positivist.a.01')]
# Phrase:  ['The', 'positivist', 'tells', 'us', 'that', 'when', 'we', 'say', 'this', 'we', 'are', 'only', 'expressing', 'our', 'present', 'emotion', '.']
# Word: positivist
# Lesk algorithm: Synset('positivist.a.01')
# True Synset: positivist.n.01
# [Synset('emotion.n.01')]
# Phrase:  ['The', 'positivist', 'tells', 'us', 'that', 'when', 'we', 'say', 'this', 'we', 'are', 'only', 'expressing', 'our', 'present', 'emotion', '.']
# Word: emotion
# Lesk algorithm: Synset('emotion.n.01')
# True Synset: emotion.n.01
# [Synset('formula.n.01'), Synset('recipe.n.01'), Synset('formula.n.03'), Synset('formula.n.04'), Synset('convention.n.02'), Synset('formula.n.06'), Synset('rule.n.11')]
# Phrase:  ['This', 'formula', 'is', 'given', 'by', 'Rumscheidt', 'and', 'Mason', '.']
# Word: formula
# Lesk algorithm: Synset('convention.n.02')
# True Synset: formula.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['This', 'formula', 'is', 'given', 'by', 'Rumscheidt', 'and', 'Mason', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['This', 'formula', 'is', 'given', 'by', 'Rumscheidt', 'and', 'Mason', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('hope.n.01'), Synset('hope.n.02'), Synset('promise.n.02'), Synset('hope.n.04'), Synset('hope.n.05'), Synset('hope.n.06'), Synset('hope.v.01'), Synset('hope.v.02'), Synset('hope.v.03')]
# Phrase:  ['They', 'hope', ',', 'of', 'course', ',', 'to', 'reclaim', 'the', 'non-Catholic', 'population', 'to', 'the', 'Catholic', 'faith', ',', 'and', 'at', 'every', 'Sunday', 'Benediction', 'they', 'recite', 'by', 'heart', 'the', '``', 'Prayer', 'for', 'England', "''", ':']
# Word: hope
# Lesk algorithm: Synset('hope.n.01')
# True Synset: hope.n.02
# [Synset('non-catholic.n.01')]
# Phrase:  ['They', 'hope', ',', 'of', 'course', ',', 'to', 'reclaim', 'the', 'non-Catholic', 'population', 'to', 'the', 'Catholic', 'faith', ',', 'and', 'at', 'every', 'Sunday', 'Benediction', 'they', 'recite', 'by', 'heart', 'the', '``', 'Prayer', 'for', 'England', "''", ':']
# Word: non-Catholic
# Lesk algorithm: Synset('non-catholic.n.01')
# True Synset: non-catholic.n.01
# [Synset('population.n.01'), Synset('population.n.02'), Synset('population.n.03'), Synset('population.n.04'), Synset('population.n.05')]
# Phrase:  ['They', 'hope', ',', 'of', 'course', ',', 'to', 'reclaim', 'the', 'non-Catholic', 'population', 'to', 'the', 'Catholic', 'faith', ',', 'and', 'at', 'every', 'Sunday', 'Benediction', 'they', 'recite', 'by', 'heart', 'the', '``', 'Prayer', 'for', 'England', "''", ':']
# Word: population
# Lesk algorithm: Synset('population.n.01')
# True Synset: population.n.01
# [Synset('decision.n.02'), Synset('conclusion.n.02'), Synset('stopping_point.n.01'), Synset('ending.n.04'), Synset('conclusion.n.05'), Synset('termination.n.05'), Synset('conclusion.n.07'), Synset('conclusion.n.08'), Synset('decision.n.01')]
# Phrase:  ['The', 'same', 'conclusions', 'can', 'be', 'drawn', 'from', 'the', 'other', 'physical', 'evidence', 'of', 'the', 'Dark', 'ages', ',', 'from', 'linguistic', 'distribution', ',', 'and', 'from', 'the', 'survivals', 'of', 'early', 'social', ',', 'political', ',', 'and', 'religious', 'patterns', 'into', 'later', 'ages', '.']
# Word: conclusion
# Lesk algorithm: Synset('decision.n.02')
# True Synset: decision.n.02
# [Synset('evidence.n.01'), Synset('evidence.n.02'), Synset('evidence.n.03'), Synset('attest.v.01'), Synset('testify.v.02'), Synset('tell.v.07')]
# Phrase:  ['The', 'same', 'conclusions', 'can', 'be', 'drawn', 'from', 'the', 'other', 'physical', 'evidence', 'of', 'the', 'Dark', 'ages', ',', 'from', 'linguistic', 'distribution', ',', 'and', 'from', 'the', 'survivals', 'of', 'early', 'social', ',', 'political', ',', 'and', 'religious', 'patterns', 'into', 'later', 'ages', '.']
# Word: evidence
# Lesk algorithm: Synset('attest.v.01')
# True Synset: evidence.n.01
# [Synset('middle_ages.n.01')]
# Phrase:  ['The', 'same', 'conclusions', 'can', 'be', 'drawn', 'from', 'the', 'other', 'physical', 'evidence', 'of', 'the', 'Dark', 'ages', ',', 'from', 'linguistic', 'distribution', ',', 'and', 'from', 'the', 'survivals', 'of', 'early', 'social', ',', 'political', ',', 'and', 'religious', 'patterns', 'into', 'later', 'ages', '.']
# Word: Dark_Ages
# Lesk algorithm: Synset('middle_ages.n.01')
# True Synset: middle_ages.n.01
# [Synset('thermocouple.n.01')]
# Phrase:  ['The', 'thermocouples', 'in', 'the', 'aluminum', 'disk', 'shown', 'in', 'figure', '2', 'indicated', 'an', 'equilibrium', 'temperature', 'of', 'the', 'surface', 'of', '**f', '.']
# Word: thermocouple
# Lesk algorithm: Synset('thermocouple.n.01')
# True Synset: thermocouple.n.01
# [Synset('aluminum.n.01')]
# Phrase:  ['The', 'thermocouples', 'in', 'the', 'aluminum', 'disk', 'shown', 'in', 'figure', '2', 'indicated', 'an', 'equilibrium', 'temperature', 'of', 'the', 'surface', 'of', '**f', '.']
# Word: aluminum
# Lesk algorithm: Synset('aluminum.n.01')
# True Synset: aluminum.n.01
# [Synset('disk.n.01'), Synset('disk.n.02'), Synset('phonograph_record.n.01'), Synset('magnetic_disk.n.01'), Synset('harrow.v.01')]
# Phrase:  ['The', 'thermocouples', 'in', 'the', 'aluminum', 'disk', 'shown', 'in', 'figure', '2', 'indicated', 'an', 'equilibrium', 'temperature', 'of', 'the', 'surface', 'of', '**f', '.']
# Word: disk
# Lesk algorithm: Synset('disk.n.01')
# True Synset: disk.n.02
# [Synset('golf.n.01'), Synset('golf.v.01')]
# Phrase:  ['``', 'It', "'s", 'kind', 'of', 'like', 'golf', '-', 'if', 'you', 'do', "n't", 'swing', 'a', 'club', 'very', 'often', ',', 'your', 'timing', 'gets', 'off', "''", '.']
# Word: golf
# Lesk algorithm: Synset('golf.v.01')
# True Synset: golf.n.01
# [Synset('baseball_club.n.01'), Synset('club.n.02'), Synset('club.n.03'), Synset('clubhouse.n.01'), Synset('golf_club.n.02'), Synset('club.n.06'), Synset('cabaret.n.01'), Synset('club.v.01'), Synset('club.v.02'), Synset('club.v.03'), Synset('club.v.04')]
# Phrase:  ['``', 'It', "'s", 'kind', 'of', 'like', 'golf', '-', 'if', 'you', 'do', "n't", 'swing', 'a', 'club', 'very', 'often', ',', 'your', 'timing', 'gets', 'off', "''", '.']
# Word: club
# Lesk algorithm: Synset('club.n.02')
# True Synset: golf_club.n.02
# [Synset('timing.n.01'), Synset('timing.n.02'), Synset('clock.v.01'), Synset('time.v.02'), Synset('time.v.03'), Synset('time.v.04'), Synset('time.v.05')]
# Phrase:  ['``', 'It', "'s", 'kind', 'of', 'like', 'golf', '-', 'if', 'you', 'do', "n't", 'swing', 'a', 'club', 'very', 'often', ',', 'your', 'timing', 'gets', 'off', "''", '.']
# Word: timing
# Lesk algorithm: Synset('time.v.05')
# True Synset: timing.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['The', 'Texans', 'won', 'the', 'game', 'through', 'ball', 'control', ',', 'with', 'Quarterback', 'Cotton', 'Davidson', 'throwing', 'only', '17', 'passes', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('game.n.01'), Synset('game.n.02'), Synset('game.n.03'), Synset('game.n.04'), Synset('game.n.05'), Synset('game.n.06'), Synset('game.n.07'), Synset('plot.n.01'), Synset('game.n.09'), Synset('game.n.10'), Synset('game.n.11'), Synset('bet_on.v.01'), Synset('crippled.s.01'), Synset('game.s.02')]
# Phrase:  ['The', 'Texans', 'won', 'the', 'game', 'through', 'ball', 'control', ',', 'with', 'Quarterback', 'Cotton', 'Davidson', 'throwing', 'only', '17', 'passes', '.']
# Word: game
# Lesk algorithm: Synset('game.n.01')
# True Synset: game.n.02
# [Synset('ball.n.01'), Synset('musket_ball.n.01'), Synset('ball.n.03'), Synset('ball.n.04'), Synset('testis.n.01'), Synset('ball.n.06'), Synset('ball.n.07'), Synset('ball.n.08'), Synset('ball.n.09'), Synset('ball.n.10'), Synset('ball.n.11'), Synset('ball.n.12'), Synset('ball.v.01')]
# Phrase:  ['The', 'Texans', 'won', 'the', 'game', 'through', 'ball', 'control', ',', 'with', 'Quarterback', 'Cotton', 'Davidson', 'throwing', 'only', '17', 'passes', '.']
# Word: ball
# Lesk algorithm: Synset('ball.n.01')
# True Synset: ball.n.01
# [Synset('foot.n.01'), Synset('foot.n.02'), Synset('foot.n.03'), Synset('animal_foot.n.01'), Synset('foundation.n.03'), Synset('foot.n.06'), Synset('foot.n.07'), Synset('foot.n.08'), Synset('infantry.n.01'), Synset('metrical_foot.n.01'), Synset('foot.n.11'), Synset('foot.v.01'), Synset('foot.v.02'), Synset('foot.v.03')]
# Phrase:  ['The', '6', '-', 'foot', '3', 'inch', 'Hansen', 'checked', 'in', 'close', 'to', '200', 'pounds', ',', '15', 'pounds', 'lighter', 'than', 'his', 'reporting', 'weight', 'last', 'spring', '.']
# Word: foot
# Lesk algorithm: Synset('foot.n.01')
# True Synset: foot.n.02
# [Synset('inch.n.01'), Synset('column_inch.n.01'), Synset('edge.v.01')]
# Phrase:  ['The', '6', '-', 'foot', '3', 'inch', 'Hansen', 'checked', 'in', 'close', 'to', '200', 'pounds', ',', '15', 'pounds', 'lighter', 'than', 'his', 'reporting', 'weight', 'last', 'spring', '.']
# Word: inch
# Lesk algorithm: Synset('inch.n.01')
# True Synset: inch.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['The', '6', '-', 'foot', '3', 'inch', 'Hansen', 'checked', 'in', 'close', 'to', '200', 'pounds', ',', '15', 'pounds', 'lighter', 'than', 'his', 'reporting', 'weight', 'last', 'spring', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('species.n.01'), Synset('species.n.02'), Synset('coinage.n.01')]
# Phrase:  ['At', 'birth', ',', 'this', 'species', 'varies', 'considerably', 'in', 'size', '.']
# Word: species
# Lesk algorithm: Synset('species.n.02')
# True Synset: species.n.01
# [Synset('size.n.01'), Synset('size.n.02'), Synset('size.n.03'), Synset('size.n.04'), Synset('size.n.05'), Synset('size.v.01'), Synset('size.v.02'), Synset('size.v.03'), Synset('size.s.01')]
# Phrase:  ['At', 'birth', ',', 'this', 'species', 'varies', 'considerably', 'in', 'size', '.']
# Word: size
# Lesk algorithm: Synset('size.n.01')
# True Synset: size.n.01
# [Synset('name.n.01'), Synset('name.n.02'), Synset('name.n.03'), Synset('name.n.04'), Synset('name.n.05'), Synset('name.n.06'), Synset('name.v.01'), Synset('name.v.02'), Synset('name.v.03'), Synset('appoint.v.01'), Synset('name.v.05'), Synset('mention.v.01'), Synset('identify.v.05'), Synset('list.v.01'), Synset('diagnose.v.01')]
# Phrase:  ['The', 'name', '``', 'alkali', 'bee', "''", 'indicates', 'that', 'one', 'has', 'to', 'look', 'for', 'them', 'in', 'rather', 'inhospitable', 'places', '.']
# Word: name
# Lesk algorithm: Synset('name.v.01')
# True Synset: name.n.01
# [Synset('nomia_melanderi.n.01')]
# Phrase:  ['The', 'name', '``', 'alkali', 'bee', "''", 'indicates', 'that', 'one', 'has', 'to', 'look', 'for', 'them', 'in', 'rather', 'inhospitable', 'places', '.']
# Word: alkali_bee
# Lesk algorithm: Synset('nomia_melanderi.n.01')
# True Synset: nomia_melanderi.n.01
# [Synset('topographic_point.n.01'), Synset('place.n.02'), Synset('place.n.03'), Synset('place.n.04'), Synset('stead.n.01'), Synset('place.n.06'), Synset('home.n.01'), Synset('position.n.06'), Synset('position.n.01'), Synset('place.n.10'), Synset('seat.n.01'), Synset('place.n.12'), Synset('place.n.13'), Synset('plaza.n.01'), Synset('place.n.15'), Synset('space.n.07'), Synset('put.v.01'), Synset('place.v.02'), Synset('rate.v.01'), Synset('locate.v.03'), Synset('place.v.05'), Synset('place.v.06'), Synset('target.v.01'), Synset('identify.v.01'), Synset('place.v.09'), Synset('set.v.09'), Synset('place.v.11'), Synset('place.v.12'), Synset('invest.v.01'), Synset('station.v.01'), Synset('place.v.15'), Synset('place.v.16')]
# Phrase:  ['The', 'name', '``', 'alkali', 'bee', "''", 'indicates', 'that', 'one', 'has', 'to', 'look', 'for', 'them', 'in', 'rather', 'inhospitable', 'places', '.']
# Word: place
# Lesk algorithm: Synset('rate.v.01')
# True Synset: topographic_point.n.01
# [Synset('industry.n.01'), Synset('industry.n.02'), Synset('diligence.n.02')]
# Phrase:  ['And', 'to', 'an', 'industry', 'that', 'prides', 'itself', 'on', 'authenticity', ',', 'he', 'urged', 'greater', 'realism', '.']
# Word: industry
# Lesk algorithm: Synset('industry.n.01')
# True Synset: industry.n.01
# [Synset('pride.n.01'), Synset('pride.n.02'), Synset('pride.n.03'), Synset('pride.n.04'), Synset('pride.n.05'), Synset('pride.v.01')]
# Phrase:  ['And', 'to', 'an', 'industry', 'that', 'prides', 'itself', 'on', 'authenticity', ',', 'he', 'urged', 'greater', 'realism', '.']
# Word: pride
# Lesk algorithm: Synset('pride.v.01')
# True Synset: pride.n.02
# [Synset('authenticity.n.01')]
# Phrase:  ['And', 'to', 'an', 'industry', 'that', 'prides', 'itself', 'on', 'authenticity', ',', 'he', 'urged', 'greater', 'realism', '.']
# Word: authenticity
# Lesk algorithm: Synset('authenticity.n.01')
# True Synset: authenticity.n.01
# [Synset('figure.n.01'), Synset('human_body.n.01'), Synset('digit.n.01'), Synset('figure.n.04'), Synset('name.n.04'), Synset('figure.n.06'), Synset('figure.n.07'), Synset('figure.n.08'), Synset('number.n.01'), Synset('trope.n.01'), Synset('figure.n.11'), Synset('design.n.04'), Synset('figure.n.13'), Synset('calculate.v.02'), Synset('figure.v.02'), Synset('visualize.v.01'), Synset('calculate.v.01'), Synset('figure.v.05')]
# Phrase:  ['If', 'one', 'wishes', 'to', 'discuss', 'a', 'literary', 'figure', 'who', 'uses', 'folklore', 'in', 'his', 'work', ',', 'the', 'first', 'thing', 'he', 'must', 'realize', 'is', 'that', 'the', 'literary', 'figure', 'is', 'probably', 'part', 'of', 'this', 'ignorant', 'American', 'public', '.']
# Word: figure
# Lesk algorithm: Synset('figure.n.04')
# True Synset: name.n.04
# [Synset('folklore.n.01')]
# Phrase:  ['If', 'one', 'wishes', 'to', 'discuss', 'a', 'literary', 'figure', 'who', 'uses', 'folklore', 'in', 'his', 'work', ',', 'the', 'first', 'thing', 'he', 'must', 'realize', 'is', 'that', 'the', 'literary', 'figure', 'is', 'probably', 'part', 'of', 'this', 'ignorant', 'American', 'public', '.']
# Word: folklore
# Lesk algorithm: Synset('folklore.n.01')
# True Synset: folklore.n.01
# [Synset('work.n.01'), Synset('work.n.02'), Synset('employment.n.02'), Synset('study.n.02'), Synset('work.n.05'), Synset('workplace.n.01'), Synset('oeuvre.n.01'), Synset('work.v.01'), Synset('work.v.02'), Synset('work.v.03'), Synset('function.v.01'), Synset('work.v.05'), Synset('exercise.v.03'), Synset('make.v.36'), Synset('work.v.08'), Synset('work.v.09'), Synset('work.v.10'), Synset('bring.v.03'), Synset('work.v.12'), Synset('cultivate.v.02'), Synset('work.v.14'), Synset('influence.v.01'), Synset('work.v.16'), Synset('work.v.17'), Synset('work.v.18'), Synset('work.v.19'), Synset('shape.v.02'), Synset('work.v.21'), Synset('knead.v.01'), Synset('exploit.v.01'), Synset('solve.v.01'), Synset('ferment.v.03'), Synset('sour.v.01'), Synset('work.v.27')]
# Phrase:  ['If', 'one', 'wishes', 'to', 'discuss', 'a', 'literary', 'figure', 'who', 'uses', 'folklore', 'in', 'his', 'work', ',', 'the', 'first', 'thing', 'he', 'must', 'realize', 'is', 'that', 'the', 'literary', 'figure', 'is', 'probably', 'part', 'of', 'this', 'ignorant', 'American', 'public', '.']
# Word: work
# Lesk algorithm: Synset('work.n.02')
# True Synset: work.n.02
# [Synset('fear.n.01'), Synset('concern.n.02'), Synset('fear.n.03'), Synset('fear.v.01'), Synset('fear.v.02'), Synset('fear.v.03'), Synset('fear.v.04'), Synset('reverence.v.01')]
# Phrase:  ['They', 'include', 'both', 'individual', 'fears', 'and', 'collective', 'ones', '.']
# Word: fear
# Lesk algorithm: Synset('fear.n.01')
# True Synset: fear.n.01
# [Synset('hormone.n.01')]
# Phrase:  ['The', 'hormone', 'has', 'also', 'been', 'called', 'thyrotrophin', 'or', 'thyrotrophic', 'hormone', '.']
# Word: hormone
# Lesk algorithm: Synset('hormone.n.01')
# True Synset: hormone.n.01
# [Synset('thyrotropin.n.01')]
# Phrase:  ['The', 'hormone', 'has', 'also', 'been', 'called', 'thyrotrophin', 'or', 'thyrotrophic', 'hormone', '.']
# Word: thyrotrophin
# Lesk algorithm: Synset('thyrotropin.n.01')
# True Synset: thyrotropin.n.01
# [Synset('thyrotropin.n.01')]
# Phrase:  ['The', 'hormone', 'has', 'also', 'been', 'called', 'thyrotrophin', 'or', 'thyrotrophic', 'hormone', '.']
# Word: thyrotrophic_hormone
# Lesk algorithm: Synset('thyrotropin.n.01')
# True Synset: thyrotropin.n.01
# [Synset('null_space.n.01')]
# Phrase:  ['Now', 'the', 'range', 'of', '*', '*', 'f', 'is', 'the', 'null', 'space', '*', '*', 'f', 'of', '*', '*', 'f', '.']
# Word: null_space
# Lesk algorithm: Synset('null_space.n.01')
# True Synset: null_space.n.01
# [Synset('professor.n.01')]
# Phrase:  ['Most', 'professors', 'in', 'the', 'course', 'must', ',', 'naturally', ',', 'again', 'have', 'a', 'higher', 'degree', 'than', 'the', 'course', 'offers', '.']
# Word: professor
# Lesk algorithm: Synset('professor.n.01')
# True Synset: professor.n.01
# [Synset('course.n.01'), Synset('course.n.02'), Synset('course.n.03'), Synset('course.n.04'), Synset('path.n.04'), Synset('class.n.02'), Synset('course.n.07'), Synset('course.n.08'), Synset('course.n.09'), Synset('course.v.01'), Synset('run.v.06'), Synset('course.v.03'), Synset('naturally.r.01')]
# Phrase:  ['Most', 'professors', 'in', 'the', 'course', 'must', ',', 'naturally', ',', 'again', 'have', 'a', 'higher', 'degree', 'than', 'the', 'course', 'offers', '.']
# Word: course
# Lesk algorithm: Synset('course.n.01')
# True Synset: course.n.01
# [Synset('degree.n.01'), Synset('degree.n.02'), Synset('academic_degree.n.01'), Synset('degree.n.04'), Synset('degree.n.05'), Synset('degree.n.06'), Synset('degree.n.07')]
# Phrase:  ['Most', 'professors', 'in', 'the', 'course', 'must', ',', 'naturally', ',', 'again', 'have', 'a', 'higher', 'degree', 'than', 'the', 'course', 'offers', '.']
# Word: degree
# Lesk algorithm: Synset('academic_degree.n.01')
# True Synset: academic_degree.n.01
# [Synset('work.n.01'), Synset('work.n.02'), Synset('employment.n.02'), Synset('study.n.02'), Synset('work.n.05'), Synset('workplace.n.01'), Synset('oeuvre.n.01'), Synset('work.v.01'), Synset('work.v.02'), Synset('work.v.03'), Synset('function.v.01'), Synset('work.v.05'), Synset('exercise.v.03'), Synset('make.v.36'), Synset('work.v.08'), Synset('work.v.09'), Synset('work.v.10'), Synset('bring.v.03'), Synset('work.v.12'), Synset('cultivate.v.02'), Synset('work.v.14'), Synset('influence.v.01'), Synset('work.v.16'), Synset('work.v.17'), Synset('work.v.18'), Synset('work.v.19'), Synset('shape.v.02'), Synset('work.v.21'), Synset('knead.v.01'), Synset('exploit.v.01'), Synset('solve.v.01'), Synset('ferment.v.03'), Synset('sour.v.01'), Synset('work.v.27')]
# Phrase:  ['Much', 'of', 'this', 'work', 'has', 'been', 'reviewed', 'by', 'White', '(', '1944', ')', 'and', 'by', 'Albert', '(', '1949', ')', '.']
# Word: work
# Lesk algorithm: Synset('work.n.01')
# True Synset: study.n.02
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Much', 'of', 'this', 'work', 'has', 'been', 'reviewed', 'by', 'White', '(', '1944', ')', 'and', 'by', 'Albert', '(', '1949', ')', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Much', 'of', 'this', 'work', 'has', 'been', 'reviewed', 'by', 'White', '(', '1944', ')', 'and', 'by', 'Albert', '(', '1949', ')', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('set.n.01'), Synset('set.n.02'), Synset('set.n.03'), Synset('stage_set.n.01'), Synset('set.n.05'), Synset('bent.n.01'), Synset('set.n.07'), Synset('set.n.08'), Synset('hardening.n.02'), Synset('set.n.10'), Synset('set.n.11'), Synset('set.n.12'), Synset('set.n.13'), Synset('put.v.01'), Synset('determine.v.03'), Synset('specify.v.02'), Synset('set.v.04'), Synset('set.v.05'), Synset('set.v.06'), Synset('fix.v.12'), Synset('set.v.08'), Synset('set.v.09'), Synset('set.v.10'), Synset('arrange.v.06'), Synset('plant.v.01'), Synset('set.v.13'), Synset('jell.v.01'), Synset('typeset.v.01'), Synset('set.v.16'), Synset('set.v.17'), Synset('set.v.18'), Synset('sic.v.01'), Synset('place.v.11'), Synset('rig.v.04'), Synset('set_up.v.04'), Synset('adjust.v.01'), Synset('fructify.v.03'), Synset('dress.v.16'), Synset('fit.s.02'), Synset('fixed.s.02'), Synset('located.s.01'), Synset('laid.s.01'), Synset('set.s.05'), Synset('determined.s.04'), Synset('hardened.s.05')]
# Phrase:  ['The', 'sets', 'are', 'remarkably', 'elaborate', 'for', 'a', 'road-show', 'that', 'does', "n't", 'pause', 'long', 'in', 'any', 'one', 'place', ',', 'and', 'they', 'are', 'devised', 'so', 'that', 'they', 'shift', 'with', 'a', 'minimum', 'of', 'interruption', 'or', 'obtrusiveness', '.']
# Word: set
# Lesk algorithm: Synset('set.n.03')
# True Synset: stage_set.n.01
# [Synset('road_show.n.01')]
# Phrase:  ['The', 'sets', 'are', 'remarkably', 'elaborate', 'for', 'a', 'road-show', 'that', 'does', "n't", 'pause', 'long', 'in', 'any', 'one', 'place', ',', 'and', 'they', 'are', 'devised', 'so', 'that', 'they', 'shift', 'with', 'a', 'minimum', 'of', 'interruption', 'or', 'obtrusiveness', '.']
# Word: road_show
# Lesk algorithm: Synset('road_show.n.01')
# True Synset: road_show.n.01
# [Synset('topographic_point.n.01'), Synset('place.n.02'), Synset('place.n.03'), Synset('place.n.04'), Synset('stead.n.01'), Synset('place.n.06'), Synset('home.n.01'), Synset('position.n.06'), Synset('position.n.01'), Synset('place.n.10'), Synset('seat.n.01'), Synset('place.n.12'), Synset('place.n.13'), Synset('plaza.n.01'), Synset('place.n.15'), Synset('space.n.07'), Synset('put.v.01'), Synset('place.v.02'), Synset('rate.v.01'), Synset('locate.v.03'), Synset('place.v.05'), Synset('place.v.06'), Synset('target.v.01'), Synset('identify.v.01'), Synset('place.v.09'), Synset('set.v.09'), Synset('place.v.11'), Synset('place.v.12'), Synset('invest.v.01'), Synset('station.v.01'), Synset('place.v.15'), Synset('place.v.16')]
# Phrase:  ['The', 'sets', 'are', 'remarkably', 'elaborate', 'for', 'a', 'road-show', 'that', 'does', "n't", 'pause', 'long', 'in', 'any', 'one', 'place', ',', 'and', 'they', 'are', 'devised', 'so', 'that', 'they', 'shift', 'with', 'a', 'minimum', 'of', 'interruption', 'or', 'obtrusiveness', '.']
# Word: place
# Lesk algorithm: Synset('topographic_point.n.01')
# True Synset: topographic_point.n.01
# [Synset('consequence.n.01'), Synset('solution.n.02'), Synset('result.n.03'), Synset('resultant_role.n.01'), Synset('result.v.01'), Synset('leave.v.07'), Synset('result.v.03')]
# Phrase:  ['From', 'these', 'results', ',', 'one', 'sees', 'that', 'the', 'study', 'of', 'linear', 'operators', 'on', 'vector', 'spaces', 'over', 'an', 'algebraically', 'closed', 'field', 'is', 'essentially', 'reduced', 'to', 'the', 'study', 'of', 'nilpotent', 'operators', '.']
# Word: result
# Lesk algorithm: Synset('consequence.n.01')
# True Synset: consequence.n.01
# [Synset('linear_operator.n.01')]
# Phrase:  ['From', 'these', 'results', ',', 'one', 'sees', 'that', 'the', 'study', 'of', 'linear', 'operators', 'on', 'vector', 'spaces', 'over', 'an', 'algebraically', 'closed', 'field', 'is', 'essentially', 'reduced', 'to', 'the', 'study', 'of', 'nilpotent', 'operators', '.']
# Word: linear_operator
# Lesk algorithm: Synset('linear_operator.n.01')
# True Synset: linear_operator.n.01
# [Synset('vector.n.01'), Synset('vector.n.02'), Synset('vector.n.03'), Synset('vector.n.04')]
# Phrase:  ['From', 'these', 'results', ',', 'one', 'sees', 'that', 'the', 'study', 'of', 'linear', 'operators', 'on', 'vector', 'spaces', 'over', 'an', 'algebraically', 'closed', 'field', 'is', 'essentially', 'reduced', 'to', 'the', 'study', 'of', 'nilpotent', 'operators', '.']
# Word: vector
# Lesk algorithm: Synset('vector.n.01')
# True Synset: vector.n.01
# [Synset('year.n.01'), Synset('year.n.02'), Synset('year.n.03'), Synset('class.n.06')]
# Phrase:  ['Only', 'a', 'few', 'years', 'ago', 'a', 'middle', 'western', 'college', 'circulated', 'a', 'request', 'for', 'a', 'teacher', 'of', 'interior', 'design', '.']
# Word: year
# Lesk algorithm: Synset('year.n.01')
# True Synset: year.n.01
# ...
# [Synset('request.n.01'), Synset('request.n.02'), Synset('request.v.01'), Synset('request.v.02'), Synset('request.v.03')]
# Phrase:  ['Only', 'a', 'few', 'years', 'ago', 'a', 'middle', 'western', 'college', 'circulated', 'a', 'request', 'for', 'a', 'teacher', 'of', 'interior', 'design', '.']
# Word: request
# Lesk algorithm: Synset('request.n.01')
# True Synset: request.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['The', 'Warwick', 'Musical', 'Theater', 'presents', '``', "Where's", 'Charley', '?', "''"]
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('curve.n.01'), Synset('curve.n.02'), Synset('curve.n.03'), Synset('curvature.n.03'), Synset('bend.n.03'), Synset('swerve.v.01'), Synset('wind.v.02'), Synset('arch.v.01'), Synset('crook.v.01'), Synset('curl.v.01')]
# Phrase:  ['We', 'note', 'that', 'two', 'such', 'curves', 'C', 'and', '**f', ',', 'cannot', 'coincide', 'at', 'more', 'than', 'a', 'finite', 'number', 'of', 'points', ';', 'otherwise', ',', 'being', 'analytic', ',', 'they', 'would', 'coincide', 'at', 'all', 'points', ',', 'which', 'is', 'impossible', 'since', 'they', 'do', 'not', 'coincide', 'near', '**f', '.']
# Word: curve
# Lesk algorithm: Synset('curve.n.03')
# True Synset: curve.n.01
# [Synset('number.n.01'), Synset('number.n.02'), Synset('act.n.04'), Synset('phone_number.n.01'), Synset('numeral.n.01'), Synset('issue.n.02'), Synset('number.n.07'), Synset('number.n.08'), Synset('number.n.09'), Synset('number.n.10'), Synset('number.n.11'), Synset('total.v.01'), Synset('number.v.02'), Synset('number.v.03'), Synset('count.v.05'), Synset('count.v.01'), Synset('number.v.06')]
# Phrase:  ['We', 'note', 'that', 'two', 'such', 'curves', 'C', 'and', '**f', ',', 'cannot', 'coincide', 'at', 'more', 'than', 'a', 'finite', 'number', 'of', 'points', ';', 'otherwise', ',', 'being', 'analytic', ',', 'they', 'would', 'coincide', 'at', 'all', 'points', ',', 'which', 'is', 'impossible', 'since', 'they', 'do', 'not', 'coincide', 'near', '**f', '.']
# Word: number
# Lesk algorithm: Synset('number.v.03')
# True Synset: number.n.02
# [Synset('point.n.01'), Synset('point.n.02'), Synset('point.n.03'), Synset('detail.n.01'), Synset('degree.n.02'), Synset('point.n.06'), Synset('point.n.07'), Synset('point.n.08'), Synset('point.n.09'), Synset('point.n.10'), Synset('point.n.11'), Synset('item.n.01'), Synset('point.n.13'), Synset('point.n.14'), Synset('point.n.15'), Synset('compass_point.n.01'), Synset('point.n.17'), Synset('point.n.18'), Synset('period.n.07'), Synset('point.n.20'), Synset('decimal_point.n.01'), Synset('point.n.22'), Synset('point.n.23'), Synset('point.n.24'), Synset('point.n.25'), Synset('distributor_point.n.01'), Synset('indicate.v.02'), Synset('orient.v.01'), Synset('charge.v.17'), Synset('steer.v.01'), Synset('bespeak.v.01'), Synset('luff.v.01'), Synset('point.v.07'), Synset('point.v.08'), Synset('point.v.09'), Synset('point.v.10'), Synset('target.v.01'), Synset('point.v.12'), Synset('sharpen.v.07'), Synset('point.v.14')]
# Phrase:  ['We', 'note', 'that', 'two', 'such', 'curves', 'C', 'and', '**f', ',', 'cannot', 'coincide', 'at', 'more', 'than', 'a', 'finite', 'number', 'of', 'points', ';', 'otherwise', ',', 'being', 'analytic', ',', 'they', 'would', 'coincide', 'at', 'all', 'points', ',', 'which', 'is', 'impossible', 'since', 'they', 'do', 'not', 'coincide', 'near', '**f', '.']
# Word: point
# Lesk algorithm: Synset('point.n.08')
# True Synset: point.n.01
# [Synset('portrayal.n.01'), Synset('portrayal.n.02'), Synset('depicting.n.01'), Synset('portrait.n.02'), Synset('depiction.n.04')]
# Phrase:  ['His', 'portrayal', 'of', 'an', 'edgy', 'head-in-the-clouds', 'artist', 'is', 'virtually', 'flawless', '.']
# Word: portrayal
# Lesk algorithm: Synset('portrayal.n.01')
# True Synset: portrayal.n.02
# [Synset('artist.n.01')]
# Phrase:  ['His', 'portrayal', 'of', 'an', 'edgy', 'head-in-the-clouds', 'artist', 'is', 'virtually', 'flawless', '.']
# Word: artist
# Lesk algorithm: Synset('artist.n.01')
# True Synset: artist.n.01
# [Synset('temperature.n.01'), Synset('temperature.n.02')]
# Phrase:  ['Temperatures', 'of', 'the', 'shield', 'and', 'of', 'the', 'surface', 'of', 'the', 'water', 'cooled', 'anode', 'holder', 'were', 'measured', 'by', 'thermocouples', 'to', 'account', 'for', 'heat', 'received', 'by', 'the', 'coolant', 'but', 'not', 'originating', 'from', 'the', 'anode', 'plug', '.']
# Word: temperature
# Lesk algorithm: Synset('temperature.n.02')
# True Synset: temperature.n.01
# [Synset('shield.n.01'), Synset('shield.n.02'), Synset('carapace.n.01'), Synset('shield.v.01'), Synset('harbor.v.04')]
# Phrase:  ['Temperatures', 'of', 'the', 'shield', 'and', 'of', 'the', 'surface', 'of', 'the', 'water', 'cooled', 'anode', 'holder', 'were', 'measured', 'by', 'thermocouples', 'to', 'account', 'for', 'heat', 'received', 'by', 'the', 'coolant', 'but', 'not', 'originating', 'from', 'the', 'anode', 'plug', '.']
# Word: shield
# Lesk algorithm: Synset('shield.n.01')
# True Synset: shield.n.01
# [Synset('surface.n.01'), Synset('surface.n.02'), Synset('surface.n.03'), Synset('surface.n.04'), Synset('open.n.04'), Synset('airfoil.n.01'), Synset('surface.v.01'), Synset('coat.v.01'), Synset('come_on.v.01'), Synset('surface.a.01')]
# Phrase:  ['Temperatures', 'of', 'the', 'shield', 'and', 'of', 'the', 'surface', 'of', 'the', 'water', 'cooled', 'anode', 'holder', 'were', 'measured', 'by', 'thermocouples', 'to', 'account', 'for', 'heat', 'received', 'by', 'the', 'coolant', 'but', 'not', 'originating', 'from', 'the', 'anode', 'plug', '.']
# Word: surface
# Lesk algorithm: Synset('surface.n.02')
# True Synset: surface.n.01
# [Synset('type.n.01'), Synset('character.n.05'), Synset('type.n.03'), Synset('type.n.04'), Synset('type.n.05'), Synset('type.n.06'), Synset('type.v.01'), Synset('type.v.02')]
# Phrase:  ['As', 'in', 'type', '1', ',', ',', 'it', 'provides', 'arterial', 'blood', 'to', 'the', 'interlobular', 'septa', ',', 'and', 'an', 'extremely', 'rich', 'anastomotic', 'pleural', 'supply', 'is', 'seen', '(', 'figs.', '9', ',', '10', ')', '.']
# Word: type
# Lesk algorithm: Synset('type.n.01')
# True Synset: type.n.01
# [Synset('blood.n.01'), Synset('blood.n.02'), Synset('rake.n.01'), Synset('lineage.n.01'), Synset('blood.n.05'), Synset('blood.v.01')]
# Phrase:  ['As', 'in', 'type', '1', ',', ',', 'it', 'provides', 'arterial', 'blood', 'to', 'the', 'interlobular', 'septa', ',', 'and', 'an', 'extremely', 'rich', 'anastomotic', 'pleural', 'supply', 'is', 'seen', '(', 'figs.', '9', ',', '10', ')', '.']
# Word: blood
# Lesk algorithm: Synset('blood.n.01')
# True Synset: blood.n.01
# [Synset('septum.n.01'), Synset('septum.n.02')]
# Phrase:  ['As', 'in', 'type', '1', ',', ',', 'it', 'provides', 'arterial', 'blood', 'to', 'the', 'interlobular', 'septa', ',', 'and', 'an', 'extremely', 'rich', 'anastomotic', 'pleural', 'supply', 'is', 'seen', '(', 'figs.', '9', ',', '10', ')', '.']
# Word: septum
# Lesk algorithm: Synset('septum.n.01')
# True Synset: septum.n.01
# [Synset('animal.n.01'), Synset('animal.s.01')]
# Phrase:  ['In', 'the', 'experimental', 'animal', 'and', 'in', 'man', 'gross', 'deficiency', 'in', 'dietary', 'iodine', 'causes', 'thyroid', 'hyperplasia', ',', 'hypertrophy', 'and', 'increased', 'thyroid', 'activity', '(', 'Money', ',', 'Rall', 'and', 'Rawson', ',', '1952', ';', 'Stanbury', ',', 'Brownell', ',', 'Riggs', ',', 'Perinetti', ',', 'Itoiz', ',', 'and', 'Del', 'Castillo', ',', '1954', ')', '.']
# Word: animal
# Lesk algorithm: Synset('animal.s.01')
# True Synset: animal.n.01
# [Synset('man.n.01'), Synset('serviceman.n.01'), Synset('man.n.03'), Synset('homo.n.02'), Synset('man.n.05'), Synset('man.n.06'), Synset('valet.n.01'), Synset('man.n.08'), Synset('man.n.09'), Synset('man.n.10'), Synset('world.n.08'), Synset('man.v.01'), Synset('man.v.02')]
# Phrase:  ['In', 'the', 'experimental', 'animal', 'and', 'in', 'man', 'gross', 'deficiency', 'in', 'dietary', 'iodine', 'causes', 'thyroid', 'hyperplasia', ',', 'hypertrophy', 'and', 'increased', 'thyroid', 'activity', '(', 'Money', ',', 'Rall', 'and', 'Rawson', ',', '1952', ';', 'Stanbury', ',', 'Brownell', ',', 'Riggs', ',', 'Perinetti', ',', 'Itoiz', ',', 'and', 'Del', 'Castillo', ',', '1954', ')', '.']
# Word: man
# Lesk algorithm: Synset('man.n.03')
# True Synset: homo.n.02
# [Synset('lack.n.01'), Synset('insufficiency.n.03')]
# Phrase:  ['In', 'the', 'experimental', 'animal', 'and', 'in', 'man', 'gross', 'deficiency', 'in', 'dietary', 'iodine', 'causes', 'thyroid', 'hyperplasia', ',', 'hypertrophy', 'and', 'increased', 'thyroid', 'activity', '(', 'Money', ',', 'Rall', 'and', 'Rawson', ',', '1952', ';', 'Stanbury', ',', 'Brownell', ',', 'Riggs', ',', 'Perinetti', ',', 'Itoiz', ',', 'and', 'Del', 'Castillo', ',', '1954', ')', '.']
# Word: deficiency
# Lesk algorithm: Synset('lack.n.01')
# True Synset: lack.n.01
# [Synset('year.n.01'), Synset('year.n.02'), Synset('year.n.03'), Synset('class.n.06')]
# Phrase:  ['In', 'the', 'earlier', 'years', 'of', 'training', 'certain', 'phases', 'of', 'the', 'work', 'must', 'be', 'covered', 'and', 'the', 'synthetic', 'problem', 'has', 'its', 'use', '.']
# Word: year
# Lesk algorithm: Synset('year.n.01')
# True Synset: year.n.01
# [Synset('training.n.01'), Synset('education.n.05'), Synset('train.v.01'), Synset('train.v.02'), Synset('discipline.v.01'), Synset('prepare.v.05'), Synset('educate.v.03'), Synset('aim.v.01'), Synset('coach.v.01'), Synset('train.v.08'), Synset('train.v.09'), Synset('train.v.10'), Synset('trail.v.05')]
# Phrase:  ['In', 'the', 'earlier', 'years', 'of', 'training', 'certain', 'phases', 'of', 'the', 'work', 'must', 'be', 'covered', 'and', 'the', 'synthetic', 'problem', 'has', 'its', 'use', '.']
# Word: training
# Lesk algorithm: Synset('train.v.01')
# True Synset: training.n.01
# [Synset('phase.n.01'), Synset('phase.n.02'), Synset('phase.n.03'), Synset('phase.n.04'), Synset('phase.v.01'), Synset('phase.v.02')]
# Phrase:  ['In', 'the', 'earlier', 'years', 'of', 'training', 'certain', 'phases', 'of', 'the', 'work', 'must', 'be', 'covered', 'and', 'the', 'synthetic', 'problem', 'has', 'its', 'use', '.']
# Word: phase
# Lesk algorithm: Synset('phase.v.01')
# True Synset: phase.n.01
# [Synset('technique.n.01'), Synset('proficiency.n.02')]
# Phrase:  ['The', 'technique', 'of', 'cutting', 'sections', 'was', 'essentially', 'the', 'same', 'as', 'that', 'described', 'by', 'Coons', 'et', 'al.', '(', '1951', ')', '.']
# Word: technique
# Lesk algorithm: Synset('technique.n.01')
# True Synset: technique.n.01
# [Synset('film_editing.n.01'), Synset('cutting.n.02'), Synset('cut.n.17'), Synset('cutting.n.04'), Synset('clipping.n.01'), Synset('carving.n.02'), Synset('cut.n.15'), Synset('cut.n.16'), Synset('cutting.n.09'), Synset('cut.n.18'), Synset('cut.v.01'), Synset('reduce.v.01'), Synset('swerve.v.01'), Synset('cut.v.04'), Synset('cut.v.05'), Synset('cut.v.06'), Synset('cut.v.07'), Synset('cut.v.08'), Synset('write_out.v.02'), Synset('edit.v.03'), Synset('cut.v.11'), Synset('hack.v.02'), Synset('cut.v.13'), Synset('cut.v.14'), Synset('cut.v.15'), Synset('cut.v.16'), Synset('cut.v.17'), Synset('cut.v.18'), Synset('cut.v.19'), Synset('cut.v.20'), Synset('cut.v.21'), Synset('cut.v.22'), Synset('cut.v.23'), Synset('cut.v.24'), Synset('cut.v.25'), Synset('cut.v.26'), Synset('switch_off.v.01'), Synset('cut.v.28'), Synset('cut.v.29'), Synset('cut.v.30'), Synset('ignore.v.01'), Synset('cut.v.32'), Synset('cut.v.33'), Synset('cut.v.34'), Synset('cut.v.35'), Synset('cut.v.36'), Synset('abridge.v.01'), Synset('dilute.v.01'), Synset('cut.v.39'), Synset('cut.v.40'), Synset('geld.v.01'), Synset('cutting.s.01'), Synset('bleak.s.03'), Synset('cutting.s.03')]
# Phrase:  ['The', 'technique', 'of', 'cutting', 'sections', 'was', 'essentially', 'the', 'same', 'as', 'that', 'described', 'by', 'Coons', 'et', 'al.', '(', '1951', ')', '.']
# Word: cutting
# Lesk algorithm: Synset('cut.v.40')
# True Synset: cut.n.17
# [Synset('section.n.01'), Synset('section.n.02'), Synset('section.n.03'), Synset('section.n.04'), Synset('section.n.05'), Synset('part.n.09'), Synset('section.n.07'), Synset('section.n.08'), Synset('section.n.09'), Synset('section.n.10'), Synset('section.n.11'), Synset('department.n.01'), Synset('section.n.13'), Synset('incision.n.02'), Synset('segment.v.01')]
# Phrase:  ['The', 'technique', 'of', 'cutting', 'sections', 'was', 'essentially', 'the', 'same', 'as', 'that', 'described', 'by', 'Coons', 'et', 'al.', '(', '1951', ')', '.']
# Word: section
# Lesk algorithm: Synset('section.n.02')
# True Synset: section.n.02
# [Synset('feeling.n.01'), Synset('impression.n.01'), Synset('spirit.n.02'), Synset('feeling.n.04'), Synset('touch.n.10'), Synset('feeling.n.06'), Synset('feel.v.01'), Synset('find.v.05'), Synset('feel.v.03'), Synset('feel.v.04'), Synset('feel.v.05'), Synset('feel.v.06'), Synset('feel.v.07'), Synset('feel.v.08'), Synset('feel.v.09'), Synset('palpate.v.01'), Synset('feel.v.11'), Synset('feel.v.12'), Synset('feel.v.13')]
# Phrase:  ['Feelings', 'of', 'a', 'community', 'of', 'interest', 'will', 'have', 'to', 'be', 'recreated', '-', 'in', 'some', 'of', 'the', 'new', 'nations', ',', 'indeed', ',', 'they', 'must', 'be', 'built', 'for', 'the', 'first', 'time', '-', 'on', 'a', 'new', 'basis', 'which', 'looks', 'toward', 'the', 'future', 'and', 'does', 'not', 'rely', 'only', 'on', 'shared', 'memories', 'of', 'the', 'past', '.']
# Word: feeling
# Lesk algorithm: Synset('find.v.05')
# True Synset: spirit.n.02
# [Synset('community.n.01'), Synset('community.n.02'), Synset('community.n.03'), Synset('community.n.04'), Synset('residential_district.n.01'), Synset('community.n.06')]
# Phrase:  ['Feelings', 'of', 'a', 'community', 'of', 'interest', 'will', 'have', 'to', 'be', 'recreated', '-', 'in', 'some', 'of', 'the', 'new', 'nations', ',', 'indeed', ',', 'they', 'must', 'be', 'built', 'for', 'the', 'first', 'time', '-', 'on', 'a', 'new', 'basis', 'which', 'looks', 'toward', 'the', 'future', 'and', 'does', 'not', 'rely', 'only', 'on', 'shared', 'memories', 'of', 'the', 'past', '.']
# Word: community
# Lesk algorithm: Synset('community.n.02')
# True Synset: community.n.04
# [Synset('interest.n.01'), Synset('sake.n.01'), Synset('interest.n.03'), Synset('interest.n.04'), Synset('interest.n.05'), Synset('interest.n.06'), Synset('pastime.n.01'), Synset('interest.v.01'), Synset('concern.v.02'), Synset('matter_to.v.01')]
# Phrase:  ['Feelings', 'of', 'a', 'community', 'of', 'interest', 'will', 'have', 'to', 'be', 'recreated', '-', 'in', 'some', 'of', 'the', 'new', 'nations', ',', 'indeed', ',', 'they', 'must', 'be', 'built', 'for', 'the', 'first', 'time', '-', 'on', 'a', 'new', 'basis', 'which', 'looks', 'toward', 'the', 'future', 'and', 'does', 'not', 'rely', 'only', 'on', 'shared', 'memories', 'of', 'the', 'past', '.']
# Word: interest
# Lesk algorithm: Synset('interest.n.01')
# True Synset: interest.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Arnold', 'Palmer', 'has', 'been', 'a', 'blazing', 'figure', 'in', 'golf', 'over', 'the', 'past', 'twelve', 'months', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('figure.n.01'), Synset('human_body.n.01'), Synset('digit.n.01'), Synset('figure.n.04'), Synset('name.n.04'), Synset('figure.n.06'), Synset('figure.n.07'), Synset('figure.n.08'), Synset('number.n.01'), Synset('trope.n.01'), Synset('figure.n.11'), Synset('design.n.04'), Synset('figure.n.13'), Synset('calculate.v.02'), Synset('figure.v.02'), Synset('visualize.v.01'), Synset('calculate.v.01'), Synset('figure.v.05')]
# Phrase:  ['Arnold', 'Palmer', 'has', 'been', 'a', 'blazing', 'figure', 'in', 'golf', 'over', 'the', 'past', 'twelve', 'months', '.']
# Word: figure
# Lesk algorithm: Synset('figure.n.04')
# True Synset: name.n.04
# [Synset('golf.n.01'), Synset('golf.v.01')]
# Phrase:  ['Arnold', 'Palmer', 'has', 'been', 'a', 'blazing', 'figure', 'in', 'golf', 'over', 'the', 'past', 'twelve', 'months', '.']
# Word: golf
# Lesk algorithm: Synset('golf.v.01')
# True Synset: golf.n.01
# Numero di volte che lesk ha trovato la giusta definizione: 80
# Numero di nomi totali da disambiguare: 135
# 0.5925925925925926

# %%
def execute_multiple_times() -> int:
    n_executions = 10

    result_score = 0

    for i in range(0, n_executions): 
        sentences, sentences_tagged = random_50_phrases()
        score = disambiguation(sentences, sentences_tagged)

        result_score += score

    print("Final Accuracy: " + str(result_score / n_executions))

execute_multiple_times()
# Out:
# [Synset('tug.n.01'), Synset('tugboat.n.01'), Synset('tug.v.01'), Synset('tug.v.02'), Synset('tug.v.03'), Synset('lug.v.01'), Synset('tug.v.05'), Synset('tug.v.06'), Synset('tug.v.07')]
# Phrase:  ['As', 'soon', 'as', 'an', 'experimental', 'tug', 'assures', 'you', 'that', 'roots', 'have', 'taken', 'over', ',', 'cut', 'it', 'off', 'from', 'the', 'mother', 'plant', '.']
# Word: tug
# Lesk algorithm: Synset('tug.v.03')
# True Synset: tug.n.01
# [Synset('root.n.01'), Synset('beginning.n.04'), Synset('root.n.03'), Synset('root.n.04'), Synset('solution.n.04'), Synset('ancestor.n.01'), Synset('etymon.n.01'), Synset('root.n.08'), Synset('root.v.01'), Synset('root.v.02'), Synset('root.v.03'), Synset('rout.v.02'), Synset('settle.v.07'), Synset('root.v.06')]
# Phrase:  ['As', 'soon', 'as', 'an', 'experimental', 'tug', 'assures', 'you', 'that', 'roots', 'have', 'taken', 'over', ',', 'cut', 'it', 'off', 'from', 'the', 'mother', 'plant', '.']
# Word: root
# Lesk algorithm: Synset('root.v.01')
# True Synset: root.n.01
# [Synset('mother.n.01'), Synset('mother.n.02'), Synset('mother.n.03'), Synset('mother.n.04'), Synset('mother.n.05'), Synset('mother.v.01'), Synset('beget.v.01')]
# Phrase:  ['As', 'soon', 'as', 'an', 'experimental', 'tug', 'assures', 'you', 'that', 'roots', 'have', 'taken', 'over', ',', 'cut', 'it', 'off', 'from', 'the', 'mother', 'plant', '.']
# Word: mother
# Lesk algorithm: Synset('mother.n.01')
# True Synset: mother.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Broglio', "'s", '4', '-', '0', 'won-lost', 'record', 'and', '1.24', 'earned-run', 'mark', 'against', 'Pittsburgh', 'a', 'year', 'ago', ';', '2', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('won-lost_record.n.01')]
# Phrase:  ['Broglio', "'s", '4', '-', '0', 'won-lost', 'record', 'and', '1.24', 'earned-run', 'mark', 'against', 'Pittsburgh', 'a', 'year', 'ago', ';', '2', '.']
# Word: won-lost_record
# Lesk algorithm: Synset('won-lost_record.n.01')
# True Synset: won-lost_record.n.01
# [Synset('earned_run.n.01')]
# Phrase:  ['Broglio', "'s", '4', '-', '0', 'won-lost', 'record', 'and', '1.24', 'earned-run', 'mark', 'against', 'Pittsburgh', 'a', 'year', 'ago', ';', '2', '.']
# Word: earned_run
# Lesk algorithm: Synset('earned_run.n.01')
# True Synset: earned_run.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['LaGuardia', "'s", 'multi', 'lingual', 'rallies', ',', 'when', 'he', 'is', 'running', 'for', 'Congress', ',', 'are', 'well', 'staged', ',', 'and', 'wind', 'up', 'in', 'a', 'wild', 'Jewish', 'folk-dance', 'that', 'is', 'really', 'great', 'musical', 'theater', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('rally.n.01'), Synset('rally.n.02'), Synset('rally.n.03'), Synset('rally.n.04'), Synset('rally.n.05'), Synset('beat_up.v.02'), Synset('call_up.v.04'), Synset('muster.v.01'), Synset('rally.v.04'), Synset('tease.v.02')]
# Phrase:  ['LaGuardia', "'s", 'multi', 'lingual', 'rallies', ',', 'when', 'he', 'is', 'running', 'for', 'Congress', ',', 'are', 'well', 'staged', ',', 'and', 'wind', 'up', 'in', 'a', 'wild', 'Jewish', 'folk-dance', 'that', 'is', 'really', 'great', 'musical', 'theater', '.']
# Word: rally
# Lesk algorithm: Synset('rally.n.01')
# True Synset: rally.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['LaGuardia', "'s", 'multi', 'lingual', 'rallies', ',', 'when', 'he', 'is', 'running', 'for', 'Congress', ',', 'are', 'well', 'staged', ',', 'and', 'wind', 'up', 'in', 'a', 'wild', 'Jewish', 'folk-dance', 'that', 'is', 'really', 'great', 'musical', 'theater', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('function.n.01'), Synset('function.n.02'), Synset('function.n.03'), Synset('function.n.04'), Synset('function.n.05'), Synset('affair.n.03'), Synset('routine.n.03'), Synset('function.v.01'), Synset('serve.v.01'), Synset('officiate.v.02')]
# Phrase:  ['These', 'are', 'real', 'analytic', 'periodic', 'functions', 'with', 'period', 'T', '.']
# Word: function
# Lesk algorithm: Synset('affair.n.03')
# True Synset: function.n.01
# [Synset('time_period.n.01'), Synset('period.n.02'), Synset('period.n.03'), Synset('period.n.04'), Synset('period.n.05'), Synset('menstruation.n.01'), Synset('period.n.07')]
# Phrase:  ['These', 'are', 'real', 'analytic', 'periodic', 'functions', 'with', 'period', 'T', '.']
# Word: period
# Lesk algorithm: Synset('time_period.n.01')
# True Synset: time_period.n.01
# [Synset('history.n.01'), Synset('history.n.02'), Synset('history.n.03'), Synset('history.n.04'), Synset('history.n.05')]
# Phrase:  ['The', 'landscape', 'of', 'Greek', 'history', 'broadens', 'widely', ',', 'and', 'rather', 'abruptly', ',', 'in', 'the', 'eighth', 'century', 'B.C.', ',', 'the', 'age', 'of', 'Homer', "'s", '``', 'rosy', 'fingered', 'Dawn', "''", '.']
# Word: history
# Lesk algorithm: Synset('history.n.01')
# True Synset: history.n.01
# [Synset('century.n.01'), Synset('hundred.n.01')]
# Phrase:  ['The', 'landscape', 'of', 'Greek', 'history', 'broadens', 'widely', ',', 'and', 'rather', 'abruptly', ',', 'in', 'the', 'eighth', 'century', 'B.C.', ',', 'the', 'age', 'of', 'Homer', "'s", '``', 'rosy', 'fingered', 'Dawn', "''", '.']
# Word: century
# Lesk algorithm: Synset('century.n.01')
# True Synset: century.n.01
# [Synset('age.n.01'), Synset('historic_period.n.01'), Synset('age.n.03'), Synset('long_time.n.01'), Synset('old_age.n.01'), Synset('age.v.01'), Synset('senesce.v.01'), Synset('age.v.03')]
# Phrase:  ['The', 'landscape', 'of', 'Greek', 'history', 'broadens', 'widely', ',', 'and', 'rather', 'abruptly', ',', 'in', 'the', 'eighth', 'century', 'B.C.', ',', 'the', 'age', 'of', 'Homer', "'s", '``', 'rosy', 'fingered', 'Dawn', "''", '.']
# Word: age
# Lesk algorithm: Synset('historic_period.n.01')
# True Synset: historic_period.n.01
# [Synset('lung.n.01')]
# Phrase:  ['Lung', 'type', '3', ',', '(', 'fig.', '3', ')', 'is', 'to', 'some', 'degree', 'a', 'composite', 'of', 'types', '1', ',', 'and', '2', ',', '.']
# Word: lung
# Lesk algorithm: Synset('lung.n.01')
# True Synset: lung.n.01
# [Synset('type.n.01'), Synset('character.n.05'), Synset('type.n.03'), Synset('type.n.04'), Synset('type.n.05'), Synset('type.n.06'), Synset('type.v.01'), Synset('type.v.02')]
# Phrase:  ['Lung', 'type', '3', ',', '(', 'fig.', '3', ')', 'is', 'to', 'some', 'degree', 'a', 'composite', 'of', 'types', '1', ',', 'and', '2', ',', '.']
# Word: type
# Lesk algorithm: Synset('type.v.01')
# True Synset: type.n.01
# [Synset('figure.n.01'), Synset('fig.n.02'), Synset('libyan_islamic_fighting_group.n.01'), Synset('fig.n.04')]
# Phrase:  ['Lung', 'type', '3', ',', '(', 'fig.', '3', ')', 'is', 'to', 'some', 'degree', 'a', 'composite', 'of', 'types', '1', ',', 'and', '2', ',', '.']
# Word: fig
# Lesk algorithm: Synset('figure.n.01')
# True Synset: figure.n.01
# [Synset('liquid.n.01'), Synset('liquid.n.02'), Synset('liquid.n.03'), Synset('liquid.n.04'), Synset('liquid.a.01'), Synset('liquid.s.02'), Synset('liquid.s.03'), Synset('melted.a.01'), Synset('liquid.s.05'), Synset('fluent.s.01'), Synset('fluid.s.04')]
# Phrase:  ['The', 'liquid', 'phase', 'photochemical', 'exchange', 'between', 'chlorine', 'and', 'carbon', 'tetrachloride', 'was', 'more', 'reproducible', 'than', 'the', 'thermal', 'exchange', ',', 'although', 'still', 'erratic', '.']
# Word: liquid
# Lesk algorithm: Synset('liquid.n.01')
# True Synset: liquid.n.02
# [Synset('phase.n.01'), Synset('phase.n.02'), Synset('phase.n.03'), Synset('phase.n.04'), Synset('phase.v.01'), Synset('phase.v.02')]
# Phrase:  ['The', 'liquid', 'phase', 'photochemical', 'exchange', 'between', 'chlorine', 'and', 'carbon', 'tetrachloride', 'was', 'more', 'reproducible', 'than', 'the', 'thermal', 'exchange', ',', 'although', 'still', 'erratic', '.']
# Word: phase
# Lesk algorithm: Synset('phase.n.02')
# True Synset: phase.n.02
# [Synset('photochemical_exchange.n.01')]
# Phrase:  ['The', 'liquid', 'phase', 'photochemical', 'exchange', 'between', 'chlorine', 'and', 'carbon', 'tetrachloride', 'was', 'more', 'reproducible', 'than', 'the', 'thermal', 'exchange', ',', 'although', 'still', 'erratic', '.']
# Word: photochemical_exchange
# Lesk algorithm: Synset('photochemical_exchange.n.01')
# True Synset: photochemical_exchange.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Yes', ',', 'with', 'Bob', 'Grove', ',', 'Carl', 'Hubbell', ',', 'Herb', 'Pennock', ',', 'Art', 'Nehf', ',', 'Vernon', 'Gomez', ',', 'et', 'al', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Yes', ',', 'with', 'Bob', 'Grove', ',', 'Carl', 'Hubbell', ',', 'Herb', 'Pennock', ',', 'Art', 'Nehf', ',', 'Vernon', 'Gomez', ',', 'et', 'al', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Yes', ',', 'with', 'Bob', 'Grove', ',', 'Carl', 'Hubbell', ',', 'Herb', 'Pennock', ',', 'Art', 'Nehf', ',', 'Vernon', 'Gomez', ',', 'et', 'al', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('fictional_character.n.01'), Synset('quality.n.03'), Synset('character.n.03'), Synset('character.n.04'), Synset('character.n.05'), Synset('character.n.06'), Synset('character.n.07'), Synset('character.n.08'), Synset('character.n.09'), Synset('character.v.01')]
# Phrase:  ['This', ',', 'of', 'course', ',', 'depends', 'on', 'the', 'character', 'of', 'the', 'site', 'itself', ',', 'the', 'previous', 'experience', 'of', 'the', 'investigator', ',', 'and', 'the', 'number', 'of', 'factors', 'needed', 'to', 'arrive', 'at', 'a', 'good', 'decision', '.']
# Word: character
# Lesk algorithm: Synset('character.n.06')
# True Synset: quality.n.03
# [Synset('site.n.01'), Synset('site.n.02'), Synset('web_site.n.01'), Synset('locate.v.03')]
# Phrase:  ['This', ',', 'of', 'course', ',', 'depends', 'on', 'the', 'character', 'of', 'the', 'site', 'itself', ',', 'the', 'previous', 'experience', 'of', 'the', 'investigator', ',', 'and', 'the', 'number', 'of', 'factors', 'needed', 'to', 'arrive', 'at', 'a', 'good', 'decision', '.']
# Word: site
# Lesk algorithm: Synset('site.n.01')
# True Synset: site.n.01
# [Synset('experience.n.01'), Synset('experience.n.02'), Synset('experience.n.03'), Synset('experience.v.01'), Synset('know.v.05'), Synset('experience.v.03'), Synset('feel.v.01'), Synset('have.v.11')]
# Phrase:  ['This', ',', 'of', 'course', ',', 'depends', 'on', 'the', 'character', 'of', 'the', 'site', 'itself', ',', 'the', 'previous', 'experience', 'of', 'the', 'investigator', ',', 'and', 'the', 'number', 'of', 'factors', 'needed', 'to', 'arrive', 'at', 'a', 'good', 'decision', '.']
# Word: experience
# Lesk algorithm: Synset('experience.n.01')
# True Synset: experience.n.01
# [Synset('universe.n.01'), Synset('world.n.02'), Synset('world.n.03'), Synset('earth.n.01'), Synset('populace.n.01'), Synset('world.n.06'), Synset('worldly_concern.n.01'), Synset('world.n.08'), Synset('global.s.01')]
# Phrase:  ['Their', 'world', ',', 'again', ',', 'was', 'a', 'still', 'simple', ',', 'traditional', 'age', 'which', 'was', 'only', 'slowly', 'beginning', 'to', 'appreciate', 'the', 'complexity', 'of', 'life', '.']
# Word: world
# Lesk algorithm: Synset('worldly_concern.n.01')
# True Synset: world.n.03
# [Synset('age.n.01'), Synset('historic_period.n.01'), Synset('age.n.03'), Synset('long_time.n.01'), Synset('old_age.n.01'), Synset('age.v.01'), Synset('senesce.v.01'), Synset('age.v.03')]
# Phrase:  ['Their', 'world', ',', 'again', ',', 'was', 'a', 'still', 'simple', ',', 'traditional', 'age', 'which', 'was', 'only', 'slowly', 'beginning', 'to', 'appreciate', 'the', 'complexity', 'of', 'life', '.']
# Word: age
# Lesk algorithm: Synset('age.n.03')
# True Synset: historic_period.n.01
# [Synset('complexity.n.01')]
# Phrase:  ['Their', 'world', ',', 'again', ',', 'was', 'a', 'still', 'simple', ',', 'traditional', 'age', 'which', 'was', 'only', 'slowly', 'beginning', 'to', 'appreciate', 'the', 'complexity', 'of', 'life', '.']
# Word: complexity
# Lesk algorithm: Synset('complexity.n.01')
# True Synset: complexity.n.01
# [Synset('size.n.01'), Synset('size.n.02'), Synset('size.n.03'), Synset('size.n.04'), Synset('size.n.05'), Synset('size.v.01'), Synset('size.v.02'), Synset('size.v.03'), Synset('size.s.01')]
# Phrase:  ['In', 'addition', ',', 'the', 'size', 'distribution', 'obtained', 'from', 'visual', 'and', 'radar', 'observations', 'of', 'meteors', 'may', 'be', 'extrapolated', 'to', 'the', 'micrometeorite', 'domain', '.']
# Word: size
# Lesk algorithm: Synset('size.n.01')
# True Synset: size.n.01
# [Synset('distribution.n.01'), Synset('distribution.n.02'), Synset('distribution.n.03'), Synset('distribution.n.04')]
# Phrase:  ['In', 'addition', ',', 'the', 'size', 'distribution', 'obtained', 'from', 'visual', 'and', 'radar', 'observations', 'of', 'meteors', 'may', 'be', 'extrapolated', 'to', 'the', 'micrometeorite', 'domain', '.']
# Word: distribution
# Lesk algorithm: Synset('distribution.n.02')
# True Synset: distribution.n.01
# [Synset('radar.n.01')]
# Phrase:  ['In', 'addition', ',', 'the', 'size', 'distribution', 'obtained', 'from', 'visual', 'and', 'radar', 'observations', 'of', 'meteors', 'may', 'be', 'extrapolated', 'to', 'the', 'micrometeorite', 'domain', '.']
# Word: radar
# Lesk algorithm: Synset('radar.n.01')
# True Synset: radar.n.01
# [Synset('nectary.n.01')]
# Phrase:  ['Those', 'are', 'the', 'nectaries', 'or', 'honey', 'glands', '(', 'Fig.', '26', ',', 'page', '74', ')', '.']
# Word: nectary
# Lesk algorithm: Synset('nectary.n.01')
# True Synset: nectary.n.01
# [Synset('honey.n.01'), Synset('beloved.n.01'), Synset('honey.v.01'), Synset('honey.s.01')]
# Phrase:  ['Those', 'are', 'the', 'nectaries', 'or', 'honey', 'glands', '(', 'Fig.', '26', ',', 'page', '74', ')', '.']
# Word: honey
# Lesk algorithm: Synset('honey.v.01')
# True Synset: honey.n.01
# [Synset('gland.n.01')]
# Phrase:  ['Those', 'are', 'the', 'nectaries', 'or', 'honey', 'glands', '(', 'Fig.', '26', ',', 'page', '74', ')', '.']
# Word: gland
# Lesk algorithm: Synset('gland.n.01')
# True Synset: gland.n.01
# [Synset('avocado.n.01'), Synset('avocado.n.02'), Synset('avocado.s.01')]
# Phrase:  ['Avocados', ',', 'however', ',', 'are', 'very', 'rich', 'in', 'nutrients', '.']
# Word: avocado
# Lesk algorithm: Synset('avocado.n.01')
# True Synset: avocado.n.01
# [Synset('food.n.01'), Synset('nutrient.n.02'), Synset('alimentary.s.01')]
# Phrase:  ['Avocados', ',', 'however', ',', 'are', 'very', 'rich', 'in', 'nutrients', '.']
# Word: nutrient
# Lesk algorithm: Synset('food.n.01')
# True Synset: food.n.01
# [Synset('playmate.n.01')]
# Phrase:  ['And', 'for', 'his', 'playmate', ',', 'Francis', 'Coletta', 'of', 'West', 'Warwick', ',', 'who', 'has', 'a', 'bit', 'part', ',', 'Billy', '.']
# Word: playmate
# Lesk algorithm: Synset('playmate.n.01')
# True Synset: playmate.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['And', 'for', 'his', 'playmate', ',', 'Francis', 'Coletta', 'of', 'West', 'Warwick', ',', 'who', 'has', 'a', 'bit', 'part', ',', 'Billy', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('location.n.01'), Synset('placement.n.03'), Synset('localization.n.01'), Synset('location.n.04')]
# Phrase:  ['And', 'for', 'his', 'playmate', ',', 'Francis', 'Coletta', 'of', 'West', 'Warwick', ',', 'who', 'has', 'a', 'bit', 'part', ',', 'Billy', '.']
# Word: location
# Lesk algorithm: Synset('location.n.01')
# True Synset: location.n.01
# [Synset('opportunity.n.01'), Synset('luck.n.02'), Synset('chance.n.03'), Synset('probability.n.01'), Synset('prospect.n.01'), Synset('chance.v.01'), Synset('gamble.v.01'), Synset('find.v.01'), Synset('casual.s.04')]
# Phrase:  ['To', 'minimize', 'the', 'chances', 'of', 'repeating', 'the', 'Balafrej', 'debacle', 'the', 'Ibrahim', 'government', 'was', 'formed', 'a', 'titre', 'personnel', 'and', 'a', 'special', 'office', 'was', 'created', 'in', 'the', 'Ministry', 'of', 'the', 'Interior', 'to', 'plan', 'and', 'to', 'conduct', 'the', 'elections', '.']
# Word: chance
# Lesk algorithm: Synset('opportunity.n.01')
# True Synset: chance.n.03
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['To', 'minimize', 'the', 'chances', 'of', 'repeating', 'the', 'Balafrej', 'debacle', 'the', 'Ibrahim', 'government', 'was', 'formed', 'a', 'titre', 'personnel', 'and', 'a', 'special', 'office', 'was', 'created', 'in', 'the', 'Ministry', 'of', 'the', 'Interior', 'to', 'plan', 'and', 'to', 'conduct', 'the', 'elections', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('debacle.n.01'), Synset('debacle.n.02'), Synset('thrashing.n.01')]
# Phrase:  ['To', 'minimize', 'the', 'chances', 'of', 'repeating', 'the', 'Balafrej', 'debacle', 'the', 'Ibrahim', 'government', 'was', 'formed', 'a', 'titre', 'personnel', 'and', 'a', 'special', 'office', 'was', 'created', 'in', 'the', 'Ministry', 'of', 'the', 'Interior', 'to', 'plan', 'and', 'to', 'conduct', 'the', 'elections', '.']
# Word: debacle
# Lesk algorithm: Synset('debacle.n.01')
# True Synset: debacle.n.01
# [Synset('data.n.01'), Synset('datum.n.01')]
# Phrase:  ['These', 'are', 'few', 'and', 'seemingly', 'disjointed', 'data', ',', 'but', 'they', 'illustrate', 'the', 'important', 'fact', 'that', 'fundamental', 'alterations', 'in', 'conditioned', 'reactions', 'occur', 'in', 'a', 'variety', 'of', 'states', 'in', 'which', 'the', 'hypothalamic', 'balance', 'has', 'been', 'altered', 'by', 'physiological', 'experimentation', ',', 'pharmacological', 'action', ',', 'or', 'clinical', 'processes', '.']
# Word: data
# Lesk algorithm: Synset('data.n.01')
# True Synset: data.n.01
# [Synset('fact.n.01'), Synset('fact.n.02'), Synset('fact.n.03'), Synset('fact.n.04')]
# Phrase:  ['These', 'are', 'few', 'and', 'seemingly', 'disjointed', 'data', ',', 'but', 'they', 'illustrate', 'the', 'important', 'fact', 'that', 'fundamental', 'alterations', 'in', 'conditioned', 'reactions', 'occur', 'in', 'a', 'variety', 'of', 'states', 'in', 'which', 'the', 'hypothalamic', 'balance', 'has', 'been', 'altered', 'by', 'physiological', 'experimentation', ',', 'pharmacological', 'action', ',', 'or', 'clinical', 'processes', '.']
# Word: fact
# Lesk algorithm: Synset('fact.n.03')
# True Synset: fact.n.01
# [Synset('change.n.01'), Synset('alteration.n.02'), Synset('revision.n.01')]
# Phrase:  ['These', 'are', 'few', 'and', 'seemingly', 'disjointed', 'data', ',', 'but', 'they', 'illustrate', 'the', 'important', 'fact', 'that', 'fundamental', 'alterations', 'in', 'conditioned', 'reactions', 'occur', 'in', 'a', 'variety', 'of', 'states', 'in', 'which', 'the', 'hypothalamic', 'balance', 'has', 'been', 'altered', 'by', 'physiological', 'experimentation', ',', 'pharmacological', 'action', ',', 'or', 'clinical', 'processes', '.']
# Word: alteration
# Lesk algorithm: Synset('change.n.01')
# True Synset: change.n.01
# [Synset('gland.n.01')]
# Phrase:  ['Further', ',', 'the', 'gland', 'is', 'able', 'to', 're-use', 'a', 'larger', 'fraction', 'of', 'the', 'thyroid', 'hormone', 'de-iodinated', 'peripherally', '.']
# Word: gland
# Lesk algorithm: Synset('gland.n.01')
# True Synset: gland.n.01
# [Synset('fraction.n.01'), Synset('fraction.n.02'), Synset('fraction.n.03'), Synset('divide.v.02')]
# Phrase:  ['Further', ',', 'the', 'gland', 'is', 'able', 'to', 're-use', 'a', 'larger', 'fraction', 'of', 'the', 'thyroid', 'hormone', 'de-iodinated', 'peripherally', '.']
# Word: fraction
# Lesk algorithm: Synset('fraction.n.01')
# True Synset: fraction.n.02
# [Synset('thyroid_hormone.n.01')]
# Phrase:  ['Further', ',', 'the', 'gland', 'is', 'able', 'to', 're-use', 'a', 'larger', 'fraction', 'of', 'the', 'thyroid', 'hormone', 'de-iodinated', 'peripherally', '.']
# Word: thyroid_hormone
# Lesk algorithm: Synset('thyroid_hormone.n.01')
# True Synset: thyroid_hormone.n.01
# [Synset('psychiatrist.n.01')]
# Phrase:  ['Most', 'psychiatrists', 'dismiss', 'these', 'instances', 'of', 'that', 'weird', 'feeling', 'as', 'the', 'deja', 'vu', '(', 'already', 'seen', ')', 'illusion', ',', 'just', 'as', 'they', 'dismiss', 'dream', 'previsions', 'as', 'coincidences', '.']
# Word: psychiatrist
# Lesk algorithm: Synset('psychiatrist.n.01')
# True Synset: psychiatrist.n.01
# [Synset('case.n.01'), Synset('example.n.01'), Synset('exemplify.v.02')]
# Phrase:  ['Most', 'psychiatrists', 'dismiss', 'these', 'instances', 'of', 'that', 'weird', 'feeling', 'as', 'the', 'deja', 'vu', '(', 'already', 'seen', ')', 'illusion', ',', 'just', 'as', 'they', 'dismiss', 'dream', 'previsions', 'as', 'coincidences', '.']
# Word: instance
# Lesk algorithm: Synset('case.n.01')
# True Synset: case.n.01
# [Synset('feeling.n.01'), Synset('impression.n.01'), Synset('spirit.n.02'), Synset('feeling.n.04'), Synset('touch.n.10'), Synset('feeling.n.06'), Synset('feel.v.01'), Synset('find.v.05'), Synset('feel.v.03'), Synset('feel.v.04'), Synset('feel.v.05'), Synset('feel.v.06'), Synset('feel.v.07'), Synset('feel.v.08'), Synset('feel.v.09'), Synset('palpate.v.01'), Synset('feel.v.11'), Synset('feel.v.12'), Synset('feel.v.13')]
# Phrase:  ['Most', 'psychiatrists', 'dismiss', 'these', 'instances', 'of', 'that', 'weird', 'feeling', 'as', 'the', 'deja', 'vu', '(', 'already', 'seen', ')', 'illusion', ',', 'just', 'as', 'they', 'dismiss', 'dream', 'previsions', 'as', 'coincidences', '.']
# Word: feeling
# Lesk algorithm: Synset('feeling.n.01')
# True Synset: impression.n.01
# [Synset('ventilation.n.02')]
# Phrase:  ['The', 'air', 'conditioning', 'and', 'ventilating', 'systems', 'of', 'large', 'buildings', 'are', 'subject', 'to', 'attack', '.']
# Word: ventilating_system
# Lesk algorithm: Synset('ventilation.n.02')
# True Synset: ventilation.n.02
# [Synset('building.n.01'), Synset('construction.n.01'), Synset('construction.n.07'), Synset('building.n.04'), Synset('construct.v.01'), Synset('build_up.v.02'), Synset('build.v.03'), Synset('build.v.04'), Synset('build.v.05'), Synset('build.v.06'), Synset('build.v.07'), Synset('build.v.08'), Synset('build_up.v.04'), Synset('build.v.10')]
# Phrase:  ['The', 'air', 'conditioning', 'and', 'ventilating', 'systems', 'of', 'large', 'buildings', 'are', 'subject', 'to', 'attack', '.']
# Word: building
# Lesk algorithm: Synset('build.v.05')
# True Synset: building.n.01
# [Synset('attack.n.01'), Synset('attack.n.02'), Synset('fire.n.09'), Synset('approach.n.01'), Synset('attack.n.05'), Synset('attack.n.06'), Synset('attack.n.07'), Synset('attack.n.08'), Synset('attack.n.09'), Synset('attack.v.01'), Synset('attack.v.02'), Synset('attack.v.03'), Synset('assail.v.01'), Synset('attack.v.05'), Synset('attack.v.06')]
# Phrase:  ['The', 'air', 'conditioning', 'and', 'ventilating', 'systems', 'of', 'large', 'buildings', 'are', 'subject', 'to', 'attack', '.']
# Word: attack
# Lesk algorithm: Synset('attack.v.02')
# True Synset: attack.n.01
# [Synset('question.n.01'), Synset('question.n.02'), Synset('question.n.03'), Synset('doubt.n.02'), Synset('motion.n.05'), Synset('question.n.06'), Synset('question.v.01'), Synset('interrogate.v.02'), Synset('question.v.03'), Synset('interview.v.01'), Synset('wonder.v.02')]
# Phrase:  ['Perhaps', 'the', 'very', 'important', 'question', '-', 'What', 'is', ',', 'then', ',', 'exactly', 'the', 'role', 'of', 'kinesthetic', 'sensations', 'in', 'the', 'patient', "'s", 'ability', 'to', 'recognize', 'forms', 'and', 'shapes', 'by', 'means', 'of', 'the', 'tracing', 'movements', 'when', 'he', 'is', 'actually', 'looking', 'at', 'things', '?']
# Word: question
# Lesk algorithm: Synset('question.n.01')
# True Synset: question.n.01
# [Synset('function.n.03'), Synset('character.n.04'), Synset('function.n.02'), Synset('role.n.04')]
# Phrase:  ['Perhaps', 'the', 'very', 'important', 'question', '-', 'What', 'is', ',', 'then', ',', 'exactly', 'the', 'role', 'of', 'kinesthetic', 'sensations', 'in', 'the', 'patient', "'s", 'ability', 'to', 'recognize', 'forms', 'and', 'shapes', 'by', 'means', 'of', 'the', 'tracing', 'movements', 'when', 'he', 'is', 'actually', 'looking', 'at', 'things', '?']
# Word: role
# Lesk algorithm: Synset('function.n.03')
# True Synset: function.n.02
# [Synset('sensation.n.01'), Synset('ace.n.03'), Synset('sensation.n.03'), Synset('sensation.n.04'), Synset('sense.n.03')]
# Phrase:  ['Perhaps', 'the', 'very', 'important', 'question', '-', 'What', 'is', ',', 'then', ',', 'exactly', 'the', 'role', 'of', 'kinesthetic', 'sensations', 'in', 'the', 'patient', "'s", 'ability', 'to', 'recognize', 'forms', 'and', 'shapes', 'by', 'means', 'of', 'the', 'tracing', 'movements', 'when', 'he', 'is', 'actually', 'looking', 'at', 'things', '?']
# Word: sensation
# Lesk algorithm: Synset('sensation.n.01')
# True Synset: sensation.n.01
# [Synset('dallas.n.01')]
# Phrase:  ['All', 'Dallas', 'members', 'voted', 'with', 'Roberts', ',', 'except', 'Rep.', 'Bill', 'Jones', ',', 'who', 'was', 'absent', '.']
# Word: Dallas
# Lesk algorithm: Synset('dallas.n.01')
# True Synset: dallas.n.01
# [Synset('member.n.01'), Synset('member.n.02'), Synset('extremity.n.01'), Synset('member.n.04'), Synset('penis.n.01')]
# Phrase:  ['All', 'Dallas', 'members', 'voted', 'with', 'Roberts', ',', 'except', 'Rep.', 'Bill', 'Jones', ',', 'who', 'was', 'absent', '.']
# Word: member
# Lesk algorithm: Synset('member.n.01')
# True Synset: member.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['All', 'Dallas', 'members', 'voted', 'with', 'Roberts', ',', 'except', 'Rep.', 'Bill', 'Jones', ',', 'who', 'was', 'absent', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('pansy.n.01'), Synset('sissy.n.01'), Synset('fagot.n.01')]
# Phrase:  ['The', 'pansies', 'I', 'cherished', 'most', 'bloomed', 'for', 'me', 'in', 'February', 'during', 'a', 'particularly', 'cold', 'winter', '.']
# Word: pansy
# Lesk algorithm: Synset('pansy.n.01')
# True Synset: pansy.n.01
# [Synset('february.n.01')]
# Phrase:  ['The', 'pansies', 'I', 'cherished', 'most', 'bloomed', 'for', 'me', 'in', 'February', 'during', 'a', 'particularly', 'cold', 'winter', '.']
# Word: February
# Lesk algorithm: Synset('february.n.01')
# True Synset: february.n.01
# [Synset('winter.n.01'), Synset('winter.v.01')]
# Phrase:  ['The', 'pansies', 'I', 'cherished', 'most', 'bloomed', 'for', 'me', 'in', 'February', 'during', 'a', 'particularly', 'cold', 'winter', '.']
# Word: winter
# Lesk algorithm: Synset('winter.n.01')
# True Synset: winter.n.01
# [Synset('site.n.01'), Synset('site.n.02'), Synset('web_site.n.01'), Synset('locate.v.03')]
# Phrase:  ['A', 'site', 'may', 'also', 'be', 'attractive', 'just', 'through', 'the', 'beauty', 'of', 'its', 'trees', 'and', 'shrubs', '.']
# Word: site
# Lesk algorithm: Synset('site.n.01')
# True Synset: site.n.01
# [Synset('beauty.n.01'), Synset('smasher.n.02'), Synset('beauty.n.03')]
# Phrase:  ['A', 'site', 'may', 'also', 'be', 'attractive', 'just', 'through', 'the', 'beauty', 'of', 'its', 'trees', 'and', 'shrubs', '.']
# Word: beauty
# Lesk algorithm: Synset('smasher.n.02')
# True Synset: beauty.n.01
# [Synset('tree.n.01'), Synset('tree.n.02'), Synset('tree.n.03'), Synset('corner.v.02'), Synset('tree.v.02'), Synset('tree.v.03'), Synset('tree.v.04')]
# Phrase:  ['A', 'site', 'may', 'also', 'be', 'attractive', 'just', 'through', 'the', 'beauty', 'of', 'its', 'trees', 'and', 'shrubs', '.']
# Word: tree
# Lesk algorithm: Synset('tree.v.02')
# True Synset: tree.n.01
# [Synset('cub.n.01')]
# Phrase:  ['Rookie', 'Ron', 'Nischwitz', 'continued', 'his', 'pinpoint', 'pitching', 'Monday', 'night', 'as', 'the', 'Bears', 'made', 'it', 'two', 'straight', 'over', 'Indianapolis', ',', '5', '-', '3', '.']
# Word: rookie
# Lesk algorithm: Synset('cub.n.01')
# True Synset: cub.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Rookie', 'Ron', 'Nischwitz', 'continued', 'his', 'pinpoint', 'pitching', 'Monday', 'night', 'as', 'the', 'Bears', 'made', 'it', 'two', 'straight', 'over', 'Indianapolis', ',', '5', '-', '3', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('pitching.n.01'), Synset('lurch.n.03'), Synset('flip.v.06'), Synset('lurch.v.02'), Synset('pitch.v.03'), Synset('pitch.v.04'), Synset('peddle.v.01'), Synset('slope.v.01'), Synset('cant.v.01'), Synset('pitch.v.08'), Synset('deliver.v.11'), Synset('pitch.v.10'), Synset('pitch.v.11'), Synset('gear.v.01')]
# Phrase:  ['Rookie', 'Ron', 'Nischwitz', 'continued', 'his', 'pinpoint', 'pitching', 'Monday', 'night', 'as', 'the', 'Bears', 'made', 'it', 'two', 'straight', 'over', 'Indianapolis', ',', '5', '-', '3', '.']
# Word: pitching
# Lesk algorithm: Synset('lurch.n.03')
# True Synset: pitching.n.01
# [Synset('teacher.n.01'), Synset('teacher.n.02')]
# Phrase:  ['It', 'will', 'occur', 'to', 'anyone', 'that', 'the', 'teacher', 'must', 'have', 'adequate', 'education', ',', 'a', 'depth', 'and', 'breadth', 'of', 'knowledge', 'far', 'beyond', 'the', 'immediate', 'necessities', 'of', 'his', 'course', 'plus', 'complete', 'dedication', 'to', 'his', 'subject', 'and', 'to', 'his', 'students', '.']
# Word: teacher
# Lesk algorithm: Synset('teacher.n.02')
# True Synset: teacher.n.01
# [Synset('education.n.01'), Synset('education.n.02'), Synset('education.n.03'), Synset('education.n.04'), Synset('education.n.05'), Synset('department_of_education.n.01')]
# Phrase:  ['It', 'will', 'occur', 'to', 'anyone', 'that', 'the', 'teacher', 'must', 'have', 'adequate', 'education', ',', 'a', 'depth', 'and', 'breadth', 'of', 'knowledge', 'far', 'beyond', 'the', 'immediate', 'necessities', 'of', 'his', 'course', 'plus', 'complete', 'dedication', 'to', 'his', 'subject', 'and', 'to', 'his', 'students', '.']
# Word: education
# Lesk algorithm: Synset('education.n.01')
# True Synset: education.n.02
# [Synset('depth.n.01'), Synset('depth.n.02'), Synset('depth.n.03'), Synset('depth.n.04'), Synset('astuteness.n.02'), Synset('depth.n.06')]
# Phrase:  ['It', 'will', 'occur', 'to', 'anyone', 'that', 'the', 'teacher', 'must', 'have', 'adequate', 'education', ',', 'a', 'depth', 'and', 'breadth', 'of', 'knowledge', 'far', 'beyond', 'the', 'immediate', 'necessities', 'of', 'his', 'course', 'plus', 'complete', 'dedication', 'to', 'his', 'subject', 'and', 'to', 'his', 'students', '.']
# Word: depth
# Lesk algorithm: Synset('depth.n.01')
# True Synset: depth.n.02
# [Synset('thyroid_gland.n.01'), Synset('thyroid.a.01'), Synset('thyroid.a.02')]
# Phrase:  ['The', 'latter', 'is', 'likely', 'to', 'occur', 'when', 'the', 'thyroid', 'is', 'removed', '.']
# Word: thyroid
# Lesk algorithm: Synset('thyroid.a.01')
# True Synset: thyroid_gland.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['Meanwhile', ',', 'it', 'was', 'learned', 'the', 'State', 'Highway', 'Department', 'is', 'very', 'near', 'being', 'ready', 'to', 'issue', 'the', 'first', '$', '30', 'million', 'worth', 'of', 'highway', 'reconstruction', 'bonds', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('worth.n.01'), Synset('worth.n.02'), Synset('worth.n.03'), Synset('deserving.s.01'), Synset('worth.s.02')]
# Phrase:  ['Meanwhile', ',', 'it', 'was', 'learned', 'the', 'State', 'Highway', 'Department', 'is', 'very', 'near', 'being', 'ready', 'to', 'issue', 'the', 'first', '$', '30', 'million', 'worth', 'of', 'highway', 'reconstruction', 'bonds', '.']
# Word: worth
# Lesk algorithm: Synset('worth.n.01')
# True Synset: worth.n.01
# [Synset('highway.n.01')]
# Phrase:  ['Meanwhile', ',', 'it', 'was', 'learned', 'the', 'State', 'Highway', 'Department', 'is', 'very', 'near', 'being', 'ready', 'to', 'issue', 'the', 'first', '$', '30', 'million', 'worth', 'of', 'highway', 'reconstruction', 'bonds', '.']
# Word: highway
# Lesk algorithm: Synset('highway.n.01')
# True Synset: highway.n.01
# [Synset('administration.n.01'), Synset('administration.n.02'), Synset('administration.n.03'), Synset('presidency.n.01'), Synset('government.n.02'), Synset('administration.n.06')]
# Phrase:  ['The', 'Administration', 'maintains', 'a', 'productive', 'facilities', 'inventory', 'of', 'small', 'business', 'industrial', 'concerns', 'that', 'have', 'voluntarily', 'registered', '.']
# Word: administration
# Lesk algorithm: Synset('administration.n.01')
# True Synset: administration.n.02
# [Synset('facility.n.01'), Synset('adeptness.n.01'), Synset('facility.n.03'), Synset('facility.n.04'), Synset('facility.n.05')]
# Phrase:  ['The', 'Administration', 'maintains', 'a', 'productive', 'facilities', 'inventory', 'of', 'small', 'business', 'industrial', 'concerns', 'that', 'have', 'voluntarily', 'registered', '.']
# Word: facility
# Lesk algorithm: Synset('facility.n.04')
# True Synset: facility.n.01
# [Synset('inventory.n.01'), Synset('stock.n.02'), Synset('inventory.n.03'), Synset('armory.n.01'), Synset('inventory.n.05'), Synset('inventory.v.01')]
# Phrase:  ['The', 'Administration', 'maintains', 'a', 'productive', 'facilities', 'inventory', 'of', 'small', 'business', 'industrial', 'concerns', 'that', 'have', 'voluntarily', 'registered', '.']
# Word: inventory
# Lesk algorithm: Synset('stock.n.02')
# True Synset: inventory.n.01
# [Synset('set.n.01'), Synset('set.n.02'), Synset('set.n.03'), Synset('stage_set.n.01'), Synset('set.n.05'), Synset('bent.n.01'), Synset('set.n.07'), Synset('set.n.08'), Synset('hardening.n.02'), Synset('set.n.10'), Synset('set.n.11'), Synset('set.n.12'), Synset('set.n.13'), Synset('put.v.01'), Synset('determine.v.03'), Synset('specify.v.02'), Synset('set.v.04'), Synset('set.v.05'), Synset('set.v.06'), Synset('fix.v.12'), Synset('set.v.08'), Synset('set.v.09'), Synset('set.v.10'), Synset('arrange.v.06'), Synset('plant.v.01'), Synset('set.v.13'), Synset('jell.v.01'), Synset('typeset.v.01'), Synset('set.v.16'), Synset('set.v.17'), Synset('set.v.18'), Synset('sic.v.01'), Synset('place.v.11'), Synset('rig.v.04'), Synset('set_up.v.04'), Synset('adjust.v.01'), Synset('fructify.v.03'), Synset('dress.v.16'), Synset('fit.s.02'), Synset('fixed.s.02'), Synset('located.s.01'), Synset('laid.s.01'), Synset('set.s.05'), Synset('determined.s.04'), Synset('hardened.s.05')]
# Phrase:  ['Used', 'in', 'several', 'sets', 'of', 'high', 'reps', 'once', 'or', 'twice', 'each', 'week', 'it', 'will', 'not', 'be', 'long', 'before', 'your', 'entire', 'upper', 'leg', 'takes', 'on', 'a', 'razor-sharp', 'definition', 'in', 'which', 'the', 'muscles', 'look', 'like', 'wire', 'cables', 'writhing', 'and', 'twisting', 'under', 'the', 'skin', '!']
# Word: set
# Lesk algorithm: Synset('set.n.10')
# True Synset: set.n.03
# [Synset('leg.n.01'), Synset('leg.n.02'), Synset('leg.n.03'), Synset('branch.n.03'), Synset('leg.n.05'), Synset('peg.n.04'), Synset('leg.n.07'), Synset('leg.n.08'), Synset('stage.n.06')]
# Phrase:  ['Used', 'in', 'several', 'sets', 'of', 'high', 'reps', 'once', 'or', 'twice', 'each', 'week', 'it', 'will', 'not', 'be', 'long', 'before', 'your', 'entire', 'upper', 'leg', 'takes', 'on', 'a', 'razor-sharp', 'definition', 'in', 'which', 'the', 'muscles', 'look', 'like', 'wire', 'cables', 'writhing', 'and', 'twisting', 'under', 'the', 'skin', '!']
# Word: leg
# Lesk algorithm: Synset('leg.n.02')
# True Synset: leg.n.01
# [Synset('definition.n.01'), Synset('definition.n.02')]
# Phrase:  ['Used', 'in', 'several', 'sets', 'of', 'high', 'reps', 'once', 'or', 'twice', 'each', 'week', 'it', 'will', 'not', 'be', 'long', 'before', 'your', 'entire', 'upper', 'leg', 'takes', 'on', 'a', 'razor-sharp', 'definition', 'in', 'which', 'the', 'muscles', 'look', 'like', 'wire', 'cables', 'writhing', 'and', 'twisting', 'under', 'the', 'skin', '!']
# Word: definition
# Lesk algorithm: Synset('definition.n.02')
# True Synset: definition.n.02
# [Synset('ball.n.01'), Synset('musket_ball.n.01'), Synset('ball.n.03'), Synset('ball.n.04'), Synset('testis.n.01'), Synset('ball.n.06'), Synset('ball.n.07'), Synset('ball.n.08'), Synset('ball.n.09'), Synset('ball.n.10'), Synset('ball.n.11'), Synset('ball.n.12'), Synset('ball.v.01')]
# Phrase:  ['The', 'ball', 'went', 'off', 'in', 'a', 'majestic', 'arc', ',', 'an', 'out-of-bounds', 'slice', '.']
# Word: ball
# Lesk algorithm: Synset('ball.n.01')
# True Synset: ball.n.01
# [Synset('discharge.n.05'), Synset('arc.n.02'), Synset('bow.n.05'), Synset('arch.v.01')]
# Phrase:  ['The', 'ball', 'went', 'off', 'in', 'a', 'majestic', 'arc', ',', 'an', 'out-of-bounds', 'slice', '.']
# Word: arc
# Lesk algorithm: Synset('discharge.n.05')
# True Synset: arc.n.02
# [Synset('slice.n.01'), Synset('piece.n.08'), Synset('cut.n.05'), Synset('slice.n.04'), Synset('slice.n.05'), Synset('slice.n.06'), Synset('slit.v.01'), Synset('slice.v.02'), Synset('slice.v.03'), Synset('slice.v.04')]
# Phrase:  ['The', 'ball', 'went', 'off', 'in', 'a', 'majestic', 'arc', ',', 'an', 'out-of-bounds', 'slice', '.']
# Word: slice
# Lesk algorithm: Synset('slice.n.01')
# True Synset: slice.n.04
# [Synset('death.n.01'), Synset('death.n.02'), Synset('death.n.03'), Synset('death.n.04'), Synset('death.n.05'), Synset('death.n.06'), Synset('end.n.06'), Synset('death.n.08')]
# Phrase:  ['His', 'death', 'is', 'his', 'alone', ',', 'yet', 'each', 'man', 'can', 'see', 'his', 'own', 'death', 'in', 'the', 'crucifixion', 'of', 'Jesus', '.']
# Word: death
# Lesk algorithm: Synset('death.n.01')
# True Synset: death.n.01
# [Synset('man.n.01'), Synset('serviceman.n.01'), Synset('man.n.03'), Synset('homo.n.02'), Synset('man.n.05'), Synset('man.n.06'), Synset('valet.n.01'), Synset('man.n.08'), Synset('man.n.09'), Synset('man.n.10'), Synset('world.n.08'), Synset('man.v.01'), Synset('man.v.02')]
# Phrase:  ['His', 'death', 'is', 'his', 'alone', ',', 'yet', 'each', 'man', 'can', 'see', 'his', 'own', 'death', 'in', 'the', 'crucifixion', 'of', 'Jesus', '.']
# Word: man
# Lesk algorithm: Synset('man.n.03')
# True Synset: man.n.03
# [Synset('death.n.01'), Synset('death.n.02'), Synset('death.n.03'), Synset('death.n.04'), Synset('death.n.05'), Synset('death.n.06'), Synset('end.n.06'), Synset('death.n.08')]
# Phrase:  ['His', 'death', 'is', 'his', 'alone', ',', 'yet', 'each', 'man', 'can', 'see', 'his', 'own', 'death', 'in', 'the', 'crucifixion', 'of', 'Jesus', '.']
# Word: death
# Lesk algorithm: Synset('death.n.01')
# True Synset: death.n.01
# [Synset('man.n.01'), Synset('serviceman.n.01'), Synset('man.n.03'), Synset('homo.n.02'), Synset('man.n.05'), Synset('man.n.06'), Synset('valet.n.01'), Synset('man.n.08'), Synset('man.n.09'), Synset('man.n.10'), Synset('world.n.08'), Synset('man.v.01'), Synset('man.v.02')]
# Phrase:  ['Man', "'s", 'life', ',', 'originally', 'shaped', 'for', 'immortality', 'and', 'for', 'communion', 'with', 'God', ',', 'must', 'now', 'be', 'conformed', 'to', 'the', 'shape', 'of', 'death', '.']
# Word: man
# Lesk algorithm: Synset('man.n.08')
# True Synset: man.n.03
# [Synset('life.n.01'), Synset('life.n.02'), Synset('life.n.03'), Synset('animation.n.01'), Synset('life.n.05'), Synset('life.n.06'), Synset('life.n.07'), Synset('life.n.08'), Synset('liveliness.n.02'), Synset('life.n.10'), Synset('life.n.11'), Synset('biography.n.01'), Synset('life.n.13'), Synset('life_sentence.n.01')]
# Phrase:  ['Man', "'s", 'life', ',', 'originally', 'shaped', 'for', 'immortality', 'and', 'for', 'communion', 'with', 'God', ',', 'must', 'now', 'be', 'conformed', 'to', 'the', 'shape', 'of', 'death', '.']
# Word: life
# Lesk algorithm: Synset('life.n.05')
# True Synset: life.n.02
# [Synset('immortality.n.01'), Synset('immortality.n.02')]
# Phrase:  ['Man', "'s", 'life', ',', 'originally', 'shaped', 'for', 'immortality', 'and', 'for', 'communion', 'with', 'God', ',', 'must', 'now', 'be', 'conformed', 'to', 'the', 'shape', 'of', 'death', '.']
# Word: immortality
# Lesk algorithm: Synset('immortality.n.02')
# True Synset: immortality.n.01
# [Synset('contemplation.n.02'), Synset('reflection.n.02'), Synset('expression.n.02'), Synset('mirror_image.n.01'), Synset('reflection.n.05'), Synset('reflection.n.06'), Synset('observation.n.03'), Synset('reflection.n.08')]
# Phrase:  ['The', 'reflection', 'of', 'radiation', 'originating', 'from', 'the', 'anode', 'holder', 'and', 'reflected', 'back', 'to', 'it', 'by', 'the', 'surrounding', 'metal', 'surfaces', 'should', 'also', 'be', 'small', 'because', 'of', 'the', 'specular', 'characteristic', 'of', 'the', 'metal', 'surfaces', 'and', 'of', 'the', 'specific', 'geometry', '.']
# Word: reflection
# Lesk algorithm: Synset('reflection.n.05')
# True Synset: reflection.n.02
# [Synset('radiation.n.01'), Synset('radiation.n.02'), Synset('radiation_sickness.n.01'), Synset('radiation.n.04'), Synset('radiation.n.05'), Synset('radiation.n.06'), Synset('radiotherapy.n.01')]
# Phrase:  ['The', 'reflection', 'of', 'radiation', 'originating', 'from', 'the', 'anode', 'holder', 'and', 'reflected', 'back', 'to', 'it', 'by', 'the', 'surrounding', 'metal', 'surfaces', 'should', 'also', 'be', 'small', 'because', 'of', 'the', 'specular', 'characteristic', 'of', 'the', 'metal', 'surfaces', 'and', 'of', 'the', 'specific', 'geometry', '.']
# Word: radiation
# Lesk algorithm: Synset('radiation_sickness.n.01')
# True Synset: radiation.n.01
# [Synset('anode.n.01'), Synset('anode.n.02')]
# Phrase:  ['The', 'reflection', 'of', 'radiation', 'originating', 'from', 'the', 'anode', 'holder', 'and', 'reflected', 'back', 'to', 'it', 'by', 'the', 'surrounding', 'metal', 'surfaces', 'should', 'also', 'be', 'small', 'because', 'of', 'the', 'specular', 'characteristic', 'of', 'the', 'metal', 'surfaces', 'and', 'of', 'the', 'specific', 'geometry', '.']
# Word: anode
# Lesk algorithm: Synset('anode.n.01')
# True Synset: anode.n.01
# [Synset('number.n.01'), Synset('number.n.02'), Synset('act.n.04'), Synset('phone_number.n.01'), Synset('numeral.n.01'), Synset('issue.n.02'), Synset('number.n.07'), Synset('number.n.08'), Synset('number.n.09'), Synset('number.n.10'), Synset('number.n.11'), Synset('total.v.01'), Synset('number.v.02'), Synset('number.v.03'), Synset('count.v.05'), Synset('count.v.01'), Synset('number.v.06')]
# Phrase:  ['Anyway', ',', 'a', 'number', 'of', 'them', 'meet', 'here', 'in', 'devastating', 'collisions', '.']
# Word: number
# Lesk algorithm: Synset('number.n.01')
# True Synset: number.n.01
# [Synset('collision.n.01'), Synset('collision.n.02'), Synset('collision.n.03')]
# Phrase:  ['Anyway', ',', 'a', 'number', 'of', 'them', 'meet', 'here', 'in', 'devastating', 'collisions', '.']
# Word: collision
# Lesk algorithm: Synset('collision.n.01')
# True Synset: collision.n.01
# [Synset('luxury.n.01'), Synset('lavishness.n.01'), Synset('luxury.n.03')]
# Phrase:  ['But', 'for', 'many', 'of', 'us', ',', 'it', 'will', 'prove', 'an', 'enjoyable', 'luxury', '.']
# Word: luxury
# Lesk algorithm: Synset('luxury.n.01')
# True Synset: luxury.n.01
# [Synset('exception.n.01'), Synset('exception.n.02'), Synset('exception.n.03')]
# Phrase:  ['There', 'is', 'one', 'exception', 'to', 'the', 'above', 'statement', 'as', 'has', 'been', 'pointed', 'out', ',', 'and', 'that', 'is', 'that', 'fluids', 'can', 'relax', 'by', 'flowing', 'into', 'fields', 'of', 'lower', 'rates', 'of', 'shear', ',', 'so', 'the', 'statement', 'should', 'be', 'modified', 'by', 'stating', 'that', 'the', 'mechanics', 'are', 'similar', '.']
# Word: exception
# Lesk algorithm: Synset('exception.n.01')
# True Synset: exception.n.01
# [Synset('statement.n.01'), Synset('argument.n.01'), Synset('statement.n.03'), Synset('statement.n.04'), Synset('affirmation.n.02'), Synset('instruction.n.04'), Synset('statement.n.07')]
# Phrase:  ['There', 'is', 'one', 'exception', 'to', 'the', 'above', 'statement', 'as', 'has', 'been', 'pointed', 'out', ',', 'and', 'that', 'is', 'that', 'fluids', 'can', 'relax', 'by', 'flowing', 'into', 'fields', 'of', 'lower', 'rates', 'of', 'shear', ',', 'so', 'the', 'statement', 'should', 'be', 'modified', 'by', 'stating', 'that', 'the', 'mechanics', 'are', 'similar', '.']
# Word: statement
# Lesk algorithm: Synset('statement.n.01')
# True Synset: statement.n.01
# [Synset('fluid.n.01'), Synset('fluid.n.02'), Synset('fluid.s.01'), Synset('fluid.s.02'), Synset('fluent.s.01'), Synset('fluid.s.04'), Synset('fluid.s.05')]
# Phrase:  ['There', 'is', 'one', 'exception', 'to', 'the', 'above', 'statement', 'as', 'has', 'been', 'pointed', 'out', ',', 'and', 'that', 'is', 'that', 'fluids', 'can', 'relax', 'by', 'flowing', 'into', 'fields', 'of', 'lower', 'rates', 'of', 'shear', ',', 'so', 'the', 'statement', 'should', 'be', 'modified', 'by', 'stating', 'that', 'the', 'mechanics', 'are', 'similar', '.']
# Word: fluid
# Lesk algorithm: Synset('fluid.s.02')
# True Synset: fluid.n.01
# [Synset('sparrow.n.01'), Synset('hedge_sparrow.n.01')]
# Phrase:  ['Sparrow', 'size', 'Virginia', 'Gibson', ',', 'with', 'sparkling', 'blue', 'eyes', 'and', 'a', 'cheerful', 'smile', ',', 'made', 'a', 'suitably', 'perky', 'Amy', ',', 'while', 'Melisande', 'Congdon', ',', 'as', 'the', 'real', 'aunt', ',', 'was', 'positively', 'monumental', 'in', 'the', 'very', 'best', 'Gibson', 'Girl', 'manner', '.']
# Word: sparrow
# Lesk algorithm: Synset('sparrow.n.01')
# True Synset: sparrow.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Sparrow', 'size', 'Virginia', 'Gibson', ',', 'with', 'sparkling', 'blue', 'eyes', 'and', 'a', 'cheerful', 'smile', ',', 'made', 'a', 'suitably', 'perky', 'Amy', ',', 'while', 'Melisande', 'Congdon', ',', 'as', 'the', 'real', 'aunt', ',', 'was', 'positively', 'monumental', 'in', 'the', 'very', 'best', 'Gibson', 'Girl', 'manner', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('eye.n.01'), Synset('eye.n.02'), Synset('eye.n.03'), Synset('center.n.01'), Synset('eye.n.05'), Synset('eye.v.01')]
# Phrase:  ['Sparrow', 'size', 'Virginia', 'Gibson', ',', 'with', 'sparkling', 'blue', 'eyes', 'and', 'a', 'cheerful', 'smile', ',', 'made', 'a', 'suitably', 'perky', 'Amy', ',', 'while', 'Melisande', 'Congdon', ',', 'as', 'the', 'real', 'aunt', ',', 'was', 'positively', 'monumental', 'in', 'the', 'very', 'best', 'Gibson', 'Girl', 'manner', '.']
# Word: eye
# Lesk algorithm: Synset('eye.n.01')
# True Synset: eye.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Beebe', 'had', 'a', '3', '-', 'foot', 'anaconda', 'that', 'weighed', 'only', '9.8', 'ounces', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('foot.n.01'), Synset('foot.n.02'), Synset('foot.n.03'), Synset('animal_foot.n.01'), Synset('foundation.n.03'), Synset('foot.n.06'), Synset('foot.n.07'), Synset('foot.n.08'), Synset('infantry.n.01'), Synset('metrical_foot.n.01'), Synset('foot.n.11'), Synset('foot.v.01'), Synset('foot.v.02'), Synset('foot.v.03')]
# Phrase:  ['Beebe', 'had', 'a', '3', '-', 'foot', 'anaconda', 'that', 'weighed', 'only', '9.8', 'ounces', '.']
# Word: foot
# Lesk algorithm: Synset('foot.n.01')
# True Synset: foot.n.02
# [Synset('anaconda.n.01')]
# Phrase:  ['Beebe', 'had', 'a', '3', '-', 'foot', 'anaconda', 'that', 'weighed', 'only', '9.8', 'ounces', '.']
# Word: anaconda
# Lesk algorithm: Synset('anaconda.n.01')
# True Synset: anaconda.n.01
# [Synset('folklore.n.01')]
# Phrase:  ['Folklore', 'is', 'individually', 'created', 'art', 'that', 'a', 'homogeneous', 'group', 'of', 'people', 'preserve', ',', 'vary', 'and', 'recreate', 'through', 'oral', 'transmission', '.']
# Word: folklore
# Lesk algorithm: Synset('folklore.n.01')
# True Synset: folklore.n.01
# [Synset('art.n.01'), Synset('art.n.02'), Synset('art.n.03'), Synset('artwork.n.01')]
# Phrase:  ['Folklore', 'is', 'individually', 'created', 'art', 'that', 'a', 'homogeneous', 'group', 'of', 'people', 'preserve', ',', 'vary', 'and', 'recreate', 'through', 'oral', 'transmission', '.']
# Word: art
# Lesk algorithm: Synset('art.n.01')
# True Synset: art.n.01
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['Folklore', 'is', 'individually', 'created', 'art', 'that', 'a', 'homogeneous', 'group', 'of', 'people', 'preserve', ',', 'vary', 'and', 'recreate', 'through', 'oral', 'transmission', '.']
# Word: group
# Lesk algorithm: Synset('group.v.01')
# True Synset: group.n.01
# [Synset('mechanism.n.01'), Synset('mechanism.n.02'), Synset('mechanism.n.03'), Synset('mechanism.n.04'), Synset('mechanism.n.05')]
# Phrase:  ['It', 'does', 'not', 'appear', 'to', 'affect', 'the', 'iodinating', 'mechanism', 'as', 'such', '.']
# Word: mechanism
# Lesk algorithm: Synset('mechanism.n.02')
# True Synset: mechanism.n.01
# [Synset('prospect.n.01'), Synset('expectation.n.01'), Synset('candidate.n.02'), Synset('view.n.02'), Synset('prognosis.n.02'), Synset('prospect.v.01'), Synset('prospect.v.02')]
# ...
# True Synset: development.n.02
# [Synset('position.n.03'), Synset('view.n.02'), Synset('view.n.03'), Synset('view.n.04'), Synset('opinion.n.01'), Synset('opinion.n.02'), Synset('view.n.07'), Synset('scene.n.08'), Synset('horizon.n.02'), Synset('view.n.10'), Synset('see.v.05'), Synset('view.v.02'), Synset('watch.v.03')]
# Phrase:  ['There', 'have', 'been', ',', 'indeed', ',', 'many', 'important', 'and', 'valuable', 'gains', 'from', 'the', 'development', 'of', 'our', 'present', 'scientific', 'view', 'of', 'the', 'world', 'for', 'which', 'we', 'may', 'be', 'rightly', 'grateful', '.']
# Word: view
# Lesk algorithm: Synset('position.n.03')
# True Synset: position.n.03
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Friend', 'is', 'off', 'to', 'a', 'great', 'start', 'with', 'a', '4', '-', '0', 'record', 'but', 'is', "n't", 'likely', 'to', 'see', 'action', 'here', 'this', 'week', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('start.n.01'), Synset('beginning.n.02'), Synset('start.n.03'), Synset('startle.n.01'), Synset('beginning.n.05'), Synset('start.n.06'), Synset('starting_signal.n.01'), Synset('start.n.08'), Synset('get_down.v.07'), Synset('begin.v.03'), Synset('depart.v.03'), Synset('begin.v.02'), Synset('originate.v.02'), Synset('start.v.06'), Synset('startle.v.02'), Synset('start.v.08'), Synset('start.v.09'), Synset('start.v.10'), Synset('start.v.11'), Synset('begin.v.07'), Synset('begin.v.08'), Synset('start.v.14')]
# Phrase:  ['Friend', 'is', 'off', 'to', 'a', 'great', 'start', 'with', 'a', '4', '-', '0', 'record', 'but', 'is', "n't", 'likely', 'to', 'see', 'action', 'here', 'this', 'week', '.']
# Word: start
# Lesk algorithm: Synset('get_down.v.07')
# True Synset: start.n.01
# [Synset('record.n.01'), Synset('phonograph_record.n.01'), Synset('record.n.03'), Synset('record.n.04'), Synset('record.n.05'), Synset('record.n.06'), Synset('record.n.07'), Synset('criminal_record.n.01'), Synset('record.v.01'), Synset('record.v.02'), Synset('read.v.08'), Synset('record.v.04'), Synset('commemorate.v.03')]
# Phrase:  ['Friend', 'is', 'off', 'to', 'a', 'great', 'start', 'with', 'a', '4', '-', '0', 'record', 'but', 'is', "n't", 'likely', 'to', 'see', 'action', 'here', 'this', 'week', '.']
# Word: record
# Lesk algorithm: Synset('record.n.01')
# True Synset: record.n.03
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['The', 'Senate', 'quickly', 'whipped', 'through', 'its', 'meager', 'fare', 'of', 'House', 'bills', 'approved', 'by', 'committees', ',', 'passing', 'the', 'three', 'on', 'the', 'calendar', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('menu.n.04'), Synset('fare.n.02'), Synset('fare.n.03'), Synset('fare.n.04'), Synset('do.v.04'), Synset('fare.v.02')]
# Phrase:  ['The', 'Senate', 'quickly', 'whipped', 'through', 'its', 'meager', 'fare', 'of', 'House', 'bills', 'approved', 'by', 'committees', ',', 'passing', 'the', 'three', 'on', 'the', 'calendar', '.']
# Word: fare
# Lesk algorithm: Synset('menu.n.04')
# True Synset: menu.n.04
# [Synset('group.n.01'), Synset('group.n.02'), Synset('group.n.03'), Synset('group.v.01'), Synset('group.v.02')]
# Phrase:  ['The', 'Senate', 'quickly', 'whipped', 'through', 'its', 'meager', 'fare', 'of', 'House', 'bills', 'approved', 'by', 'committees', ',', 'passing', 'the', 'three', 'on', 'the', 'calendar', '.']
# Word: group
# Lesk algorithm: Synset('group.n.01')
# True Synset: group.n.01
# [Synset('attempt.n.01'), Synset('attack.n.05'), Synset('try.v.01'), Synset('undertake.v.01')]
# Phrase:  ['Repeated', 'attempts', 'to', 'withdraw', 'steroids', 'entirely', 'were', 'unsuccessful', 'because', 'increased', 'muscle', 'weakness', 'resulted', ',', 'as', 'well', 'as', 'fever', ',', 'malaise', ',', 'anorexia', ',', 'anxiety', ',', 'and', 'an', 'exacerbation', 'of', 'the', 'anemia', '.']
# Word: attempt
# Lesk algorithm: Synset('attack.n.05')
# True Synset: attempt.n.01
# [Synset('steroid.n.01'), Synset('steroid_hormone.n.01')]
# Phrase:  ['Repeated', 'attempts', 'to', 'withdraw', 'steroids', 'entirely', 'were', 'unsuccessful', 'because', 'increased', 'muscle', 'weakness', 'resulted', ',', 'as', 'well', 'as', 'fever', ',', 'malaise', ',', 'anorexia', ',', 'anxiety', ',', 'and', 'an', 'exacerbation', 'of', 'the', 'anemia', '.']
# Word: steroid
# Lesk algorithm: Synset('steroid.n.01')
# True Synset: steroid.n.01
# [Synset('muscle.n.01'), Synset('muscle.n.02'), Synset('muscleman.n.01'), Synset('muscle.n.04'), Synset('brawn.n.01'), Synset('muscle.v.01')]
# Phrase:  ['Repeated', 'attempts', 'to', 'withdraw', 'steroids', 'entirely', 'were', 'unsuccessful', 'because', 'increased', 'muscle', 'weakness', 'resulted', ',', 'as', 'well', 'as', 'fever', ',', 'malaise', ',', 'anorexia', ',', 'anxiety', ',', 'and', 'an', 'exacerbation', 'of', 'the', 'anemia', '.']
# Word: muscle
# Lesk algorithm: Synset('muscle.n.04')
# True Synset: muscle.n.01
# [Synset('area.n.01'), Synset('area.n.02'), Synset('area.n.03'), Synset('sphere.n.01'), Synset('area.n.05'), Synset('area.n.06')]
# Phrase:  ['Some', 'areas', 'may', 'provide', 'archeological', 'values', 'such', 'as', 'ancient', 'Indian', 'village', 'sites', 'or', 'hunting', 'areas', ',', 'caves', ',', 'artifacts', ',', 'etcetera', '.']
# Word: area
# Lesk algorithm: Synset('area.n.02')
# True Synset: area.n.01
# [Synset('value.n.01'), Synset('value.n.02'), Synset('value.n.03'), Synset('value.n.04'), Synset('value.n.05'), Synset('value.n.06'), Synset('value.v.01'), Synset('prize.v.01'), Synset('respect.v.01'), Synset('measure.v.04'), Synset('rate.v.03')]
# Phrase:  ['Some', 'areas', 'may', 'provide', 'archeological', 'values', 'such', 'as', 'ancient', 'Indian', 'village', 'sites', 'or', 'hunting', 'areas', ',', 'caves', ',', 'artifacts', ',', 'etcetera', '.']
# Word: value
# Lesk algorithm: Synset('value.n.04')
# True Synset: value.n.02
# [Synset('village.n.01'), Synset('village.n.02'), Synset('greenwich_village.n.01')]
# Phrase:  ['Some', 'areas', 'may', 'provide', 'archeological', 'values', 'such', 'as', 'ancient', 'Indian', 'village', 'sites', 'or', 'hunting', 'areas', ',', 'caves', ',', 'artifacts', ',', 'etcetera', '.']
# Word: village
# Lesk algorithm: Synset('village.n.01')
# True Synset: village.n.01
# [Synset('system.n.01'), Synset('system.n.02'), Synset('system.n.03'), Synset('system.n.04'), Synset('arrangement.n.03'), Synset('system.n.06'), Synset('system.n.07'), Synset('system.n.08'), Synset('organization.n.05')]
# Phrase:  ['A', 'system', 'had', 'to', 'be', 'used', 'which', 'did', 'not', 'depend', 'upon', 'the', 'feeding', 'of', 'the', 'fluid', 'into', 'the', 'manometer', 'if', 'measurements', 'of', 'the', 'normal', 'pressure', 'were', 'to', 'be', 'made', 'in', 'a', 'reasonable', 'time', '.']
# Word: system
# Lesk algorithm: Synset('system.n.07')
# True Synset: system.n.07
# [Synset('eating.n.01'), Synset('feeding.n.02'), Synset('feed.v.01'), Synset('feed.v.02'), Synset('feed.v.03'), Synset('feed.v.04'), Synset('feed.v.05'), Synset('feed.v.06'), Synset('feed.v.07'), Synset('run.v.06'), Synset('prey.v.01'), Synset('feed.v.10'), Synset('fertilize.v.01')]
# Phrase:  ['A', 'system', 'had', 'to', 'be', 'used', 'which', 'did', 'not', 'depend', 'upon', 'the', 'feeding', 'of', 'the', 'fluid', 'into', 'the', 'manometer', 'if', 'measurements', 'of', 'the', 'normal', 'pressure', 'were', 'to', 'be', 'made', 'in', 'a', 'reasonable', 'time', '.']
# Word: feeding
# Lesk algorithm: Synset('eating.n.01')
# True Synset: eating.n.01
# [Synset('fluid.n.01'), Synset('fluid.n.02'), Synset('fluid.s.01'), Synset('fluid.s.02'), Synset('fluent.s.01'), Synset('fluid.s.04'), Synset('fluid.s.05')]
# Phrase:  ['A', 'system', 'had', 'to', 'be', 'used', 'which', 'did', 'not', 'depend', 'upon', 'the', 'feeding', 'of', 'the', 'fluid', 'into', 'the', 'manometer', 'if', 'measurements', 'of', 'the', 'normal', 'pressure', 'were', 'to', 'be', 'made', 'in', 'a', 'reasonable', 'time', '.']
# Word: fluid
# Lesk algorithm: Synset('fluid.n.01')
# True Synset: fluid.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['``', 'How', 'many', 'is', 'that', ',', 'Jim', "''", '?', 'asked', 'Willie', 'at', 'one', 'stage', 'of', 'his', 'excavation', 'project', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['``', 'How', 'many', 'is', 'that', ',', 'Jim', "''", '?', 'asked', 'Willie', 'at', 'one', 'stage', 'of', 'his', 'excavation', 'project', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('phase.n.01'), Synset('degree.n.02'), Synset('stage.n.03'), Synset('stage.n.04'), Synset('stagecoach.n.01'), Synset('stage.n.06'), Synset('stage.n.07'), Synset('stage.n.08'), Synset('stage.v.01'), Synset('stage.v.02')]
# Phrase:  ['``', 'How', 'many', 'is', 'that', ',', 'Jim', "''", '?', 'asked', 'Willie', 'at', 'one', 'stage', 'of', 'his', 'excavation', 'project', '.']
# Word: stage
# Lesk algorithm: Synset('phase.n.01')
# True Synset: phase.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['After', 'Larkin', 'has', 'been', 'persuaded', 'to', 'restock', 'his', 'tangled', 'acres', 'with', 'pheasants', ',', 'he', 'poaches', 'only', 'what', 'he', 'needs', 'for', 'the', 'nourishment', 'of', 'his', 'family', 'and', 'local', 'callers', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('estate.n.02'), Synset('acre.n.01'), Synset('acre.n.02'), Synset('acre.n.03')]
# Phrase:  ['After', 'Larkin', 'has', 'been', 'persuaded', 'to', 'restock', 'his', 'tangled', 'acres', 'with', 'pheasants', ',', 'he', 'poaches', 'only', 'what', 'he', 'needs', 'for', 'the', 'nourishment', 'of', 'his', 'family', 'and', 'local', 'callers', '.']
# Word: acres
# Lesk algorithm: Synset('estate.n.02')
# True Synset: estate.n.02
# [Synset('pheasant.n.01'), Synset('pheasant.n.02')]
# Phrase:  ['After', 'Larkin', 'has', 'been', 'persuaded', 'to', 'restock', 'his', 'tangled', 'acres', 'with', 'pheasants', ',', 'he', 'poaches', 'only', 'what', 'he', 'needs', 'for', 'the', 'nourishment', 'of', 'his', 'family', 'and', 'local', 'callers', '.']
# Word: pheasant
# Lesk algorithm: Synset('pheasant.n.01')
# True Synset: pheasant.n.01
# [Synset('argument.n.01'), Synset('controversy.n.01'), Synset('argument.n.03'), Synset('argument.n.04'), Synset('argument.n.05'), Synset('argument.n.06'), Synset('argumentation.n.02')]
# Phrase:  ['The', 'first', 'argument', 'is', 'thus', 'an', 'ideal', 'experiment', 'in', 'which', 'we', 'use', 'the', 'method', 'of', 'difference', '.']
# Word: argument
# Lesk algorithm: Synset('argument.n.01')
# True Synset: argument.n.01
# [Synset('experiment.n.01'), Synset('experiment.n.02'), Synset('experiment.n.03'), Synset('experiment.v.01'), Synset('experiment.v.02')]
# Phrase:  ['The', 'first', 'argument', 'is', 'thus', 'an', 'ideal', 'experiment', 'in', 'which', 'we', 'use', 'the', 'method', 'of', 'difference', '.']
# Word: experiment
# Lesk algorithm: Synset('experiment.v.02')
# True Synset: experiment.n.01
# [Synset('method.n.01'), Synset('method_acting.n.01')]
# Phrase:  ['The', 'first', 'argument', 'is', 'thus', 'an', 'ideal', 'experiment', 'in', 'which', 'we', 'use', 'the', 'method', 'of', 'difference', '.']
# Word: method
# Lesk algorithm: Synset('method.n.01')
# True Synset: method.n.01
# [Synset('person.n.01'), Synset('person.n.02'), Synset('person.n.03')]
# Phrase:  ['Brown', '(', '1959', ')', 'has', 'reviewed', 'generally', 'the', 'various', 'methods', 'of', 'assaying', 'TSH', ',', 'and', 'the', 'reader', 'is', 'referred', 'to', 'her', 'paper', 'for', 'further', 'information', 'on', 'the', 'subject', '.']
# Word: person
# Lesk algorithm: Synset('person.n.01')
# True Synset: person.n.01
# [Synset('method.n.01'), Synset('method_acting.n.01')]
# Phrase:  ['Brown', '(', '1959', ')', 'has', 'reviewed', 'generally', 'the', 'various', 'methods', 'of', 'assaying', 'TSH', ',', 'and', 'the', 'reader', 'is', 'referred', 'to', 'her', 'paper', 'for', 'further', 'information', 'on', 'the', 'subject', '.']
# Word: method
# Lesk algorithm: Synset('method.n.01')
# True Synset: method.n.01
# [Synset('thyrotropin.n.01')]
# Phrase:  ['Brown', '(', '1959', ')', 'has', 'reviewed', 'generally', 'the', 'various', 'methods', 'of', 'assaying', 'TSH', ',', 'and', 'the', 'reader', 'is', 'referred', 'to', 'her', 'paper', 'for', 'further', 'information', 'on', 'the', 'subject', '.']
# Word: TSH
# Lesk algorithm: Synset('thyrotropin.n.01')
# True Synset: thyrotropin.n.01
# [Synset('mention.n.01'), Synset('citation.n.03'), Synset('reference_point.n.01'), Synset('reference_book.n.01'), Synset('character.n.07'), Synset('reference.n.06'), Synset('reference.n.07'), Synset('reference.n.08'), Synset('address.n.01'), Synset('reference.n.10'), Synset('reference.v.01')]
# Phrase:  ['No', 'reference', 'is', 'made', 'to', 'the', 'possibility', 'of', 'recording', 'other', 'than', 'popular', 'music', 'in', 'this', 'manner', ',', 'and', 'it', 'would', 'not', 'seem', 'to', 'lend', 'itself', 'well', 'to', 'serious', 'music', '.']
# Word: reference
# Lesk algorithm: Synset('reference_point.n.01')
# True Synset: mention.n.01
# [Synset('possibility.n.01'), Synset('possibility.n.02'), Synset('hypothesis.n.02'), Synset('possibility.n.04')]
# Phrase:  ['No', 'reference', 'is', 'made', 'to', 'the', 'possibility', 'of', 'recording', 'other', 'than', 'popular', 'music', 'in', 'this', 'manner', ',', 'and', 'it', 'would', 'not', 'seem', 'to', 'lend', 'itself', 'well', 'to', 'serious', 'music', '.']
# Word: possibility
# Lesk algorithm: Synset('possibility.n.02')
# True Synset: possibility.n.01
# [Synset('popular_music.n.01')]
# Phrase:  ['No', 'reference', 'is', 'made', 'to', 'the', 'possibility', 'of', 'recording', 'other', 'than', 'popular', 'music', 'in', 'this', 'manner', ',', 'and', 'it', 'would', 'not', 'seem', 'to', 'lend', 'itself', 'well', 'to', 'serious', 'music', '.']
# Word: popular_music
# Lesk algorithm: Synset('popular_music.n.01')
# True Synset: popular_music.n.01
# [Synset('rooting.n.01'), Synset('root.v.01'), Synset('root.v.02'), Synset('root.v.03'), Synset('rout.v.02'), Synset('settle.v.07'), Synset('root.v.06')]
# Phrase:  ['That', 'encourages', 'rooting', ',', 'and', 'the', 'better', 'developed', 'the', 'roots', ',', 'the', 'larger', 'and', 'more', 'plentiful', 'the', 'flowers', '.']
# Word: rooting
# Lesk algorithm: Synset('rooting.n.01')
# True Synset: rooting.n.01
# [Synset('root.n.01'), Synset('beginning.n.04'), Synset('root.n.03'), Synset('root.n.04'), Synset('solution.n.04'), Synset('ancestor.n.01'), Synset('etymon.n.01'), Synset('root.n.08'), Synset('root.v.01'), Synset('root.v.02'), Synset('root.v.03'), Synset('rout.v.02'), Synset('settle.v.07'), Synset('root.v.06')]
# Phrase:  ['That', 'encourages', 'rooting', ',', 'and', 'the', 'better', 'developed', 'the', 'roots', ',', 'the', 'larger', 'and', 'more', 'plentiful', 'the', 'flowers', '.']
# Word: root
# Lesk algorithm: Synset('root.v.01')
# True Synset: root.n.01
# [Synset('flower.n.01'), Synset('flower.n.02'), Synset('flower.n.03'), Synset('bloom.v.01')]
# Phrase:  ['That', 'encourages', 'rooting', ',', 'and', 'the', 'better', 'developed', 'the', 'roots', ',', 'the', 'larger', 'and', 'more', 'plentiful', 'the', 'flowers', '.']
# Word: flower
# Lesk algorithm: Synset('bloom.v.01')
# True Synset: flower.n.01
# [Synset('device.n.01'), Synset('device.n.02'), Synset('device.n.03'), Synset('device.n.04'), Synset('device.n.05')]
# Phrase:  ['It', 'should', 'be', 'no', 'more', 'difficult', 'to', 'deliver', 'such', 'devices', 'than', 'other', 'weapons', '.']
# Word: device
# Lesk algorithm: Synset('device.n.01')
# True Synset: device.n.01
# [Synset('weapon.n.01'), Synset('weapon.n.02')]
# Phrase:  ['It', 'should', 'be', 'no', 'more', 'difficult', 'to', 'deliver', 'such', 'devices', 'than', 'other', 'weapons', '.']
# Word: weapon
# Lesk algorithm: Synset('weapon.n.02')
# True Synset: weapon.n.01
# Numero di volte che lesk ha trovato la giusta definizione: 88
# Numero di nomi totali da disambiguare: 135
# Final Accuracy: 0.6397702365766589
